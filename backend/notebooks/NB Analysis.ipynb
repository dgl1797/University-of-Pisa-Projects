# %% [markdown]
# ## ANALYSIS WITH LEVEL

# %%
import pandas as pd
import numpy as np

ranks_df = pd.read_csv("../csv_sources/leveled_for_rarity.csv").drop(["index", "crowns"], axis="columns")
print("---------------------------------------------------")
print(ranks_df[["rank", "troop"]].groupby("rank").mean())
print(ranks_df[["rank", "troop"]].groupby("rank").std())
print("---------------------------------------------------")
print("---------------------------------------------------")
print(ranks_df[["rank", "building"]].groupby("rank").mean())
print(ranks_df[["rank", "building"]].groupby("rank").std())
print("---------------------------------------------------")
print("---------------------------------------------------")
print(ranks_df[["rank", "spell"]].groupby("rank").mean())
print(ranks_df[["rank", "spell"]].groupby("rank").std())
print("---------------------------------------------------")
print("---------------------------------------------------")
print(ranks_df[["rank", "common"]].groupby("rank").mean())
print(ranks_df[["rank", "common"]].groupby("rank").std())
print("---------------------------------------------------")
print("---------------------------------------------------")
print(ranks_df[["rank", "rare"]].groupby("rank").mean())
print(ranks_df[["rank", "rare"]].groupby("rank").std())
print("---------------------------------------------------")
print("---------------------------------------------------")
print(ranks_df[["rank", "epic"]].groupby("rank").mean())
print(ranks_df[["rank", "epic"]].groupby("rank").std())
print("---------------------------------------------------")
print("---------------------------------------------------")
print(ranks_df[["rank", "legendary"]].groupby("rank").mean())
print(ranks_df[["rank", "legendary"]].groupby("rank").std())
print("---------------------------------------------------")
print("---------------------------------------------------")
print(ranks_df[["rank", "elixir"]].groupby("rank").mean())
print(ranks_df[["rank", "elixir"]].groupby("rank").std())
print("---------------------------------------------------")
print("---------------------------------------------------")
print(ranks_df[["rank", "conf_synergy"]].groupby("rank").mean())
print(ranks_df[["rank", "conf_synergy"]].groupby("rank").std())
print("---------------------------------------------------")
print("---------------------------------------------------")
print(ranks_df[["rank", "lift_synergy"]].groupby("rank").mean())
print(ranks_df[["rank", "lift_synergy"]].groupby("rank").std())
print("---------------------------------------------------")
print("---------------------------------------------------")
print(ranks_df[["rank", "levelSum"]].groupby("rank").mean())
print(ranks_df[["rank", "levelSum"]].groupby("rank").std())
print("---------------------------------------------------")
print("---------------------------------------------------")
print(ranks_df[["rank", "avgSpeed"]].groupby("rank").mean())
print(ranks_df[["rank", "avgSpeed"]].groupby("rank").std())
print("---------------------------------------------------")
print("---------------------------------------------------")
print(ranks_df[["rank", "avgSpellDuration"]].groupby("rank").mean())
print(ranks_df[["rank", "avgSpellDuration"]].groupby("rank").std())
print("---------------------------------------------------")
print("---------------------------------------------------")
print(ranks_df[["rank", "totalHP"]].groupby("rank").mean())
print(ranks_df[["rank", "totalHP"]].groupby("rank").std())
print("---------------------------------------------------")
print("---------------------------------------------------")
print(ranks_df[["rank", "totalDMG"]].groupby("rank").mean())
print(ranks_df[["rank", "totalDMG"]].groupby("rank").std())
print("---------------------------------------------------")
print("---------------------------------------------------")
print(ranks_df[["rank", "avgAS"]].groupby("rank").mean())
print(ranks_df[["rank", "avgAS"]].groupby("rank").std())
print("---------------------------------------------------")
print("---------------------------------------------------")
print(ranks_df[["rank", "totalUnitsCount"]].groupby("rank").mean())
print(ranks_df[["rank", "totalUnitsCount"]].groupby("rank").std())
print("---------------------------------------------------")
print("---------------------------------------------------")
print(ranks_df[["rank", "abilityCount"]].groupby("rank").mean())
print(ranks_df[["rank", "abilityCount"]].groupby("rank").std())
print("---------------------------------------------------")
print("---------------------------------------------------")
print(ranks_df[["rank", "avgRange"]].groupby("rank").mean())
print(ranks_df[["rank", "avgRange"]].groupby("rank").std())
print("---------------------------------------------------")
print("---------------------------------------------------")
print(ranks_df[["rank", "totalGroundT"]].groupby("rank").mean())
print(ranks_df[["rank", "totalGroundT"]].groupby("rank").std())
print("---------------------------------------------------")
print("---------------------------------------------------")
print(ranks_df[["rank", "totalAirT"]].groupby("rank").mean())
print(ranks_df[["rank", "totalAirT"]].groupby("rank").std())
print("---------------------------------------------------")
print("---------------------------------------------------")
print(ranks_df[["rank", "totalBuildingT"]].groupby("rank").mean())
print(ranks_df[["rank", "totalBuildingT"]].groupby("rank").std())
print("---------------------------------------------------")
print("---------------------------------------------------")
print(ranks_df[["rank", "totalBuffCount"]].groupby("rank").mean())
print(ranks_df[["rank", "totalBuffCount"]].groupby("rank").std())
print("---------------------------------------------------")
print("---------------------------------------------------")
print(ranks_df[["rank", "totalProjectiles"]].groupby("rank").mean())
print(ranks_df[["rank", "totalProjectiles"]].groupby("rank").std())
print("---------------------------------------------------")
print("---------------------------------------------------")

ranks_df
# Out:
# ---------------------------------------------------
#                troop
# rank
# Challenger  5.889429
# Champion    5.137143
# Master      5.368857
#                troop
# rank
# Challenger  1.115021
# Champion    0.950650
# Master      1.013316
# ---------------------------------------------------
# ---------------------------------------------------
#             building
# rank
# Challenger  0.372857
# Champion    0.508571
# Master      0.516571
#             building
# rank
# Challenger   0.55465
# Champion     0.58287
# Master       0.60342
# ---------------------------------------------------
# ---------------------------------------------------
#                spell
# rank
# Challenger  1.737714
# Champion    2.354286
# Master      2.114571
#                spell
# rank
# Challenger  0.902700
# Champion    0.688925
# Master      0.792047
# ---------------------------------------------------
# ---------------------------------------------------
#               common
# rank
# Challenger  2.013143
# Champion    2.072000
# Master      2.136571
#               common
# rank
# Challenger  1.294281
# Champion    1.376305
# Master      1.301693
# ---------------------------------------------------
# ---------------------------------------------------
#                 rare
# rank
# Challenger  2.021143
# Champion    1.655429
# Master      2.154286
#                 rare
# rank
# Challenger  1.248999
# Champion    1.116844
# Master      1.283559
# ---------------------------------------------------
# ---------------------------------------------------
#                 epic
# rank
# Challenger  2.185714
# Champion    2.470857
# Master      2.216857
#                 epic
# rank
# Challenger  1.298458
# Champion    1.577567
# Master      1.415668
# ---------------------------------------------------
# ---------------------------------------------------
#             legendary
# rank
# Challenger   1.780000
# Champion     1.801714
# Master       1.492286
#             legendary
# rank
# Challenger   1.344450
# Champion     1.019444
# Master       1.047158
# ---------------------------------------------------
# ---------------------------------------------------
#               elixir
# rank
# Challenger  3.941923
# Champion    3.663602
# Master      3.789852
#               elixir
# rank
# Challenger  0.537450
# Champion    0.489592
# Master      0.496820
# ---------------------------------------------------
# ---------------------------------------------------
#             conf_synergy
# rank
# Challenger   5166.317494
# Champion    11960.667065
# Master       8512.293683
#             conf_synergy
# rank
# Challenger  11910.223708
# Champion    16885.578943
# Master      14923.715174
# ---------------------------------------------------
# ---------------------------------------------------
#              lift_synergy
# rank
# Challenger  171762.530769
# Champion    366761.641239
# Master      273465.345554
#              lift_synergy
# rank
# Challenger  431438.047552
# Champion    543340.957634
# Master      517453.027176
# ---------------------------------------------------
# ---------------------------------------------------
#               levelSum
# rank
# Challenger   91.497714
# Champion    103.779429
# Master      103.326571
#              levelSum
# rank
# Challenger  11.262933
# Champion     0.590900
# Master       1.403027
# ---------------------------------------------------
# ---------------------------------------------------
#              avgSpeed
# rank
# Challenger  76.585816
# Champion    75.893459
# Master      77.657602
#              avgSpeed
# rank
# Challenger   9.492413
# Champion    10.364504
# Master       9.948391
# ---------------------------------------------------
# ---------------------------------------------------
#             avgSpellDuration
# rank
# Challenger          5.644639
# Champion            5.840915
# Master              6.916762
#             avgSpellDuration
# rank
# Challenger          8.355736
# Champion            6.088218
# Master              8.031840
# ---------------------------------------------------
# ---------------------------------------------------
#                 totalHP
# rank
# Challenger  8081.543429
# Champion    8247.429143
# Master      8776.516000
#                 totalHP
# rank
# Challenger  2481.123329
# Champion    2348.916699
# Master      2527.995296
# ---------------------------------------------------
# ---------------------------------------------------
#                totalDMG
# rank
# Challenger  2122.466571
# Champion    2219.544857
# Master      2306.429429
#               totalDMG
# rank
# Challenger  736.051547
# Champion    771.445512
# Master      757.911465
# ---------------------------------------------------
# ---------------------------------------------------
#                avgAS
# rank
# Challenger  1.564996
# Champion    1.717283
# Master      1.681641
#                avgAS
# rank
# Challenger  0.469242
# Champion    0.658200
# Master      0.618986
# ---------------------------------------------------
# ---------------------------------------------------
#             totalUnitsCount
# rank
# Challenger        13.337714
# Champion           9.594571
# Master            11.098000
#             totalUnitsCount
# rank
# Challenger         7.276297
# Champion           5.809535
# Master             6.554788
# ---------------------------------------------------
# ---------------------------------------------------
#             abilityCount
# rank
# Challenger      2.488857
# Champion        2.569143
# Master          2.147143
#             abilityCount
# rank
# Challenger      1.472096
# Champion        1.367807
# Master          1.312026
# ---------------------------------------------------
# ---------------------------------------------------
#                avgRange
# rank
# Challenger  2863.975000
# Champion    2976.914286
# Master      2801.794643
#               avgRange
# rank
# Challenger  637.938937
# Champion    688.172799
# Master      640.297747
# ---------------------------------------------------
# ---------------------------------------------------
#             totalGroundT
# rank
# Challenger      7.923429
# Champion        7.982286
# Master          7.953714
#             totalGroundT
# rank
# Challenger      0.275450
# Champion        0.131930
# Master          0.212836
# ---------------------------------------------------
# ---------------------------------------------------
#             totalAirT
# rank
# Challenger   4.072286
# Champion     4.089714
# Master       3.991714
#             totalAirT
# rank
# Challenger   1.023406
# Champion     0.895167
# Master       0.966835
# ---------------------------------------------------
# ---------------------------------------------------
#             totalBuildingT
# rank
# Challenger        0.910000
# Champion          0.920000
# Master            0.947429
#             totalBuildingT
# rank
# Challenger        0.750088
# Champion          0.636509
# Master            0.632168
# ---------------------------------------------------
# ---------------------------------------------------
#             totalBuffCount
# rank
# Challenger        0.672571
# Champion          0.956000
# Master            0.821143
#             totalBuffCount
# rank
# Challenger        0.711793
# Champion          0.743309
# Master            0.739224
# ---------------------------------------------------
# ---------------------------------------------------
#             totalProjectiles
# rank
# Challenger          1.123714
# Champion            1.377429
# Master              1.324000
#             totalProjectiles
# rank
# Challenger          0.850908
# Champion            0.865062
# Master              0.866740
# ---------------------------------------------------
# ---------------------------------------------------
#              rank  troop  building  spell  common  rare  epic  legendary  \
# 0      Challenger      5         0      3       1     1     4          2
# 1      Challenger      5         1      2       1     2     3          2
# 2          Master      7         1      0       3     3     2          0
# 3      Challenger      7         0      1       4     2     1          1
# 4      Challenger      5         0      3       1     1     5          1
# ...           ...    ...       ...    ...     ...   ...   ...        ...
# 10495    Champion      5         1      2       0     4     4          0
# 10496    Champion      6         0      2       1     2     3          2
# 10497    Champion      6         0      2       2     1     2          3
# 10498    Champion      5         1      2       4     2     1          1
# 10499    Champion      6         0      2       0     1     6          1
#
#        elixir  conf_synergy  ...  avgRange  totalGroundT  totalAirT  \
# 0       3.375   2865.990531  ...   2712.50             8          3
# 1       4.250   3980.516610  ...   2018.75             7          5
# 2       4.875      0.000000  ...   1925.00             8          2
# 3       3.750   1389.332225  ...   4175.00             8          6
# 4       4.500   4049.013035  ...   3056.25             8          4
# ...       ...           ...  ...       ...           ...        ...
# 10495   3.625   2191.588585  ...   2800.00             8          4
# 10496   4.000  26569.219252  ...   2581.25             8          4
# 10497   3.750   2671.736517  ...   2275.00             8          4
# 10498   3.125  14365.842341  ...   3868.75             8          3
# 10499   4.625   3303.615309  ...   3006.25             8          5
#
#        totalBuildingT  totalBuffCount  totalProjectiles  commonLevel  \
# 0                   0               0                 3        11.00
# 1                   1               2                 0        13.00
# 2                   2               0                 0        13.00
# 3                   0               0                 1        13.00
# 4                   1               2                 1        13.00
# ...               ...             ...               ...          ...
# 10495               1               1                 1         0.00
# 10496               1               2                 0        13.00
# 10497               1               1                 1        13.00
# 10498               1               0                 2        16.25
# 10499               1               0                 2         0.00
#
#        rareLevel  epicLevel  legendaryLevel
# 0           11.0      10.25            10.5
# 1           13.0      13.00            13.0
# 2           13.0      13.00             0.0
# 3           13.0      13.00            13.0
# 4           13.0      13.00            13.0
# ...          ...        ...             ...
# 10495       13.0      13.00             0.0
# 10496       13.0      13.00            13.0
# 10497       13.0      13.00            13.0
# 10498       13.0       0.00            13.0
# 10499       13.0      13.00            13.0
#
# [10500 rows x 29 columns]

# %%
from sklearn.model_selection import StratifiedKFold
from imblearn.pipeline import Pipeline
from imblearn.over_sampling import SMOTE
from sklearn.feature_selection import SelectKBest, chi2, mutual_info_classif, VarianceThreshold
from sklearn.metrics import classification_report
from sklearn.model_selection import cross_validate
from sklearn.tree import DecisionTreeClassifier
from random import randrange
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn.metrics import make_scorer
from sklearn.naive_bayes import GaussianNB

y = np.array([x for x in ranks_df["rank"]])
X = np.array([x for x in ranks_df.drop(["rank"], axis="columns").values])

scoring = {
    'Accuracy': make_scorer(accuracy_score),
    'Precision': make_scorer(precision_score, average='macro', zero_division=0),
    'Recall': make_scorer(recall_score, average="macro", zero_division=0),
    'F-Measure': make_scorer(f1_score, average="macro", zero_division=0)
}

def converter(df):
    scores = {
        'fit_time': df['fit_time'],
        'score_time': df['score_time'],
        'test_Accuracy': df['test_Accuracy'],
        'test_Precision': df['test_Precision'],
        'test_Recall': df['test_Recall'],
        'test_F-Measure': df['test_F-Measure']
    }
    estimators = df['estimator']
    accuracies = df['test_Accuracy']
    for key in scores.keys():
        if "test_" in key:
            scores[key] = [f"{scores[key].mean() * 100: .2f}%"]
        else:
            scores[key] = [f"{scores[key].mean(): .2f}"]
    return [pd.DataFrame(scores), estimators, accuracies]

def feat_extraction(estimators, avoid_scores = False):
    features_per_fold = {}
    fold_index = 0
    for estim in estimators:
        fold_index += 1
        feature = 0
        sel_features = {}
        feat_scores = []
        if not avoid_scores:
            feat_scores = estim['feat_sel'].scores_
        for selected in estim['feat_sel'].get_support():
            feature+=1
            if(selected == True):
                if len(feat_scores) > 0:
                    sel_features[ranks_df.columns[feature]] = [feat_scores[feature-1]]
                else:
                    sel_features[ranks_df.columns[feature]] = True
        features_per_fold[f"fold_{fold_index}"] = sel_features
    return pd.DataFrame(features_per_fold).transpose()

skf = StratifiedKFold(n_splits=10, shuffle=True, random_state=randrange(1,42))

# %% [markdown]
# ### ANALYSIS

# %%
smoted_pipeline = Pipeline([
    ('sampler', SMOTE(random_state=randrange(1,42))),
    ('clf', GaussianNB())
])
unsmoted_pipeline = Pipeline([
    ('clf', GaussianNB())
])
#######################################################
kbest_smoted = Pipeline([
    ('feat_sel', SelectKBest(chi2, k=12)),
    ('sampler', SMOTE(random_state=randrange(1,42))),
    ('clf', GaussianNB())
])
kbest_unsmoted = Pipeline([
    ('feat_sel', SelectKBest(chi2, k=12)),
    ('clf', GaussianNB())
])
########################################################
kbest_smoted_mutual = Pipeline([
    ('feat_sel', SelectKBest(mutual_info_classif, k=12)),
    ('sampler', SMOTE(random_state=randrange(1,42))),
    ('clf', GaussianNB())
])
kbest_unsmoted_mutual = Pipeline([
    ('feat_sel', SelectKBest(mutual_info_classif, k=12)),
    ('clf', GaussianNB())
])
########################################################
VT_smoted = Pipeline([
    ('feat_sel', VarianceThreshold(threshold=0.7)),
    ('sampler', SMOTE(random_state=randrange(1,42))),
    ('clf', GaussianNB())
])
VT_unsmoted = Pipeline([
    ('feat_sel', VarianceThreshold(threshold=0.7)),
    ('clf', GaussianNB())
])

metricsComparison = {}

# %% [markdown]
# ### SMOTE NO ATTRIBUT SELECTION

# %%
smoted_ = cross_validate(smoted_pipeline, X, y, scoring=scoring, cv=skf, n_jobs=8, return_estimator=True)
mean_smoted, smoted_estimators, accuracies = converter(smoted_)

metricsComparison['NB + SMOTE'] = [accuracies]

mean_smoted
# Out:
#   fit_time score_time test_Accuracy test_Precision test_Recall test_F-Measure
# 0     0.05       0.03        49.53%         49.61%      49.53%         48.39%

# %% [markdown]
# ### NO SMOTE NO ATTRIBUTE SELECTION

# %%
unsmoted_ = cross_validate(unsmoted_pipeline, X, y, scoring=scoring, cv=skf, n_jobs=8, return_estimator=True)
mean_unsmoted, unsmoted_estimators, accuracies = converter(unsmoted_)

metricsComparison['NB'] = [accuracies]

mean_unsmoted
# Out:
#   fit_time score_time test_Accuracy test_Precision test_Recall test_F-Measure
# 0     0.03       0.04        49.53%         49.61%      49.53%         48.39%

# %% [markdown]
# ### SMOTE KBEST SELECTION

# %%
kbest_smoted_ = cross_validate(kbest_smoted, X, y, scoring=scoring, cv=skf, n_jobs=8, return_estimator=True)

mean_kbest_smoted, kbest_smoted_estimators, accuracies = converter(kbest_smoted_)
    
kbest_features = feat_extraction(kbest_smoted_estimators)
kbest_features
# Out:
#                  conf_synergy          lift_synergy              levelSum  \
# fold_1   [8075052.2262648465]  [209666041.21608642]  [3049.3811836141135]
# fold_2    [8754173.153740823]  [228241073.64206237]   [3083.365805109797]
# fold_3    [8547483.360623756]  [223079836.61656144]  [3051.5169890991665]
# fold_4    [8395241.107442059]  [217701921.13713798]    [3051.63921576131]
# fold_5     [8874232.10094733]  [233627530.24617955]   [3065.212824721577]
# fold_6    [8100442.246420473]  [211635509.43471643]   [3074.904745704329]
# fold_7     [8436161.27234011]  [217882092.74294388]   [3067.403817081183]
# fold_8    [8646668.334578888]   [221611623.1146889]  [3055.4367082686626]
# fold_9    [8748486.558960492]  [231889521.57868445]   [3119.092212715952]
# fold_10   [8543816.900685994]  [220164561.56737024]   [3076.835769007508]
#
#              avgSpellDuration               totalHP              totalDMG  \
# fold_1    [531.4505804887946]  [103318.49522938734]   [21810.37084508276]
# fold_2     [464.226162108037]  [102342.14469008314]  [24073.314254392964]
# fold_3    [513.6988882863157]   [90870.27993146934]  [23601.848247513597]
# fold_4    [438.5518117979904]  [106533.59208289089]  [25294.793007166234]
# fold_5    [503.4377588414409]   [95026.17998385665]  [26302.427631537445]
# fold_6    [433.3600660819445]  [105418.91900609047]   [25411.57215520225]
# fold_7   [472.71193987958225]    [97567.8280242671]  [24287.566319733935]
# fold_8    [467.0052199597096]  [103106.84630589356]  [22991.042639179796]
# fold_9   [434.17288456964343]    [92094.2723843377]   [25466.61835702225]
# fold_10   [593.0788109333319]   [97116.32777807117]  [21948.519605790003]
#
#               totalUnitsCount              avgRange           commonLevel  \
# fold_1    [2021.196614146832]  [17069.765556724167]   [339.1058196383989]
# fold_2   [1972.2656157967072]   [18404.35087823187]   [331.9313912396284]
# fold_3    [1964.850895856663]  [15448.627184640452]   [364.8730939811495]
# fold_4   [1913.9054295942722]   [17300.64878502264]  [350.41359615861313]
# fold_5   [1987.5816720437126]   [16617.79112697936]   [381.1151171101002]
# fold_6   [1935.2780905958484]   [17568.03830741494]  [337.75718941337146]
# fold_7   [1917.2541771347987]   [18028.87408064611]   [347.8290158096921]
# fold_8    [1993.302958855599]  [17471.723112776213]  [377.15290643509286]
# fold_9   [1928.0958623133008]  [17697.544534082743]  [369.54962464503205]
# fold_10  [2078.7807521546097]   [16932.28650769668]  [378.20494536333194]
#
#                     rareLevel             epicLevel        legendaryLevel
# fold_1   [396.85044604395137]  [383.96128740973325]  [1170.6273736757257]
# fold_2   [423.96861575642237]   [379.9519888541917]  [1205.7211675391188]
# fold_3    [430.0165078984999]  [356.98228419930854]  [1182.6432905305899]
# fold_4    [416.9899197144093]  [356.85528517821626]  [1175.9462742082742]
# fold_5    [427.4452974790062]   [356.1581753744079]  [1203.9010396687338]
# fold_6    [421.0368753950985]  [365.75033692581087]  [1155.0767944345546]
# fold_7    [393.9058672265957]  [376.51723919455395]  [1154.0246602636153]
# fold_8   [396.33937301112934]   [386.6246847963707]   [1182.204274501119]
# fold_9    [417.3580137054488]  [348.97740000770295]  [1193.6617048408573]
# fold_10   [391.6732237476756]   [382.7353595587005]  [1218.7188686012337]

# %%
metricsComparison['NB + SMOTE + KBEST and chi2'] = [accuracies]

mean_kbest_smoted
# Out:
#   fit_time score_time test_Accuracy test_Precision test_Recall test_F-Measure
# 0     0.08       0.03        49.44%         49.48%      49.44%         48.33%

# %% [markdown]
# ### NO SMOTE KBEST SELECTION

# %%
kbest_unsmoted_scores = cross_validate(kbest_unsmoted, X, y, scoring=scoring, cv=skf, n_jobs=8, return_estimator=True)
mean_kbest_unsmoted, kbest_unsmoted_estimators, accuracies = converter(kbest_unsmoted_scores)

kbest_unsmoted_features = feat_extraction(kbest_unsmoted_estimators)

kbest_unsmoted_features
# Out:
#                  conf_synergy          lift_synergy              levelSum  \
# fold_1   [8075052.2262648465]  [209666041.21608642]  [3049.3811836141135]
# fold_2    [8754173.153740823]  [228241073.64206237]   [3083.365805109797]
# fold_3    [8547483.360623756]  [223079836.61656144]  [3051.5169890991665]
# fold_4    [8395241.107442059]  [217701921.13713798]    [3051.63921576131]
# fold_5     [8874232.10094733]  [233627530.24617955]   [3065.212824721577]
# fold_6    [8100442.246420473]  [211635509.43471643]   [3074.904745704329]
# fold_7     [8436161.27234011]  [217882092.74294388]   [3067.403817081183]
# fold_8    [8646668.334578888]   [221611623.1146889]  [3055.4367082686626]
# fold_9    [8748486.558960492]  [231889521.57868445]   [3119.092212715952]
# fold_10   [8543816.900685994]  [220164561.56737024]   [3076.835769007508]
#
#              avgSpellDuration               totalHP              totalDMG  \
# fold_1    [531.4505804887946]  [103318.49522938734]   [21810.37084508276]
# fold_2     [464.226162108037]  [102342.14469008314]  [24073.314254392964]
# fold_3    [513.6988882863157]   [90870.27993146934]  [23601.848247513597]
# fold_4    [438.5518117979904]  [106533.59208289089]  [25294.793007166234]
# fold_5    [503.4377588414409]   [95026.17998385665]  [26302.427631537445]
# fold_6    [433.3600660819445]  [105418.91900609047]   [25411.57215520225]
# fold_7   [472.71193987958225]    [97567.8280242671]  [24287.566319733935]
# fold_8    [467.0052199597096]  [103106.84630589356]  [22991.042639179796]
# fold_9   [434.17288456964343]    [92094.2723843377]   [25466.61835702225]
# fold_10   [593.0788109333319]   [97116.32777807117]  [21948.519605790003]
#
#               totalUnitsCount              avgRange           commonLevel  \
# fold_1    [2021.196614146832]  [17069.765556724167]   [339.1058196383989]
# fold_2   [1972.2656157967072]   [18404.35087823187]   [331.9313912396284]
# fold_3    [1964.850895856663]  [15448.627184640452]   [364.8730939811495]
# fold_4   [1913.9054295942722]   [17300.64878502264]  [350.41359615861313]
# fold_5   [1987.5816720437126]   [16617.79112697936]   [381.1151171101002]
# fold_6   [1935.2780905958484]   [17568.03830741494]  [337.75718941337146]
# fold_7   [1917.2541771347987]   [18028.87408064611]   [347.8290158096921]
# fold_8    [1993.302958855599]  [17471.723112776213]  [377.15290643509286]
# fold_9   [1928.0958623133008]  [17697.544534082743]  [369.54962464503205]
# fold_10  [2078.7807521546097]   [16932.28650769668]  [378.20494536333194]
#
#                     rareLevel             epicLevel        legendaryLevel
# fold_1   [396.85044604395137]  [383.96128740973325]  [1170.6273736757257]
# fold_2   [423.96861575642237]   [379.9519888541917]  [1205.7211675391188]
# fold_3    [430.0165078984999]  [356.98228419930854]  [1182.6432905305899]
# fold_4    [416.9899197144093]  [356.85528517821626]  [1175.9462742082742]
# fold_5    [427.4452974790062]   [356.1581753744079]  [1203.9010396687338]
# fold_6    [421.0368753950985]  [365.75033692581087]  [1155.0767944345546]
# fold_7    [393.9058672265957]  [376.51723919455395]  [1154.0246602636153]
# fold_8   [396.33937301112934]   [386.6246847963707]   [1182.204274501119]
# fold_9    [417.3580137054488]  [348.97740000770295]  [1193.6617048408573]
# fold_10   [391.6732237476756]   [382.7353595587005]  [1218.7188686012337]

# %%
metricsComparison['NB + KBEST and chi2'] = [accuracies]

mean_kbest_unsmoted
# Out:
#   fit_time score_time test_Accuracy test_Precision test_Recall test_F-Measure
# 0     0.07       0.02        49.44%         49.48%      49.44%         48.33%

# %% [markdown]
# ### KBEST SELECTOR WITH MUTUAL INFO CLASSIFIER

# %% [markdown]
# ###### SMOTED

# %%
kbest_smoted_mutual_ = cross_validate(kbest_smoted_mutual, X, y, scoring=scoring, cv=skf, n_jobs=8, return_estimator=True)
kbest_smoted_mutual_scores, kbest_smoted_mutual_estimators, accuracies = converter(kbest_smoted_mutual_)

kbest_smoted_mutual_features = feat_extraction(kbest_smoted_mutual_estimators)
kbest_smoted_mutual_features
# Out:
#                   conf_synergy           lift_synergy               levelSum  \
# fold_1    [0.1815881585050907]  [0.18229233381180898]  [0.33466802275781626]
# fold_2    [0.1822846956091233]   [0.1825528341112499]    [0.331745772186981]
# fold_3   [0.18182024908576122]  [0.17454751496141796]   [0.3421790094239774]
# fold_4   [0.16918227980423417]  [0.17997367782885787]   [0.3330388081400657]
# fold_5    [0.1769595608535688]   [0.1771870178360926]  [0.33770471170485084]
# fold_6   [0.16940400193575944]  [0.17690174960689609]   [0.3422926442417751]
# fold_7    [0.1740783911740007]   [0.1753680713104968]   [0.3404040552102061]
# fold_8    [0.1788186113318062]  [0.17573612358264534]   [0.3401715226743971]
# fold_9   [0.18446044716976306]   [0.1852490690003301]  [0.34592609364425075]
# fold_10   [0.1832468666043916]  [0.18330867651069704]  [0.33379540951321407]
#
#               avgSpellDuration                totalHP               totalDMG  \
# fold_1   [0.11073262451161003]  [0.20589210695746774]  [0.18057541618072115]
# fold_2   [0.10891443632097397]  [0.20107075901193938]   [0.1846104035917011]
# fold_3    [0.1012778236083891]  [0.20081222483229477]  [0.17844893353759872]
# fold_4   [0.10528878137229891]  [0.19635264707974387]  [0.18122393691911998]
# fold_5     [0.098407663244517]  [0.19635990575785778]  [0.17821827854788408]
# fold_6   [0.10801986065351588]  [0.20361954807913696]  [0.18393302699821978]
# fold_7    [0.1018285808222339]   [0.2018270458708349]  [0.17835096390608585]
# fold_8   [0.10740831618519464]  [0.20090101080128542]   [0.1855672827178796]
# fold_9   [0.10861918857599684]  [0.18957599345002651]  [0.17800637882468795]
# fold_10  [0.11792287355495112]  [0.20369196404443013]    [0.180087655295057]
#
#                          avgAS               avgRange            commonLevel  \
# fold_1   [0.11782368561868739]   [0.0839958767052098]  [0.19626827041750405]
# fold_2   [0.11537666133115443]  [0.09012089893282971]  [0.20457257392504702]
# fold_3   [0.11361412444659624]  [0.09541841345857671]   [0.1921253702255208]
# fold_4   [0.11853865360543248]  [0.08655843324005463]  [0.20019281716488435]
# fold_5   [0.11951365537965275]  [0.08432084310548582]  [0.19558474225434752]
# fold_6   [0.11297112976111312]   [0.1010227188843551]  [0.19549776572541377]
# fold_7   [0.10776139781583649]   [0.0940033228228736]  [0.19876924014646113]
# fold_8   [0.11420789280009203]  [0.08056335880137477]  [0.18753630901289453]
# fold_9   [0.12212074413388119]  [0.08723149232491512]  [0.20909779098407943]
# fold_10  [0.11413073231497006]  [0.08047640346654683]    [0.196077837961667]
#
#                      rareLevel              epicLevel         legendaryLevel
# fold_1   [0.23529146007760526]  [0.24980217340386512]  [0.31282372189310226]
# fold_2    [0.2246152787109259]   [0.2578363065211615]   [0.3167480540641494]
# fold_3   [0.23239680608392232]   [0.2464260872459325]  [0.32285375423421847]
# fold_4   [0.23585773504951524]   [0.2467845384447278]  [0.31978611766550413]
# fold_5   [0.23425576214985622]  [0.24251511857585584]   [0.3116555044474201]
# fold_6   [0.23094570252056057]  [0.24928893864639945]    [0.322935724771912]
# fold_7   [0.23278298712179168]   [0.2525213750254076]  [0.31584201076505947]
# fold_8   [0.23185820393946255]  [0.25005132635613614]  [0.32029884742683556]
# fold_9   [0.23579474308017212]   [0.2557174952050161]   [0.3153185030046386]
# fold_10  [0.23511425501689076]   [0.2485365350840978]   [0.3232989267845998]

# %%
metricsComparison['NB + SMOTE + KBEST and mutual_info'] = [accuracies]

kbest_smoted_mutual_scores
# Out:
#   fit_time score_time test_Accuracy test_Precision test_Recall test_F-Measure
# 0     3.86       0.02        48.95%         49.11%      48.95%         47.60%

# %% [markdown]
# ###### UNSMOTED

# %%
kbest_unsmoted_mutual_ = cross_validate(kbest_unsmoted_mutual, X, y, scoring=scoring, cv=skf, n_jobs=8, return_estimator=True)
kbest_unsmoted_mutual_scores, kbest_unsmoted_mutual_estimators, accuracies = converter(kbest_unsmoted_mutual_)

kbest_unsmoted_mutual_features = feat_extraction(kbest_unsmoted_mutual_estimators)
kbest_unsmoted_mutual_features
# Out:
#                   conf_synergy           lift_synergy               levelSum  \
# fold_1   [0.18779217300068263]   [0.1737398870772633]   [0.3398645874319668]
# fold_2   [0.18917195262526887]   [0.1864444933521643]   [0.3438938613116729]
# fold_3    [0.1731471922902721]  [0.17993469244285087]   [0.3425915093739744]
# fold_4   [0.17320612700495386]  [0.17887086137412989]  [0.33772727323159835]
# fold_5   [0.17103638684413203]  [0.17724012991634552]  [0.33653719734362064]
# fold_6   [0.17278091729129907]   [0.1789381639416152]  [0.33576168715258703]
# fold_7    [0.1707778969260425]  [0.18053541849994037]  [0.33863318926515484]
# fold_8   [0.17884704204296398]  [0.17390748629585695]   [0.3410698520323632]
# fold_9   [0.18124173210155403]  [0.18308014255080396]  [0.33602872051039445]
# fold_10   [0.1757215897547948]  [0.17671309617838227]   [0.3337308445889169]
#
#               avgSpellDuration                totalHP               totalDMG  \
# fold_1   [0.10906202967938294]  [0.20586673800870225]    [0.178437894803124]
# fold_2   [0.10558007876385211]   [0.2074790270084026]   [0.1837845263479423]
# fold_3   [0.11094200556352507]  [0.20518815762303655]  [0.18083483495625252]
# fold_4   [0.10322247137467278]  [0.20191337197757853]   [0.1889307884099689]
# fold_5   [0.10444226710059312]  [0.19877405305446572]   [0.1776454205389686]
# fold_6   [0.10452173822325639]    [0.204961614484942]  [0.18034693105463218]
# fold_7   [0.11007565906998962]  [0.19743391906745011]  [0.18531346121870862]
# fold_8   [0.10974886132762718]   [0.2023742795152641]   [0.1921463070399172]
# fold_9   [0.09115077782226488]  [0.19099147165708685]  [0.17901527288434527]
# fold_10  [0.10965384250537191]  [0.20270038988267403]   [0.1827806504351286]
#
#                          avgAS               avgRange            commonLevel  \
# fold_1   [0.12110258000492813]  [0.08381201427910812]  [0.20163087830014947]
# fold_2   [0.11907492213995097]  [0.08432183467873644]  [0.19549187306292093]
# fold_3   [0.11008484639501925]  [0.08564198381774446]    [0.195032757660353]
# fold_4   [0.11509937640677115]  [0.08695043300545247]  [0.19836374717959715]
# fold_5    [0.1123037854321478]  [0.09070368730862599]   [0.1945806060037929]
# fold_6   [0.11790248778414747]  [0.08826411338254192]  [0.20378787214037142]
# fold_7   [0.10755724296009994]  [0.08446763340071572]   [0.2071364574926704]
# fold_8    [0.1101873034716887]  [0.08821858864827403]  [0.19571598252193168]
# fold_9   [0.11466340152710908]  [0.09742106938979056]  [0.20352448262866285]
# fold_10  [0.10731687086497654]  [0.08552663851872477]  [0.18173935215863368]
#
#                      rareLevel              epicLevel         legendaryLevel
# fold_1   [0.23511154269882728]  [0.24532057707094967]    [0.312682612864422]
# fold_2     [0.235672857356803]   [0.2533440957848785]   [0.3269198218047764]
# fold_3   [0.22736397067132907]   [0.2474705795805534]  [0.31588219510257676]
# fold_4   [0.23649428431103647]   [0.2477860812402255]   [0.3177910197074123]
# fold_5    [0.2275116337405929]   [0.2467135590162819]  [0.32517491156557843]
# fold_6    [0.2215949556264767]   [0.2541898025741598]   [0.3191237640630815]
# fold_7   [0.23262903121244172]   [0.2514540634405682]   [0.3149835654330373]
# fold_8   [0.23129956361433957]   [0.2539626248188973]  [0.31928047320984865]
# fold_9   [0.23192403920790827]  [0.24441272205198894]  [0.32039564560758627]
# fold_10  [0.22815458358307872]  [0.24928407802199604]  [0.31829457080936474]

# %%
metricsComparison['NB + KBEST and mutual_info'] = [accuracies]

kbest_unsmoted_mutual_scores
# Out:
#   fit_time score_time test_Accuracy test_Precision test_Recall test_F-Measure
# 0     4.10       0.02        48.95%         49.11%      48.95%         47.60%

# %% [markdown]
# ### VARIANCE THRESHOLD SELECTION

# %% [markdown]
# ###### SMOTED

# %%
VT_smoted_ = cross_validate(VT_smoted, X, y, scoring=scoring, cv=skf, n_jobs=8, return_estimator=True)
VT_smoted_scores, VT_smoted_estimators, accuracies = converter(VT_smoted_)

VT_smoted_features = feat_extraction(VT_smoted_estimators, avoid_scores=True)
VT_smoted_features
# Out:
#         troop common  rare  epic legendary conf_synergy lift_synergy levelSum  \
# fold_1   True   True  True  True      True         True         True     True
# fold_2   True   True  True  True      True         True         True     True
# fold_3   True   True  True  True      True         True         True     True
# fold_4   True   True  True  True      True         True         True     True
# fold_5   True   True  True  True      True         True         True     True
# fold_6   True   True  True  True      True         True         True     True
# fold_7   True   True  True  True      True         True         True     True
# fold_8   True   True  True  True      True         True         True     True
# fold_9   True   True  True  True      True         True         True     True
# fold_10  True   True  True  True      True         True         True     True
#
#         avgSpeed avgSpellDuration  ... totalUnitsCount abilityCount avgRange  \
# fold_1      True             True  ...            True         True     True
# fold_2      True             True  ...            True         True     True
# fold_3      True             True  ...            True         True     True
# fold_4      True             True  ...            True         True     True
# fold_5      True             True  ...            True         True     True
# fold_6      True             True  ...            True         True     True
# fold_7      True             True  ...            True         True     True
# fold_8      True             True  ...            True         True     True
# fold_9      True             True  ...            True         True     True
# fold_10     True             True  ...            True         True     True
#
#         totalAirT totalProjectiles commonLevel rareLevel epicLevel  \
# fold_1       True             True        True      True      True
# fold_2       True             True        True      True      True
# fold_3       True             True        True      True      True
# fold_4       True             True        True      True      True
# fold_5       True             True        True      True      True
# fold_6       True             True        True      True      True
# fold_7       True             True        True      True      True
# fold_8       True             True        True      True      True
# fold_9       True             True        True      True      True
# fold_10      True             True        True      True      True
#
#         legendaryLevel spell
# fold_1            True   NaN
# fold_2            True   NaN
# fold_3            True  True
# fold_4            True  True
# fold_5            True  True
# fold_6            True  True
# fold_7            True  True
# fold_8            True  True
# fold_9            True  True
# fold_10           True   NaN
#
# [10 rows x 22 columns]

# %%
metricsComparison['NB + SMOTE + Variance Threshold'] = [accuracies]

VT_smoted_scores
# Out:
#   fit_time score_time test_Accuracy test_Precision test_Recall test_F-Measure
# 0     0.10       0.07        49.52%         49.61%      49.52%         48.38%

# %% [markdown]
# ###### UNSMOTED

# %%
VT_unsmoted_ = cross_validate(VT_unsmoted, X, y, scoring=scoring, cv=skf, n_jobs=8, return_estimator=True)
VT_unsmoted_scores, VT_unsmoted_estimators, accuracies = converter(VT_unsmoted_)

VT_unsmoted_features = feat_extraction(VT_unsmoted_estimators, avoid_scores=True)
VT_unsmoted_features
# Out:
#         troop common  rare  epic legendary conf_synergy lift_synergy levelSum  \
# fold_1   True   True  True  True      True         True         True     True
# fold_2   True   True  True  True      True         True         True     True
# fold_3   True   True  True  True      True         True         True     True
# fold_4   True   True  True  True      True         True         True     True
# fold_5   True   True  True  True      True         True         True     True
# fold_6   True   True  True  True      True         True         True     True
# fold_7   True   True  True  True      True         True         True     True
# fold_8   True   True  True  True      True         True         True     True
# fold_9   True   True  True  True      True         True         True     True
# fold_10  True   True  True  True      True         True         True     True
#
#         avgSpeed avgSpellDuration  ... totalUnitsCount abilityCount avgRange  \
# fold_1      True             True  ...            True         True     True
# fold_2      True             True  ...            True         True     True
# fold_3      True             True  ...            True         True     True
# fold_4      True             True  ...            True         True     True
# fold_5      True             True  ...            True         True     True
# fold_6      True             True  ...            True         True     True
# fold_7      True             True  ...            True         True     True
# fold_8      True             True  ...            True         True     True
# fold_9      True             True  ...            True         True     True
# fold_10     True             True  ...            True         True     True
#
#         totalAirT totalProjectiles commonLevel rareLevel epicLevel  \
# fold_1       True             True        True      True      True
# fold_2       True             True        True      True      True
# fold_3       True             True        True      True      True
# fold_4       True             True        True      True      True
# fold_5       True             True        True      True      True
# fold_6       True             True        True      True      True
# fold_7       True             True        True      True      True
# fold_8       True             True        True      True      True
# fold_9       True             True        True      True      True
# fold_10      True             True        True      True      True
#
#         legendaryLevel spell
# fold_1            True   NaN
# fold_2            True   NaN
# fold_3            True  True
# fold_4            True  True
# fold_5            True  True
# fold_6            True  True
# fold_7            True  True
# fold_8            True  True
# fold_9            True  True
# fold_10           True   NaN
#
# [10 rows x 22 columns]

# %%
metricsComparison['NB + Variance Threshold'] = [accuracies]

VT_unsmoted_scores
# Out:
#   fit_time score_time test_Accuracy test_Precision test_Recall test_F-Measure
# 0     0.07       0.03        49.52%         49.61%      49.52%         48.38%

# %% [markdown]
# ### BOX PLOT OF RESULTS

# %%
final_dict = {}
for metric in metricsComparison:
    for m in metricsComparison[metric]:
        final_dict[metric] = m
mc_df = pd.DataFrame(final_dict)
mc_df.plot.box(return_type='axes', figsize=(40,20), grid=True, fontsize=14)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## ANALYSIS WITHOUT LEVEL

# %%
ranks_nolevel_df = ranks_df.drop(["levelSum"], axis="columns")
ranks_nolevel_df
# Out:
#              rank  troop  building  spell  common  rare  epic  legendary  \
# 0      Challenger      5         0      3       1     1     4          2
# 1      Challenger      5         1      2       1     2     3          2
# 2          Master      7         1      0       3     3     2          0
# 3      Challenger      7         0      1       4     2     1          1
# 4      Challenger      5         0      3       1     1     5          1
# ...           ...    ...       ...    ...     ...   ...   ...        ...
# 10495    Champion      5         1      2       0     4     4          0
# 10496    Champion      6         0      2       1     2     3          2
# 10497    Champion      6         0      2       2     1     2          3
# 10498    Champion      5         1      2       4     2     1          1
# 10499    Champion      6         0      2       0     1     6          1
#
#        elixir  conf_synergy  ...  avgRange  totalGroundT  totalAirT  \
# 0       3.375   2865.990531  ...   2712.50             8          3
# 1       4.250   3980.516610  ...   2018.75             7          5
# 2       4.875      0.000000  ...   1925.00             8          2
# 3       3.750   1389.332225  ...   4175.00             8          6
# 4       4.500   4049.013035  ...   3056.25             8          4
# ...       ...           ...  ...       ...           ...        ...
# 10495   3.625   2191.588585  ...   2800.00             8          4
# 10496   4.000  26569.219252  ...   2581.25             8          4
# 10497   3.750   2671.736517  ...   2275.00             8          4
# 10498   3.125  14365.842341  ...   3868.75             8          3
# 10499   4.625   3303.615309  ...   3006.25             8          5
#
#        totalBuildingT  totalBuffCount  totalProjectiles  commonLevel  \
# 0                   0               0                 3        11.00
# 1                   1               2                 0        13.00
# 2                   2               0                 0        13.00
# 3                   0               0                 1        13.00
# 4                   1               2                 1        13.00
# ...               ...             ...               ...          ...
# 10495               1               1                 1         0.00
# 10496               1               2                 0        13.00
# 10497               1               1                 1        13.00
# 10498               1               0                 2        16.25
# 10499               1               0                 2         0.00
#
#        rareLevel  epicLevel  legendaryLevel
# 0           11.0      10.25            10.5
# 1           13.0      13.00            13.0
# 2           13.0      13.00             0.0
# 3           13.0      13.00            13.0
# 4           13.0      13.00            13.0
# ...          ...        ...             ...
# 10495       13.0      13.00             0.0
# 10496       13.0      13.00            13.0
# 10497       13.0      13.00            13.0
# 10498       13.0       0.00            13.0
# 10499       13.0      13.00            13.0
#
# [10500 rows x 28 columns]

# %%
y = np.array([x for x in ranks_nolevel_df["rank"]])
X = np.array([x for x in ranks_nolevel_df.drop(["rank"], axis="columns").values])
metricsComparison = {}

# %% [markdown]
# ### SMOTE NO ATTRIBUT SELECTION

# %%
smoted_ = cross_validate(smoted_pipeline, X, y, scoring=scoring, cv=skf, n_jobs=8, return_estimator=True)
mean_smoted, smoted_estimators, accuracies = converter(smoted_)

metricsComparison['NB+SMOTE'] = [accuracies]

mean_smoted
# Out:
#   fit_time score_time test_Accuracy test_Precision test_Recall test_F-Measure
# 0     0.22       0.11        42.23%         44.94%      42.23%         38.43%

# %% [markdown]
# ### NO SMOTE NO ATTRIBUTE SELECTION

# %%
unsmoted_ = cross_validate(unsmoted_pipeline, X, y, scoring=scoring, cv=skf, n_jobs=8, return_estimator=True)
mean_unsmoted, unsmoted_estimators, accuracies = converter(unsmoted_)

metricsComparison['NB'] = [accuracies]

mean_unsmoted
# Out:
#   fit_time score_time test_Accuracy test_Precision test_Recall test_F-Measure
# 0     0.06       0.03        42.23%         44.94%      42.23%         38.43%

# %% [markdown]
# ### SMOTE KBEST SELECTION

# %%
kbest_smoted_ = cross_validate(kbest_smoted, X, y, scoring=scoring, cv=skf, n_jobs=8, return_estimator=True)

mean_kbest_smoted, kbest_smoted_estimators, accuracies = converter(kbest_smoted_)
    
kbest_features = feat_extraction(kbest_smoted_estimators)
kbest_features
# Out:
#                         spell          conf_synergy          lift_synergy  \
# fold_1   [292.46406633906633]  [8075052.2262648465]  [209666041.21608642]
# fold_2    [294.4828115408226]   [8754173.153740823]  [228241073.64206237]
# fold_3   [291.98764549724325]   [8547483.360623756]  [223079836.61656144]
# fold_4   [281.20379921360365]   [8395241.107442059]  [217701921.13713798]
# fold_5     [286.180393362016]    [8874232.10094733]  [233627530.24617955]
# fold_6   [296.38576243488916]   [8100442.246420473]  [211635509.43471643]
# fold_7    [304.5958732271773]    [8436161.27234011]  [217882092.74294388]
# fold_8   [292.37964194373404]   [8646668.334578888]   [221611623.1146889]
# fold_9    [304.2233705105904]   [8748486.558960492]  [231889521.57868445]
# fold_10   [298.8227880526666]   [8543816.900685994]  [220164561.56737024]
#
#                      avgSpeed      avgSpellDuration               totalHP  \
# fold_1    [531.4505804887946]  [103318.49522938734]   [21810.37084508276]
# fold_2     [464.226162108037]  [102342.14469008314]  [24073.314254392964]
# fold_3    [513.6988882863157]   [90870.27993146934]  [23601.848247513597]
# fold_4    [438.5518117979904]  [106533.59208289089]  [25294.793007166234]
# fold_5    [503.4377588414409]   [95026.17998385665]  [26302.427631537445]
# fold_6    [433.3600660819445]  [105418.91900609047]   [25411.57215520225]
# fold_7   [472.71193987958225]    [97567.8280242671]  [24287.566319733935]
# fold_8    [467.0052199597096]  [103106.84630589356]  [22991.042639179796]
# fold_9   [434.17288456964343]    [92094.2723843377]   [25466.61835702225]
# fold_10   [593.0788109333319]   [97116.32777807117]  [21948.519605790003]
#
#                         avgAS          abilityCount      totalProjectiles  \
# fold_1    [2021.196614146832]  [17069.765556724167]   [339.1058196383989]
# fold_2   [1972.2656157967072]   [18404.35087823187]   [331.9313912396284]
# fold_3    [1964.850895856663]  [15448.627184640452]   [364.8730939811495]
# fold_4   [1913.9054295942722]   [17300.64878502264]  [350.41359615861313]
# fold_5   [1987.5816720437126]   [16617.79112697936]   [381.1151171101002]
# fold_6   [1935.2780905958484]   [17568.03830741494]  [337.75718941337146]
# fold_7   [1917.2541771347987]   [18028.87408064611]   [347.8290158096921]
# fold_8    [1993.302958855599]  [17471.723112776213]  [377.15290643509286]
# fold_9   [1928.0958623133008]  [17697.544534082743]  [369.54962464503205]
# fold_10  [2078.7807521546097]   [16932.28650769668]  [378.20494536333194]
#
#                   commonLevel             rareLevel             epicLevel
# fold_1   [396.85044604395137]  [383.96128740973325]  [1170.6273736757257]
# fold_2   [423.96861575642237]   [379.9519888541917]  [1205.7211675391188]
# fold_3    [430.0165078984999]  [356.98228419930854]  [1182.6432905305899]
# fold_4    [416.9899197144093]  [356.85528517821626]  [1175.9462742082742]
# fold_5    [427.4452974790062]   [356.1581753744079]  [1203.9010396687338]
# fold_6    [421.0368753950985]  [365.75033692581087]  [1155.0767944345546]
# fold_7    [393.9058672265957]  [376.51723919455395]  [1154.0246602636153]
# fold_8   [396.33937301112934]   [386.6246847963707]   [1182.204274501119]
# fold_9    [417.3580137054488]  [348.97740000770295]  [1193.6617048408573]
# fold_10   [391.6732237476756]   [382.7353595587005]  [1218.7188686012337]

# %%
metricsComparison['NB+SMOTE+KBEST and chi2'] = [accuracies]

mean_kbest_smoted
# Out:
#   fit_time score_time test_Accuracy test_Precision test_Recall test_F-Measure
# 0     0.11       0.04        42.35%         44.90%      42.35%         38.71%

# %% [markdown]
# ### NO SMOTE KBEST SELECTION

# %%
kbest_unsmoted_scores = cross_validate(kbest_unsmoted, X, y, scoring=scoring, cv=skf, n_jobs=8, return_estimator=True)
mean_kbest_unsmoted, kbest_unsmoted_estimators, accuracies = converter(kbest_unsmoted_scores)

kbest_unsmoted_features = feat_extraction(kbest_unsmoted_estimators)

kbest_unsmoted_features
# Out:
#                         spell          conf_synergy          lift_synergy  \
# fold_1   [292.46406633906633]  [8075052.2262648465]  [209666041.21608642]
# fold_2    [294.4828115408226]   [8754173.153740823]  [228241073.64206237]
# fold_3   [291.98764549724325]   [8547483.360623756]  [223079836.61656144]
# fold_4   [281.20379921360365]   [8395241.107442059]  [217701921.13713798]
# fold_5     [286.180393362016]    [8874232.10094733]  [233627530.24617955]
# fold_6   [296.38576243488916]   [8100442.246420473]  [211635509.43471643]
# fold_7    [304.5958732271773]    [8436161.27234011]  [217882092.74294388]
# fold_8   [292.37964194373404]   [8646668.334578888]   [221611623.1146889]
# fold_9    [304.2233705105904]   [8748486.558960492]  [231889521.57868445]
# fold_10   [298.8227880526666]   [8543816.900685994]  [220164561.56737024]
#
#                      avgSpeed      avgSpellDuration               totalHP  \
# fold_1    [531.4505804887946]  [103318.49522938734]   [21810.37084508276]
# fold_2     [464.226162108037]  [102342.14469008314]  [24073.314254392964]
# fold_3    [513.6988882863157]   [90870.27993146934]  [23601.848247513597]
# fold_4    [438.5518117979904]  [106533.59208289089]  [25294.793007166234]
# fold_5    [503.4377588414409]   [95026.17998385665]  [26302.427631537445]
# fold_6    [433.3600660819445]  [105418.91900609047]   [25411.57215520225]
# fold_7   [472.71193987958225]    [97567.8280242671]  [24287.566319733935]
# fold_8    [467.0052199597096]  [103106.84630589356]  [22991.042639179796]
# fold_9   [434.17288456964343]    [92094.2723843377]   [25466.61835702225]
# fold_10   [593.0788109333319]   [97116.32777807117]  [21948.519605790003]
#
#                         avgAS          abilityCount      totalProjectiles  \
# fold_1    [2021.196614146832]  [17069.765556724167]   [339.1058196383989]
# fold_2   [1972.2656157967072]   [18404.35087823187]   [331.9313912396284]
# fold_3    [1964.850895856663]  [15448.627184640452]   [364.8730939811495]
# fold_4   [1913.9054295942722]   [17300.64878502264]  [350.41359615861313]
# fold_5   [1987.5816720437126]   [16617.79112697936]   [381.1151171101002]
# fold_6   [1935.2780905958484]   [17568.03830741494]  [337.75718941337146]
# fold_7   [1917.2541771347987]   [18028.87408064611]   [347.8290158096921]
# fold_8    [1993.302958855599]  [17471.723112776213]  [377.15290643509286]
# fold_9   [1928.0958623133008]  [17697.544534082743]  [369.54962464503205]
# fold_10  [2078.7807521546097]   [16932.28650769668]  [378.20494536333194]
#
#                   commonLevel             rareLevel             epicLevel
# fold_1   [396.85044604395137]  [383.96128740973325]  [1170.6273736757257]
# fold_2   [423.96861575642237]   [379.9519888541917]  [1205.7211675391188]
# fold_3    [430.0165078984999]  [356.98228419930854]  [1182.6432905305899]
# fold_4    [416.9899197144093]  [356.85528517821626]  [1175.9462742082742]
# fold_5    [427.4452974790062]   [356.1581753744079]  [1203.9010396687338]
# fold_6    [421.0368753950985]  [365.75033692581087]  [1155.0767944345546]
# fold_7    [393.9058672265957]  [376.51723919455395]  [1154.0246602636153]
# fold_8   [396.33937301112934]   [386.6246847963707]   [1182.204274501119]
# fold_9    [417.3580137054488]  [348.97740000770295]  [1193.6617048408573]
# fold_10   [391.6732237476756]   [382.7353595587005]  [1218.7188686012337]

# %%
metricsComparison['NB+KBEST and chi2'] = [accuracies]

mean_kbest_unsmoted
# Out:
#   fit_time score_time test_Accuracy test_Precision test_Recall test_F-Measure
# 0     0.05       0.03        42.35%         44.90%      42.35%         38.71%

# %% [markdown]
# ### KBEST SELECTOR WITH MUTUAL INFO CLASSIFIER

# %% [markdown]
# ###### SMOTED

# %%
kbest_smoted_mutual_ = cross_validate(kbest_smoted_mutual, X, y, scoring=scoring, cv=skf, n_jobs=8, return_estimator=True)
kbest_smoted_mutual_scores, kbest_smoted_mutual_estimators, accuracies = converter(kbest_smoted_mutual_)

kbest_smoted_mutual_features = feat_extraction(kbest_smoted_mutual_estimators)
kbest_smoted_mutual_features
# Out:
#                   conf_synergy           lift_synergy               levelSum  \
# fold_1   [0.18842129166536914]   [0.1652261849895167]  [0.07638603606660288]
# fold_2   [0.17979994695853518]  [0.18653771496388605]                    NaN
# fold_3   [0.17691731167341906]   [0.1787620211456422]  [0.08441393668447073]
# fold_4   [0.17139297084999328]   [0.1745550952522097]                    NaN
# fold_5   [0.17937483825796785]  [0.17416751428368582]   [0.0738721563586795]
# fold_6   [0.17651740424113238]  [0.17066976306399684]   [0.0663848849079669]
# fold_7   [0.17639199314692422]   [0.1739970098992114]  [0.09220102601181024]
# fold_8    [0.1877031963352831]  [0.17172237863404782]  [0.07797431288583145]
# fold_9   [0.18174282998305502]  [0.18275232554108545]  [0.06927505488342978]
# fold_10   [0.1704866850776714]   [0.1816029504561869]  [0.07626345579025573]
#
#                       avgSpeed       avgSpellDuration                totalHP  \
# fold_1   [0.10855825019182341]  [0.20450583471822092]   [0.1821834017218904]
# fold_2   [0.11117881783861616]  [0.20187874657267035]  [0.18537914627735486]
# fold_3   [0.10287519414436508]   [0.2015903045910361]  [0.18492307267832886]
# fold_4   [0.11189895724761478]   [0.2023060714906677]  [0.18380848567373342]
# fold_5     [0.105349351759634]  [0.19860598390513395]  [0.17884747838219783]
# fold_6   [0.10877817928460809]  [0.20477354808994108]  [0.17537339122300066]
# fold_7   [0.11033166350657253]   [0.2006930175060615]  [0.17806452896043878]
# fold_8    [0.1038720353204563]   [0.1992013704069724]  [0.18578703415923403]
# fold_9   [0.10304785205955813]  [0.19196462777649836]  [0.18239601564990005]
# fold_10   [0.1012960660976161]  [0.20029896448563078]   [0.1809139775489117]
#
#                       totalDMG           abilityCount       totalProjectiles  \
# fold_1   [0.11279489363320572]   [0.0896724450659494]  [0.19067043080822876]
# fold_2   [0.11038612221684962]  [0.08567708350485281]  [0.20521641827381476]
# fold_3   [0.11486360653503547]  [0.09060763394565052]   [0.2080233896366266]
# fold_4   [0.11171162929609624]  [0.07683985344532474]   [0.2068053497796507]
# fold_5   [0.10440320758664479]  [0.08669051419131679]   [0.2069827885601192]
# fold_6   [0.11843176819895396]  [0.08545957937884552]  [0.20732468718865094]
# fold_7   [0.11781058964899782]  [0.08578069064702398]  [0.19657144107719215]
# fold_8   [0.11009449291034068]  [0.09254246124511423]  [0.19263982563116855]
# fold_9   [0.11833511106092698]  [0.09296862167743636]   [0.2094135749031305]
# fold_10  [0.11610845985055951]  [0.09384795245484323]  [0.18763366660465253]
#
#                    commonLevel              rareLevel              epicLevel  \
# fold_1   [0.23855038820663887]   [0.2563244010513106]  [0.31789844011833757]
# fold_2    [0.2291480393721017]  [0.24399351756996523]    [0.323592504442352]
# fold_3    [0.2255386085314519]  [0.26139784319875536]  [0.32427590403196804]
# fold_4   [0.23654169083015697]  [0.24779767902972494]  [0.31480440339889837]
# fold_5   [0.23451797625450999]  [0.24686681278874456]   [0.3206700076135627]
# fold_6    [0.2304789497464761]  [0.24594195031118726]   [0.3233563690468608]
# fold_7   [0.23160501097976782]  [0.25072636276497384]   [0.3207547344251507]
# fold_8   [0.23149348542147652]  [0.25215288905628097]  [0.31630213440442545]
# fold_9   [0.22928344894478814]  [0.23764173651088916]  [0.31531270297728353]
# fold_10  [0.22095284047913455]  [0.24902291860016335]  [0.31489970621064156]
#
#                          spell                  troop
# fold_1                     NaN                    NaN
# fold_2   [0.06910184123221663]                    NaN
# fold_3                     NaN                    NaN
# fold_4                     NaN  [0.06597248165052538]
# fold_5                     NaN                    NaN
# fold_6                     NaN                    NaN
# fold_7                     NaN                    NaN
# fold_8                     NaN                    NaN
# fold_9                     NaN                    NaN
# fold_10                    NaN                    NaN

# %%
metricsComparison['NB+SMOTE+KBest and mutual info'] = [accuracies]

kbest_smoted_mutual_scores
# Out:
#   fit_time score_time test_Accuracy test_Precision test_Recall test_F-Measure
# 0     3.72       0.02        41.89%         44.79%      41.89%         37.79%

# %% [markdown]
# ###### UNSMOTED

# %%
kbest_unsmoted_mutual_ = cross_validate(kbest_unsmoted_mutual, X, y, scoring=scoring, cv=skf, n_jobs=8, return_estimator=True)
kbest_unsmoted_mutual_scores, kbest_unsmoted_mutual_estimators, accuracies = converter(kbest_unsmoted_mutual_)

kbest_unsmoted_mutual_features = feat_extraction(kbest_unsmoted_mutual_estimators)
kbest_unsmoted_mutual_features
# Out:
#                   conf_synergy           lift_synergy               levelSum  \
# fold_1   [0.18332522514308836]   [0.1786991923125254]  [0.07670323825789227]
# fold_2    [0.1766327522411424]   [0.1850735832744521]  [0.07917584389331123]
# fold_3    [0.1821491974278926]  [0.18257251772108418]  [0.07527597479336623]
# fold_4    [0.1696085736450299]   [0.1727440303026293]   [0.0803809253917005]
# fold_5    [0.1798134532423632]  [0.17260419651613668]   [0.0690321758347201]
# fold_6   [0.16990419594077943]   [0.1836304540266216]  [0.08254204136560817]
# fold_7   [0.18802437453622378]  [0.18048454589404228]  [0.08245999298845863]
# fold_8   [0.17798275509622763]  [0.17931616754792934]  [0.07788032501219089]
# fold_9    [0.1811629998632256]  [0.18330678568643588]  [0.07500151897990781]
# fold_10   [0.1769865974790239]  [0.18065995311646388]  [0.06970274457398085]
#
#                       avgSpeed       avgSpellDuration                totalHP  \
# fold_1    [0.1107116758101363]  [0.20327929700632752]  [0.18121159510499574]
# fold_2   [0.10808719483520202]  [0.20502537861930503]   [0.1851011438137724]
# fold_3   [0.09855612074703424]  [0.20377941498020524]    [0.180793474050714]
# fold_4   [0.09393560319224914]   [0.1989123085215545]  [0.18531766756892587]
# fold_5   [0.10589766547569912]  [0.20011392235471326]   [0.1785088744082941]
# fold_6   [0.10990851337123653]  [0.20497313466294353]  [0.18134724785521628]
# fold_7    [0.1082212763303978]  [0.20104827452836838]   [0.1744555494571307]
# fold_8   [0.10932452691938233]  [0.20439235038172665]   [0.1891581376861362]
# fold_9   [0.12296295030186988]  [0.18858492892514178]  [0.17795351286676064]
# fold_10   [0.1202348861660476]   [0.2035014465297107]  [0.17822916760582563]
#
#                       totalDMG           abilityCount       totalProjectiles  \
# fold_1   [0.11683040087628638]  [0.08951060302436287]  [0.20165140465421394]
# fold_2   [0.11331146942996351]  [0.09667806264108281]   [0.2004138291816553]
# fold_3   [0.12243204024549237]  [0.09362912327456407]  [0.20161426204213573]
# fold_4   [0.12278584608890286]   [0.0909186475642636]  [0.19981259978278576]
# fold_5   [0.10519994345789185]   [0.0909954343510877]   [0.2010763315293158]
# fold_6   [0.11555641459577437]  [0.08639385736922622]  [0.19367545295817368]
# fold_7   [0.10915363926761179]  [0.09438966924312142]   [0.1896273111770146]
# fold_8   [0.11913961106522608]  [0.08801653597420622]  [0.20675183203041425]
# fold_9    [0.1195655535955793]  [0.09498683408986697]  [0.19801819498229856]
# fold_10  [0.11489859156640647]  [0.09575324585662703]  [0.20183966479810955]
#
#                    commonLevel              rareLevel              epicLevel
# fold_1   [0.22560407987183684]  [0.25432100652290024]  [0.31772186383938994]
# fold_2   [0.24217465710745123]  [0.24312548483269159]   [0.3159947031554091]
# fold_3    [0.2239410481432138]  [0.25233192095744683]  [0.32301569899779325]
# fold_4     [0.233447709301702]   [0.2502236222008294]  [0.32346148464698254]
# fold_5    [0.2358929729332957]  [0.24595883372582805]  [0.32430530533296387]
# fold_6   [0.23840836601985504]  [0.25088113491951214]  [0.32749239038933053]
# fold_7   [0.24027684039698083]  [0.25138783827447897]  [0.32027000984772536]
# fold_8   [0.23166647594174328]   [0.2517676238277795]  [0.32091683563162343]
# fold_9   [0.22685298874430915]   [0.2546945650722532]   [0.3274858943369987]
# fold_10  [0.22948637848792308]  [0.24813886664077756]    [0.310440116820637]

# %%
metricsComparison['NB+KBest and mutual info'] = [accuracies]

kbest_unsmoted_mutual_scores
# Out:
#   fit_time score_time test_Accuracy test_Precision test_Recall test_F-Measure
# 0     3.64       0.02        41.86%         44.82%      41.86%         37.72%

# %% [markdown]
# ### VARIANCE THRESHOLD SELECTION

# %% [markdown]
# ###### SMOTED

# %%
VT_smoted_ = cross_validate(VT_smoted, X, y, scoring=scoring, cv=skf, n_jobs=8, return_estimator=True)
VT_smoted_scores, VT_smoted_estimators, accuracies = converter(VT_smoted_)

VT_smoted_features = feat_extraction(VT_smoted_estimators, avoid_scores=True)
VT_smoted_features
# Out:
#         troop common  rare  epic legendary conf_synergy lift_synergy levelSum  \
# fold_1   True   True  True  True      True         True         True     True
# fold_2   True   True  True  True      True         True         True     True
# fold_3   True   True  True  True      True         True         True     True
# fold_4   True   True  True  True      True         True         True     True
# fold_5   True   True  True  True      True         True         True     True
# fold_6   True   True  True  True      True         True         True     True
# fold_7   True   True  True  True      True         True         True     True
# fold_8   True   True  True  True      True         True         True     True
# fold_9   True   True  True  True      True         True         True     True
# fold_10  True   True  True  True      True         True         True     True
#
#         avgSpeed avgSpellDuration  ... avgAS totalUnitsCount abilityCount  \
# fold_1      True             True  ...  True            True         True
# fold_2      True             True  ...  True            True         True
# fold_3      True             True  ...  True            True         True
# fold_4      True             True  ...  True            True         True
# fold_5      True             True  ...  True            True         True
# fold_6      True             True  ...  True            True         True
# fold_7      True             True  ...  True            True         True
# fold_8      True             True  ...  True            True         True
# fold_9      True             True  ...  True            True         True
# fold_10     True             True  ...  True            True         True
#
#         totalGroundT totalBuffCount totalProjectiles commonLevel rareLevel  \
# fold_1          True           True             True        True      True
# fold_2          True           True             True        True      True
# fold_3          True           True             True        True      True
# fold_4          True           True             True        True      True
# fold_5          True           True             True        True      True
# fold_6          True           True             True        True      True
# fold_7          True           True             True        True      True
# fold_8          True           True             True        True      True
# fold_9          True           True             True        True      True
# fold_10         True           True             True        True      True
#
#         epicLevel spell
# fold_1       True   NaN
# fold_2       True   NaN
# fold_3       True  True
# fold_4       True  True
# fold_5       True  True
# fold_6       True  True
# fold_7       True  True
# fold_8       True  True
# fold_9       True  True
# fold_10      True   NaN
#
# [10 rows x 21 columns]

# %%
metricsComparison['NB+SMOTE+VT'] = [accuracies]

VT_smoted_scores
# Out:
#   fit_time score_time test_Accuracy test_Precision test_Recall test_F-Measure
# 0     0.09       0.07        42.22%         44.93%      42.22%         38.41%

# %% [markdown]
# ###### UNSMOTED

# %%
VT_unsmoted_ = cross_validate(VT_unsmoted, X, y, scoring=scoring, cv=skf, n_jobs=8, return_estimator=True)
VT_unsmoted_scores, VT_unsmoted_estimators, accuracies = converter(VT_unsmoted_)

VT_unsmoted_features = feat_extraction(VT_unsmoted_estimators, avoid_scores=True)
VT_unsmoted_features
# Out:
#         troop common  rare  epic legendary conf_synergy lift_synergy levelSum  \
# fold_1   True   True  True  True      True         True         True     True
# fold_2   True   True  True  True      True         True         True     True
# fold_3   True   True  True  True      True         True         True     True
# fold_4   True   True  True  True      True         True         True     True
# fold_5   True   True  True  True      True         True         True     True
# fold_6   True   True  True  True      True         True         True     True
# fold_7   True   True  True  True      True         True         True     True
# fold_8   True   True  True  True      True         True         True     True
# fold_9   True   True  True  True      True         True         True     True
# fold_10  True   True  True  True      True         True         True     True
#
#         avgSpeed avgSpellDuration  ... avgAS totalUnitsCount abilityCount  \
# fold_1      True             True  ...  True            True         True
# fold_2      True             True  ...  True            True         True
# fold_3      True             True  ...  True            True         True
# fold_4      True             True  ...  True            True         True
# fold_5      True             True  ...  True            True         True
# fold_6      True             True  ...  True            True         True
# fold_7      True             True  ...  True            True         True
# fold_8      True             True  ...  True            True         True
# fold_9      True             True  ...  True            True         True
# fold_10     True             True  ...  True            True         True
#
#         totalGroundT totalBuffCount totalProjectiles commonLevel rareLevel  \
# fold_1          True           True             True        True      True
# fold_2          True           True             True        True      True
# fold_3          True           True             True        True      True
# fold_4          True           True             True        True      True
# fold_5          True           True             True        True      True
# fold_6          True           True             True        True      True
# fold_7          True           True             True        True      True
# fold_8          True           True             True        True      True
# fold_9          True           True             True        True      True
# fold_10         True           True             True        True      True
#
#         epicLevel spell
# fold_1       True   NaN
# fold_2       True   NaN
# fold_3       True  True
# fold_4       True  True
# fold_5       True  True
# fold_6       True  True
# fold_7       True  True
# fold_8       True  True
# fold_9       True  True
# fold_10      True   NaN
#
# [10 rows x 21 columns]

# %%
metricsComparison['NB+VT'] = [accuracies]

VT_unsmoted_scores
# Out:
#   fit_time score_time test_Accuracy test_Precision test_Recall test_F-Measure
# 0     0.07       0.04        42.22%         44.93%      42.22%         38.41%

# %% [markdown]
# ### BOX PLOT OF RESULTS

# %%
final_dict = {}
for metric in metricsComparison:
    for m in metricsComparison[metric]:
        final_dict[metric] = m
mc_df = pd.DataFrame(final_dict)
mc_df.plot.box(return_type='axes', figsize=(40,20), grid=True, fontsize=14)
# Out:
# <AxesSubplot:>
