# %% [markdown]
# ## ANALYSIS WITH LEVEL

# %%
import pandas as pd
import numpy as np

ranks_df = pd.read_csv("../csv_sources/leveled_for_rarity.csv").drop(["index", "crowns"], axis="columns")
print("---------------------------------------------------")
print(ranks_df[["rank", "troop"]].groupby("rank").mean())
print(ranks_df[["rank", "troop"]].groupby("rank").std())
print("---------------------------------------------------")
print("---------------------------------------------------")
print(ranks_df[["rank", "building"]].groupby("rank").mean())
print(ranks_df[["rank", "building"]].groupby("rank").std())
print("---------------------------------------------------")
print("---------------------------------------------------")
print(ranks_df[["rank", "spell"]].groupby("rank").mean())
print(ranks_df[["rank", "spell"]].groupby("rank").std())
print("---------------------------------------------------")
print("---------------------------------------------------")
print(ranks_df[["rank", "common"]].groupby("rank").mean())
print(ranks_df[["rank", "common"]].groupby("rank").std())
print("---------------------------------------------------")
print("---------------------------------------------------")
print(ranks_df[["rank", "rare"]].groupby("rank").mean())
print(ranks_df[["rank", "rare"]].groupby("rank").std())
print("---------------------------------------------------")
print("---------------------------------------------------")
print(ranks_df[["rank", "epic"]].groupby("rank").mean())
print(ranks_df[["rank", "epic"]].groupby("rank").std())
print("---------------------------------------------------")
print("---------------------------------------------------")
print(ranks_df[["rank", "legendary"]].groupby("rank").mean())
print(ranks_df[["rank", "legendary"]].groupby("rank").std())
print("---------------------------------------------------")
print("---------------------------------------------------")
print(ranks_df[["rank", "elixir"]].groupby("rank").mean())
print(ranks_df[["rank", "elixir"]].groupby("rank").std())
print("---------------------------------------------------")
print("---------------------------------------------------")
print(ranks_df[["rank", "conf_synergy"]].groupby("rank").mean())
print(ranks_df[["rank", "conf_synergy"]].groupby("rank").std())
print("---------------------------------------------------")
print("---------------------------------------------------")
print(ranks_df[["rank", "lift_synergy"]].groupby("rank").mean())
print(ranks_df[["rank", "lift_synergy"]].groupby("rank").std())
print("---------------------------------------------------")
print("---------------------------------------------------")
print(ranks_df[["rank", "levelSum"]].groupby("rank").mean())
print(ranks_df[["rank", "levelSum"]].groupby("rank").std())
print("---------------------------------------------------")
print("---------------------------------------------------")
print(ranks_df[["rank", "avgSpeed"]].groupby("rank").mean())
print(ranks_df[["rank", "avgSpeed"]].groupby("rank").std())
print("---------------------------------------------------")
print("---------------------------------------------------")
print(ranks_df[["rank", "avgSpellDuration"]].groupby("rank").mean())
print(ranks_df[["rank", "avgSpellDuration"]].groupby("rank").std())
print("---------------------------------------------------")
print("---------------------------------------------------")
print(ranks_df[["rank", "totalHP"]].groupby("rank").mean())
print(ranks_df[["rank", "totalHP"]].groupby("rank").std())
print("---------------------------------------------------")
print("---------------------------------------------------")
print(ranks_df[["rank", "totalDMG"]].groupby("rank").mean())
print(ranks_df[["rank", "totalDMG"]].groupby("rank").std())
print("---------------------------------------------------")
print("---------------------------------------------------")
print(ranks_df[["rank", "avgAS"]].groupby("rank").mean())
print(ranks_df[["rank", "avgAS"]].groupby("rank").std())
print("---------------------------------------------------")
print("---------------------------------------------------")
print(ranks_df[["rank", "totalUnitsCount"]].groupby("rank").mean())
print(ranks_df[["rank", "totalUnitsCount"]].groupby("rank").std())
print("---------------------------------------------------")
print("---------------------------------------------------")
print(ranks_df[["rank", "abilityCount"]].groupby("rank").mean())
print(ranks_df[["rank", "abilityCount"]].groupby("rank").std())
print("---------------------------------------------------")
print("---------------------------------------------------")
print(ranks_df[["rank", "avgRange"]].groupby("rank").mean())
print(ranks_df[["rank", "avgRange"]].groupby("rank").std())
print("---------------------------------------------------")
print("---------------------------------------------------")
print(ranks_df[["rank", "totalGroundT"]].groupby("rank").mean())
print(ranks_df[["rank", "totalGroundT"]].groupby("rank").std())
print("---------------------------------------------------")
print("---------------------------------------------------")
print(ranks_df[["rank", "totalAirT"]].groupby("rank").mean())
print(ranks_df[["rank", "totalAirT"]].groupby("rank").std())
print("---------------------------------------------------")
print("---------------------------------------------------")
print(ranks_df[["rank", "totalBuildingT"]].groupby("rank").mean())
print(ranks_df[["rank", "totalBuildingT"]].groupby("rank").std())
print("---------------------------------------------------")
print("---------------------------------------------------")
print(ranks_df[["rank", "totalBuffCount"]].groupby("rank").mean())
print(ranks_df[["rank", "totalBuffCount"]].groupby("rank").std())
print("---------------------------------------------------")
print("---------------------------------------------------")
print(ranks_df[["rank", "totalProjectiles"]].groupby("rank").mean())
print(ranks_df[["rank", "totalProjectiles"]].groupby("rank").std())
print("---------------------------------------------------")
print("---------------------------------------------------")

ranks_df
# Out:
# ---------------------------------------------------
#                troop
# rank
# Challenger  5.889429
# Champion    5.137143
# Master      5.368857
#                troop
# rank
# Challenger  1.115021
# Champion    0.950650
# Master      1.013316
# ---------------------------------------------------
# ---------------------------------------------------
#             building
# rank
# Challenger  0.372857
# Champion    0.508571
# Master      0.516571
#             building
# rank
# Challenger   0.55465
# Champion     0.58287
# Master       0.60342
# ---------------------------------------------------
# ---------------------------------------------------
#                spell
# rank
# Challenger  1.737714
# Champion    2.354286
# Master      2.114571
#                spell
# rank
# Challenger  0.902700
# Champion    0.688925
# Master      0.792047
# ---------------------------------------------------
# ---------------------------------------------------
#               common
# rank
# Challenger  2.013143
# Champion    2.072000
# Master      2.136571
#               common
# rank
# Challenger  1.294281
# Champion    1.376305
# Master      1.301693
# ---------------------------------------------------
# ---------------------------------------------------
#                 rare
# rank
# Challenger  2.021143
# Champion    1.655429
# Master      2.154286
#                 rare
# rank
# Challenger  1.248999
# Champion    1.116844
# Master      1.283559
# ---------------------------------------------------
# ---------------------------------------------------
#                 epic
# rank
# Challenger  2.185714
# Champion    2.470857
# Master      2.216857
#                 epic
# rank
# Challenger  1.298458
# Champion    1.577567
# Master      1.415668
# ---------------------------------------------------
# ---------------------------------------------------
#             legendary
# rank
# Challenger   1.780000
# Champion     1.801714
# Master       1.492286
#             legendary
# rank
# Challenger   1.344450
# Champion     1.019444
# Master       1.047158
# ---------------------------------------------------
# ---------------------------------------------------
#               elixir
# rank
# Challenger  3.941923
# Champion    3.663602
# Master      3.789852
#               elixir
# rank
# Challenger  0.537450
# Champion    0.489592
# Master      0.496820
# ---------------------------------------------------
# ---------------------------------------------------
#             conf_synergy
# rank
# Challenger   5166.317494
# Champion    11960.667065
# Master       8512.293683
#             conf_synergy
# rank
# Challenger  11910.223708
# Champion    16885.578943
# Master      14923.715174
# ---------------------------------------------------
# ---------------------------------------------------
#              lift_synergy
# rank
# Challenger  171762.530769
# Champion    366761.641239
# Master      273465.345554
#              lift_synergy
# rank
# Challenger  431438.047552
# Champion    543340.957634
# Master      517453.027176
# ---------------------------------------------------
# ---------------------------------------------------
#               levelSum
# rank
# Challenger   91.497714
# Champion    103.779429
# Master      103.326571
#              levelSum
# rank
# Challenger  11.262933
# Champion     0.590900
# Master       1.403027
# ---------------------------------------------------
# ---------------------------------------------------
#              avgSpeed
# rank
# Challenger  76.585816
# Champion    75.893459
# Master      77.657602
#              avgSpeed
# rank
# Challenger   9.492413
# Champion    10.364504
# Master       9.948391
# ---------------------------------------------------
# ---------------------------------------------------
#             avgSpellDuration
# rank
# Challenger          5.644639
# Champion            5.840915
# Master              6.916762
#             avgSpellDuration
# rank
# Challenger          8.355736
# Champion            6.088218
# Master              8.031840
# ---------------------------------------------------
# ---------------------------------------------------
#                 totalHP
# rank
# Challenger  8081.543429
# Champion    8247.429143
# Master      8776.516000
#                 totalHP
# rank
# Challenger  2481.123329
# Champion    2348.916699
# Master      2527.995296
# ---------------------------------------------------
# ---------------------------------------------------
#                totalDMG
# rank
# Challenger  2122.466571
# Champion    2219.544857
# Master      2306.429429
#               totalDMG
# rank
# Challenger  736.051547
# Champion    771.445512
# Master      757.911465
# ---------------------------------------------------
# ---------------------------------------------------
#                avgAS
# rank
# Challenger  1.564996
# Champion    1.717283
# Master      1.681641
#                avgAS
# rank
# Challenger  0.469242
# Champion    0.658200
# Master      0.618986
# ---------------------------------------------------
# ---------------------------------------------------
#             totalUnitsCount
# rank
# Challenger        13.337714
# Champion           9.594571
# Master            11.098000
#             totalUnitsCount
# rank
# Challenger         7.276297
# Champion           5.809535
# Master             6.554788
# ---------------------------------------------------
# ---------------------------------------------------
#             abilityCount
# rank
# Challenger      2.488857
# Champion        2.569143
# Master          2.147143
#             abilityCount
# rank
# Challenger      1.472096
# Champion        1.367807
# Master          1.312026
# ---------------------------------------------------
# ---------------------------------------------------
#                avgRange
# rank
# Challenger  2863.975000
# Champion    2976.914286
# Master      2801.794643
#               avgRange
# rank
# Challenger  637.938937
# Champion    688.172799
# Master      640.297747
# ---------------------------------------------------
# ---------------------------------------------------
#             totalGroundT
# rank
# Challenger      7.923429
# Champion        7.982286
# Master          7.953714
#             totalGroundT
# rank
# Challenger      0.275450
# Champion        0.131930
# Master          0.212836
# ---------------------------------------------------
# ---------------------------------------------------
#             totalAirT
# rank
# Challenger   4.072286
# Champion     4.089714
# Master       3.991714
#             totalAirT
# rank
# Challenger   1.023406
# Champion     0.895167
# Master       0.966835
# ---------------------------------------------------
# ---------------------------------------------------
#             totalBuildingT
# rank
# Challenger        0.910000
# Champion          0.920000
# Master            0.947429
#             totalBuildingT
# rank
# Challenger        0.750088
# Champion          0.636509
# Master            0.632168
# ---------------------------------------------------
# ---------------------------------------------------
#             totalBuffCount
# rank
# Challenger        0.672571
# Champion          0.956000
# Master            0.821143
#             totalBuffCount
# rank
# Challenger        0.711793
# Champion          0.743309
# Master            0.739224
# ---------------------------------------------------
# ---------------------------------------------------
#             totalProjectiles
# rank
# Challenger          1.123714
# Champion            1.377429
# Master              1.324000
#             totalProjectiles
# rank
# Challenger          0.850908
# Champion            0.865062
# Master              0.866740
# ---------------------------------------------------
# ---------------------------------------------------
#              rank  troop  building  spell  common  rare  epic  legendary  \
# 0      Challenger      5         0      3       1     1     4          2
# 1      Challenger      5         1      2       1     2     3          2
# 2          Master      7         1      0       3     3     2          0
# 3      Challenger      7         0      1       4     2     1          1
# 4      Challenger      5         0      3       1     1     5          1
# ...           ...    ...       ...    ...     ...   ...   ...        ...
# 10495    Champion      5         1      2       0     4     4          0
# 10496    Champion      6         0      2       1     2     3          2
# 10497    Champion      6         0      2       2     1     2          3
# 10498    Champion      5         1      2       4     2     1          1
# 10499    Champion      6         0      2       0     1     6          1
#
#        elixir  conf_synergy  ...  avgRange  totalGroundT  totalAirT  \
# 0       3.375   2865.990531  ...   2712.50             8          3
# 1       4.250   3980.516610  ...   2018.75             7          5
# 2       4.875      0.000000  ...   1925.00             8          2
# 3       3.750   1389.332225  ...   4175.00             8          6
# 4       4.500   4049.013035  ...   3056.25             8          4
# ...       ...           ...  ...       ...           ...        ...
# 10495   3.625   2191.588585  ...   2800.00             8          4
# 10496   4.000  26569.219252  ...   2581.25             8          4
# 10497   3.750   2671.736517  ...   2275.00             8          4
# 10498   3.125  14365.842341  ...   3868.75             8          3
# 10499   4.625   3303.615309  ...   3006.25             8          5
#
#        totalBuildingT  totalBuffCount  totalProjectiles  commonLevel  \
# 0                   0               0                 3        11.00
# 1                   1               2                 0        13.00
# 2                   2               0                 0        13.00
# 3                   0               0                 1        13.00
# 4                   1               2                 1        13.00
# ...               ...             ...               ...          ...
# 10495               1               1                 1         0.00
# 10496               1               2                 0        13.00
# 10497               1               1                 1        13.00
# 10498               1               0                 2        16.25
# 10499               1               0                 2         0.00
#
#        rareLevel  epicLevel  legendaryLevel
# 0           11.0      10.25            10.5
# 1           13.0      13.00            13.0
# 2           13.0      13.00             0.0
# 3           13.0      13.00            13.0
# 4           13.0      13.00            13.0
# ...          ...        ...             ...
# 10495       13.0      13.00             0.0
# 10496       13.0      13.00            13.0
# 10497       13.0      13.00            13.0
# 10498       13.0       0.00            13.0
# 10499       13.0      13.00            13.0
#
# [10500 rows x 29 columns]

# %%
from sklearn.model_selection import StratifiedKFold
from imblearn.pipeline import Pipeline
from imblearn.over_sampling import SMOTE
from sklearn.feature_selection import SelectKBest, chi2, mutual_info_classif, VarianceThreshold
from sklearn.metrics import classification_report
from sklearn.model_selection import cross_validate
from sklearn.tree import DecisionTreeClassifier
from random import randrange
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn.metrics import make_scorer
from sklearn.neighbors import KNeighborsClassifier

y = np.array([x for x in ranks_df["rank"]])
X = np.array([x for x in ranks_df.drop(["rank"], axis="columns").values])

scoring = {
    'Accuracy': make_scorer(accuracy_score),
    'Precision': make_scorer(precision_score, average='macro', zero_division=0),
    'Recall': make_scorer(recall_score, average="macro", zero_division=0),
    'F-Measure': make_scorer(f1_score, average="macro", zero_division=0)
}

def converter(df):
    scores = {
        'fit_time': df['fit_time'],
        'score_time': df['score_time'],
        'test_Accuracy': df['test_Accuracy'],
        'test_Precision': df['test_Precision'],
        'test_Recall': df['test_Recall'],
        'test_F-Measure': df['test_F-Measure']
    }
    estimators = df['estimator']
    accuracies = df['test_Accuracy']
    for key in scores.keys():
        if "test_" in key:
            scores[key] = [f"{scores[key].mean() * 100: .2f}%"]
        else:
            scores[key] = [f"{scores[key].mean(): .2f}"]
    return [pd.DataFrame(scores), estimators, accuracies]

def feat_extraction(estimators, avoid_scores = False):
    features_per_fold = {}
    fold_index = 0
    for estim in estimators:
        fold_index += 1
        feature = 0
        sel_features = {}
        feat_scores = []
        if not avoid_scores:
            feat_scores = estim['feat_sel'].scores_
        for selected in estim['feat_sel'].get_support():
            feature+=1
            if(selected == True):
                if len(feat_scores) > 0:
                    sel_features[ranks_df.columns[feature]] = [feat_scores[feature-1]]
                else:
                    sel_features[ranks_df.columns[feature]] = True
        features_per_fold[f"fold_{fold_index}"] = sel_features
    return pd.DataFrame(features_per_fold).transpose()

skf = StratifiedKFold(n_splits=10, shuffle=True, random_state=randrange(1,42))

# %% [markdown]
# ### ANALYSIS

# %%
smoted_pipeline = Pipeline([
    ('sampler', SMOTE(random_state=randrange(1,42))),
    ('clf', KNeighborsClassifier(n_neighbors=4))
])
unsmoted_pipeline = Pipeline([
    ('clf', KNeighborsClassifier(n_neighbors=4))
])
#######################################################
kbest_smoted = Pipeline([
    ('feat_sel', SelectKBest(chi2, k=12)),
    ('sampler', SMOTE(random_state=randrange(1,42))),
    ('clf', KNeighborsClassifier(n_neighbors=4))
])
kbest_unsmoted = Pipeline([
    ('feat_sel', SelectKBest(chi2, k=12)),
    ('clf', KNeighborsClassifier(n_neighbors=4))
])
########################################################
kbest_smoted_mutual = Pipeline([
    ('feat_sel', SelectKBest(mutual_info_classif, k=12)),
    ('sampler', SMOTE(random_state=randrange(1,42))),
    ('clf', KNeighborsClassifier(n_neighbors=4))
])
kbest_unsmoted_mutual = Pipeline([
    ('feat_sel', SelectKBest(mutual_info_classif, k=12)),
    ('clf', KNeighborsClassifier(n_neighbors=4))
])
########################################################
VT_smoted = Pipeline([
    ('feat_sel', VarianceThreshold(threshold=0.7)),
    ('sampler', SMOTE(random_state=randrange(1,42))),
    ('clf', KNeighborsClassifier(n_neighbors=4))
])
VT_unsmoted = Pipeline([
    ('feat_sel', VarianceThreshold(threshold=0.7)),
    ('clf', KNeighborsClassifier(n_neighbors=4))
])

metricsComparison = {}

# %% [markdown]
# ### SMOTE NO ATTRIBUT SELECTION

# %%
smoted_ = cross_validate(smoted_pipeline, X, y, scoring=scoring, cv=skf, n_jobs=8, return_estimator=True)
mean_smoted, smoted_estimators, accuracies = converter(smoted_)

metricsComparison['KNN + SMOTE'] = [accuracies]

mean_smoted
# Out:
#   fit_time score_time test_Accuracy test_Precision test_Recall test_F-Measure
# 0     0.03       0.69        55.48%         54.25%      55.48%         53.88%

# %% [markdown]
# ### NO SMOTE NO ATTRIBUTE SELECTION

# %%
unsmoted_ = cross_validate(unsmoted_pipeline, X, y, scoring=scoring, cv=skf, n_jobs=8, return_estimator=True)
mean_unsmoted, unsmoted_estimators, accuracies = converter(unsmoted_)

metricsComparison['KNN'] = [accuracies]

mean_unsmoted
# Out:
#   fit_time score_time test_Accuracy test_Precision test_Recall test_F-Measure
# 0     0.01       0.71        55.48%         54.25%      55.48%         53.88%

# %% [markdown]
# ### SMOTE KBEST SELECTION

# %%
kbest_smoted_ = cross_validate(kbest_smoted, X, y, scoring=scoring, cv=skf, n_jobs=8, return_estimator=True)

mean_kbest_smoted, kbest_smoted_estimators, accuracies = converter(kbest_smoted_)
    
kbest_features = feat_extraction(kbest_smoted_estimators)
kbest_features
# Out:
#                 conf_synergy          lift_synergy              levelSum  \
# fold_1   [8438011.862129148]  [218400470.65836045]  [3085.7283499854866]
# fold_2    [8388647.25270739]   [215138291.9096845]  [3058.9522378000747]
# fold_3   [8365645.679946916]  [215674337.66412026]  [3076.6663342504903]
# fold_4    [8454315.71339073]  [218410495.73813957]  [3069.4660159800965]
# fold_5   [8320926.917106697]  [216814520.31966653]   [3095.017533263008]
# fold_6   [8900416.018479113]  [231735060.46655792]   [3072.375998060759]
# fold_7   [8199859.198191839]  [212366746.34123906]  [3085.7725139546014]
# fold_8   [8915604.604000445]  [238236136.11995432]  [3032.7259390432378]
# fold_9   [8375232.335531646]  [219707894.57672152]  [3051.6371621111625]
# fold_10  [8747687.377840146]  [228683222.26307344]    [3066.37575836178]
#
#              avgSpellDuration               totalHP              totalDMG  \
# fold_1   [436.62667849861214]  [100762.14090379392]  [22315.353096034283]
# fold_2   [435.78604643268744]  [105158.81799928837]  [26611.039730686498]
# fold_3    [508.2837929351699]  [102235.32515749196]  [26057.842062469193]
# fold_4    [515.7742985704888]   [93884.94994415599]  [21472.978584068485]
# fold_5    [522.9520753506929]   [99260.71324981545]  [25409.478604715354]
# fold_6    [487.1862670651951]   [96884.24042702827]    [22413.1596559485]
# fold_7    [463.9789579065445]   [95930.14153662769]  [25641.536864722315]
# fold_8     [455.881220601794]   [93887.48369546173]   [23260.94247602368]
# fold_9   [506.43041478736814]   [96939.65572110799]   [24114.93795987955]
# fold_10  [495.18339365685597]  [107872.36734732697]  [23975.809351027387]
#
#               totalUnitsCount              avgRange           commonLevel  \
# fold_1    [1919.149488054608]  [18119.976958128547]  [376.55751341818996]
# fold_2   [1889.4126481919195]  [16429.251988242835]  [350.75630457214027]
# fold_3    [1940.929226626273]   [20059.54557610143]   [357.1109105726346]
# fold_4   [1927.7173524150269]  [16594.508141599632]   [364.4859564230096]
# fold_5    [2024.692607003891]  [16174.937471123965]  [346.60727209314075]
# fold_6    [2054.486667722197]   [17572.07345610701]  [321.24036493444396]
# fold_7   [1993.0830088247653]  [15878.885196969153]   [368.5461423786189]
# fold_8   [1957.0981753050487]  [16667.003081380593]  [339.28084275590777]
# fold_9   [1977.8014361419753]  [17092.125183046894]   [377.2782341185847]
# fold_10  [2025.4366268210686]  [18048.456473796665]   [374.1879436253971]
#
#                     rareLevel             epicLevel        legendaryLevel
# fold_1    [432.7548054502747]  [386.89126190111966]  [1217.5413313449724]
# fold_2   [410.49973138885383]  [363.74531930618946]  [1160.3023540560193]
# fold_3    [416.3025453533189]  [369.34000335294803]  [1199.1282576664983]
# fold_4    [407.1072884275655]   [372.1613746467842]   [1188.093158603672]
# fold_5   [409.72589463469774]  [369.02338983429513]  [1195.7963416076725]
# fold_6    [432.9959371920085]   [364.8325366641795]   [1208.604040415474]
# fold_7    [406.8355737549688]     [384.22861566767]  [1161.8539829223575]
# fold_8    [402.3778380067081]   [354.2971799778599]  [1172.4760543127488]
# fold_9    [372.7746167691738]   [359.9284302149809]  [1155.8580804891556]
# fold_10   [424.7268772664086]  [368.77626969693085]  [1180.6416896002127]

# %%
metricsComparison['KNN + SMOTE + KBEST and chi2'] = [accuracies]

mean_kbest_smoted
# Out:
#   fit_time score_time test_Accuracy test_Precision test_Recall test_F-Measure
# 0     0.07       0.06        55.44%         54.22%      55.44%         53.88%

# %% [markdown]
# ### NO SMOTE KBEST SELECTION

# %%
kbest_unsmoted_scores = cross_validate(kbest_unsmoted, X, y, scoring=scoring, cv=skf, n_jobs=8, return_estimator=True)
mean_kbest_unsmoted, kbest_unsmoted_estimators, accuracies = converter(kbest_unsmoted_scores)

kbest_unsmoted_features = feat_extraction(kbest_unsmoted_estimators)

kbest_unsmoted_features
# Out:
#                 conf_synergy          lift_synergy              levelSum  \
# fold_1   [8438011.862129148]  [218400470.65836045]  [3085.7283499854866]
# fold_2    [8388647.25270739]   [215138291.9096845]  [3058.9522378000747]
# fold_3   [8365645.679946916]  [215674337.66412026]  [3076.6663342504903]
# fold_4    [8454315.71339073]  [218410495.73813957]  [3069.4660159800965]
# fold_5   [8320926.917106697]  [216814520.31966653]   [3095.017533263008]
# fold_6   [8900416.018479113]  [231735060.46655792]   [3072.375998060759]
# fold_7   [8199859.198191839]  [212366746.34123906]  [3085.7725139546014]
# fold_8   [8915604.604000445]  [238236136.11995432]  [3032.7259390432378]
# fold_9   [8375232.335531646]  [219707894.57672152]  [3051.6371621111625]
# fold_10  [8747687.377840146]  [228683222.26307344]    [3066.37575836178]
#
#              avgSpellDuration               totalHP              totalDMG  \
# fold_1   [436.62667849861214]  [100762.14090379392]  [22315.353096034283]
# fold_2   [435.78604643268744]  [105158.81799928837]  [26611.039730686498]
# fold_3    [508.2837929351699]  [102235.32515749196]  [26057.842062469193]
# fold_4    [515.7742985704888]   [93884.94994415599]  [21472.978584068485]
# fold_5    [522.9520753506929]   [99260.71324981545]  [25409.478604715354]
# fold_6    [487.1862670651951]   [96884.24042702827]    [22413.1596559485]
# fold_7    [463.9789579065445]   [95930.14153662769]  [25641.536864722315]
# fold_8     [455.881220601794]   [93887.48369546173]   [23260.94247602368]
# fold_9   [506.43041478736814]   [96939.65572110799]   [24114.93795987955]
# fold_10  [495.18339365685597]  [107872.36734732697]  [23975.809351027387]
#
#               totalUnitsCount              avgRange           commonLevel  \
# fold_1    [1919.149488054608]  [18119.976958128547]  [376.55751341818996]
# fold_2   [1889.4126481919195]  [16429.251988242835]  [350.75630457214027]
# fold_3    [1940.929226626273]   [20059.54557610143]   [357.1109105726346]
# fold_4   [1927.7173524150269]  [16594.508141599632]   [364.4859564230096]
# fold_5    [2024.692607003891]  [16174.937471123965]  [346.60727209314075]
# fold_6    [2054.486667722197]   [17572.07345610701]  [321.24036493444396]
# fold_7   [1993.0830088247653]  [15878.885196969153]   [368.5461423786189]
# fold_8   [1957.0981753050487]  [16667.003081380593]  [339.28084275590777]
# fold_9   [1977.8014361419753]  [17092.125183046894]   [377.2782341185847]
# fold_10  [2025.4366268210686]  [18048.456473796665]   [374.1879436253971]
#
#                     rareLevel             epicLevel        legendaryLevel
# fold_1    [432.7548054502747]  [386.89126190111966]  [1217.5413313449724]
# fold_2   [410.49973138885383]  [363.74531930618946]  [1160.3023540560193]
# fold_3    [416.3025453533189]  [369.34000335294803]  [1199.1282576664983]
# fold_4    [407.1072884275655]   [372.1613746467842]   [1188.093158603672]
# fold_5   [409.72589463469774]  [369.02338983429513]  [1195.7963416076725]
# fold_6    [432.9959371920085]   [364.8325366641795]   [1208.604040415474]
# fold_7    [406.8355737549688]     [384.22861566767]  [1161.8539829223575]
# fold_8    [402.3778380067081]   [354.2971799778599]  [1172.4760543127488]
# fold_9    [372.7746167691738]   [359.9284302149809]  [1155.8580804891556]
# fold_10   [424.7268772664086]  [368.77626969693085]  [1180.6416896002127]

# %%
metricsComparison['KNN + KBEST and chi2'] = [accuracies]

mean_kbest_unsmoted
# Out:
#   fit_time score_time test_Accuracy test_Precision test_Recall test_F-Measure
# 0     0.06       0.07        55.44%         54.22%      55.44%         53.88%

# %% [markdown]
# ### KBEST SELECTOR WITH MUTUAL INFO CLASSIFIER

# %% [markdown]
# ###### SMOTED

# %%
kbest_smoted_mutual_ = cross_validate(kbest_smoted_mutual, X, y, scoring=scoring, cv=skf, n_jobs=8, return_estimator=True)
kbest_smoted_mutual_scores, kbest_smoted_mutual_estimators, accuracies = converter(kbest_smoted_mutual_)

kbest_smoted_mutual_features = feat_extraction(kbest_smoted_mutual_estimators)
kbest_smoted_mutual_features
# Out:
#                   conf_synergy           lift_synergy               levelSum  \
# fold_1    [0.1754356759141058]  [0.17203826299779612]   [0.3293261642260654]
# fold_2   [0.18187903180427067]   [0.1797631000654618]  [0.33899715164406263]
# fold_3   [0.17495300632786526]  [0.17585297706233294]   [0.3407918721930516]
# fold_4   [0.17589657403294767]  [0.17867662097258452]   [0.3361535191037477]
# fold_5     [0.174419603499117]   [0.1724562125046447]   [0.3291410652492004]
# fold_6   [0.17594102923926802]  [0.16421733636165348]  [0.33553224237854185]
# fold_7    [0.1796227398167649]  [0.17662338474326722]  [0.33896137411463667]
# fold_8    [0.1735259604452808]  [0.17452487917300274]   [0.3234437173699123]
# fold_9   [0.17145084421472134]  [0.16710367975415585]  [0.33273263355565685]
# fold_10  [0.18322680850059236]  [0.17512901298917938]   [0.3402674487874091]
#
#               avgSpellDuration                totalHP               totalDMG  \
# fold_1   [0.10746309757724593]  [0.20020931980452938]  [0.18357560396552475]
# fold_2   [0.10397804661008547]  [0.20204586802055724]   [0.1665675158876958]
# fold_3   [0.11632495381606645]  [0.19864462710628872]  [0.18564976634780672]
# fold_4   [0.10882658334395678]  [0.20545900147800933]  [0.18425873876833898]
# fold_5   [0.10407656483334926]  [0.20085737577696827]  [0.17984087966023088]
# fold_6   [0.11412303213169328]  [0.20480633584401797]  [0.17749694263526816]
# fold_7   [0.10170321345836975]  [0.20182716717695182]  [0.18131031163577616]
# fold_8   [0.10562554163012416]   [0.1992425382599332]   [0.1803175190785251]
# fold_9   [0.11615571171828787]  [0.19383035723485031]   [0.1908573244874776]
# fold_10  [0.10927607994870536]  [0.19891456265956853]  [0.17992455789555684]
#
#                          avgAS               avgRange            commonLevel  \
# fold_1   [0.12086360981136268]  [0.08978262578011553]    [0.198732474843192]
# fold_2   [0.11180180752340063]  [0.08544612094835458]  [0.19632677149482802]
# fold_3   [0.11230995688854506]  [0.09639179616717741]  [0.20080658189117395]
# fold_4    [0.1155180119528969]  [0.08968587914544113]  [0.20041227657772143]
# fold_5    [0.1104345859532121]  [0.09634357957908701]  [0.18546355602833242]
# fold_6   [0.11378115475591466]  [0.08550592191797013]  [0.20047870495526943]
# fold_7   [0.11338188853382847]  [0.08746851348978746]  [0.19699311425750343]
# fold_8   [0.11579614928521464]  [0.08874840449640731]  [0.20357639934121963]
# fold_9   [0.11617005473734876]  [0.08898574249646707]  [0.19806295362256465]
# fold_10  [0.11409121126070221]  [0.08142148260420545]  [0.19340207505116735]
#
#                      rareLevel              epicLevel         legendaryLevel
# fold_1   [0.23570675364037474]  [0.25508806517813576]  [0.31673108477177125]
# fold_2   [0.23684360867795573]   [0.2517559059922636]   [0.3095497683908801]
# fold_3   [0.24307797293539757]  [0.24683842946594448]   [0.3315431440470882]
# fold_4   [0.23122285170745638]  [0.24933456672980947]   [0.3235133027554318]
# fold_5   [0.22802108704022106]   [0.2499855789226444]   [0.3266184900161033]
# fold_6   [0.23590216610775805]   [0.2580283270126731]  [0.32390922048540105]
# fold_7   [0.23018811549716478]  [0.23898660160694396]   [0.3161378999140949]
# fold_8   [0.22732530084183566]  [0.25146140443906195]  [0.32742528669139337]
# fold_9   [0.22143699123345373]  [0.25699670162866495]   [0.3258809824436584]
# fold_10  [0.22471847641039933]  [0.24394831853505528]  [0.31295361164907454]

# %%
metricsComparison['KNN + SMOTE + KBEST and mutual_info'] = [accuracies]

kbest_smoted_mutual_scores
# Out:
#   fit_time score_time test_Accuracy test_Precision test_Recall test_F-Measure
# 0     2.09       0.06        55.45%         54.23%      55.45%         53.89%

# %% [markdown]
# ###### UNSMOTED

# %%
kbest_unsmoted_mutual_ = cross_validate(kbest_unsmoted_mutual, X, y, scoring=scoring, cv=skf, n_jobs=8, return_estimator=True)
kbest_unsmoted_mutual_scores, kbest_unsmoted_mutual_estimators, accuracies = converter(kbest_unsmoted_mutual_)

kbest_unsmoted_mutual_features = feat_extraction(kbest_unsmoted_mutual_estimators)
kbest_unsmoted_mutual_features
# Out:
#                   conf_synergy           lift_synergy               levelSum  \
# fold_1   [0.18036373427524421]  [0.17750828134497532]  [0.32990845164970795]
# fold_2   [0.17149724608395145]  [0.17828693477251334]   [0.3413174204454277]
# fold_3    [0.1745140595778274]  [0.17617481780669175]    [0.338163998329285]
# fold_4   [0.17407109169464663]  [0.17996269675274923]   [0.3441826691198404]
# fold_5   [0.18299694917038334]  [0.17757119825471923]  [0.34322962832580184]
# fold_6   [0.16942179598007012]  [0.16374213182448183]  [0.33596649553695435]
# fold_7   [0.19205811963333397]  [0.17380967694811722]  [0.33591902182672406]
# fold_8   [0.16960936628197198]  [0.17114320419762685]   [0.3342208219517322]
# fold_9    [0.1811387767685435]   [0.1760926103217202]  [0.33310637219894446]
# fold_10  [0.18900198887377573]   [0.1830798303161989]  [0.33137642794970645]
#
#               avgSpellDuration                totalHP               totalDMG  \
# fold_1    [0.1151502030039886]  [0.20446499183310252]  [0.18358989392554892]
# fold_2   [0.11584295055837868]   [0.1972261186349924]   [0.1780582551919705]
# fold_3   [0.10721280340510342]  [0.20386235145791232]   [0.1808123594731692]
# fold_4   [0.10408144674440778]  [0.20480957790586474]  [0.18240669085001815]
# fold_5   [0.10974106444331522]  [0.20190287245377037]   [0.1741745618109627]
# fold_6   [0.10471470379330339]  [0.20754967437223582]  [0.18139820406862683]
# fold_7   [0.10418288800851849]   [0.1996768150023518]  [0.18173832939979806]
# fold_8   [0.11854861848058063]  [0.20012527057995566]  [0.18052191514096738]
# fold_9   [0.10859134069451337]  [0.19249503422542702]  [0.18690695157877069]
# fold_10   [0.1107173673422055]  [0.19796620379643382]  [0.17916693877435885]
#
#                          avgAS               avgRange            commonLevel  \
# fold_1   [0.10561952062510938]  [0.08476050564460902]   [0.1952209728839709]
# fold_2   [0.11689114449401128]  [0.08768444005173603]  [0.19886857166532135]
# fold_3   [0.12581083962031325]  [0.09675719955419737]  [0.20364321906446148]
# fold_4   [0.11097544779986213]  [0.09916772757505066]  [0.18761780885861712]
# fold_5   [0.11191325096076632]  [0.08674866832945649]  [0.20485042231729977]
# fold_6   [0.11281285002217611]  [0.09063120645844136]  [0.19503059517316568]
# fold_7   [0.10576002204906687]  [0.09159918414221324]  [0.20100485241882127]
# fold_8   [0.11572136423429602]                    NaN  [0.19104538279181038]
# fold_9   [0.12280851839201201]  [0.09652324693204895]  [0.19983629794380176]
# fold_10  [0.11527809570521819]  [0.09378258617028523]  [0.19860824183646275]
#
#                      rareLevel              epicLevel         legendaryLevel  \
# fold_1   [0.23919719539558226]  [0.25080891422088825]  [0.31936454732414066]
# fold_2    [0.2341301015086965]   [0.2506204371836742]   [0.3178730610138052]
# fold_3   [0.22849417643940573]  [0.24595280497889904]   [0.3182421200616419]
# fold_4   [0.23140016962739596]  [0.24480788678935483]  [0.31934376577645884]
# fold_5   [0.23021420004195825]   [0.2510895816783345]  [0.33364406035003125]
# fold_6   [0.23886132067678179]  [0.24813979325164337]  [0.31391821432680245]
# fold_7    [0.2304770865709831]  [0.25232075140994614]   [0.3113475661376721]
# fold_8   [0.22734251801288097]   [0.2482983836410615]   [0.3203980478586925]
# fold_9   [0.22862143861096063]    [0.253058132864346]  [0.31687947249613946]
# fold_10  [0.23333006928718558]   [0.2526790132157424]  [0.31582043982257346]
#
#                       avgSpeed
# fold_1                     NaN
# fold_2                     NaN
# fold_3                     NaN
# fold_4                     NaN
# fold_5                     NaN
# fold_6                     NaN
# fold_7                     NaN
# fold_8   [0.08288883674304293]
# fold_9                     NaN
# fold_10                    NaN

# %%
metricsComparison['KNN + KBEST and mutual_info'] = [accuracies]

kbest_unsmoted_mutual_scores
# Out:
#   fit_time score_time test_Accuracy test_Precision test_Recall test_F-Measure
# 0     2.01       0.07        55.47%         54.25%      55.47%         53.91%

# %% [markdown]
# ### VARIANCE THRESHOLD SELECTION

# %% [markdown]
# ###### SMOTED

# %%
VT_smoted_ = cross_validate(VT_smoted, X, y, scoring=scoring, cv=skf, n_jobs=8, return_estimator=True)
VT_smoted_scores, VT_smoted_estimators, accuracies = converter(VT_smoted_)

VT_smoted_features = feat_extraction(VT_smoted_estimators, avoid_scores=True)
VT_smoted_features
# Out:
#         troop spell common  rare  epic legendary conf_synergy lift_synergy  \
# fold_1   True  True   True  True  True      True         True         True
# fold_2   True  True   True  True  True      True         True         True
# fold_3   True   NaN   True  True  True      True         True         True
# fold_4   True  True   True  True  True      True         True         True
# fold_5   True  True   True  True  True      True         True         True
# fold_6   True  True   True  True  True      True         True         True
# fold_7   True   NaN   True  True  True      True         True         True
# fold_8   True  True   True  True  True      True         True         True
# fold_9   True  True   True  True  True      True         True         True
# fold_10  True  True   True  True  True      True         True         True
#
#         levelSum avgSpeed  ... totalDMG totalUnitsCount abilityCount avgRange  \
# fold_1      True     True  ...     True            True         True     True
# fold_2      True     True  ...     True            True         True     True
# fold_3      True     True  ...     True            True         True     True
# fold_4      True     True  ...     True            True         True     True
# fold_5      True     True  ...     True            True         True     True
# fold_6      True     True  ...     True            True         True     True
# fold_7      True     True  ...     True            True         True     True
# fold_8      True     True  ...     True            True         True     True
# fold_9      True     True  ...     True            True         True     True
# fold_10     True     True  ...     True            True         True     True
#
#         totalAirT totalProjectiles commonLevel rareLevel epicLevel  \
# fold_1       True             True        True      True      True
# fold_2       True             True        True      True      True
# fold_3       True             True        True      True      True
# fold_4       True             True        True      True      True
# fold_5       True             True        True      True      True
# fold_6       True             True        True      True      True
# fold_7       True             True        True      True      True
# fold_8       True             True        True      True      True
# fold_9       True             True        True      True      True
# fold_10      True             True        True      True      True
#
#         legendaryLevel
# fold_1            True
# fold_2            True
# fold_3            True
# fold_4            True
# fold_5            True
# fold_6            True
# fold_7            True
# fold_8            True
# fold_9            True
# fold_10           True
#
# [10 rows x 22 columns]

# %%
metricsComparison['KNN + SMOTE + Variance Threshold'] = [accuracies]

VT_smoted_scores
# Out:
#   fit_time score_time test_Accuracy test_Precision test_Recall test_F-Measure
# 0     0.05       0.73        55.44%         54.20%      55.44%         53.83%

# %% [markdown]
# ###### UNSMOTED

# %%
VT_unsmoted_ = cross_validate(VT_unsmoted, X, y, scoring=scoring, cv=skf, n_jobs=8, return_estimator=True)
VT_unsmoted_scores, VT_unsmoted_estimators, accuracies = converter(VT_unsmoted_)

VT_unsmoted_features = feat_extraction(VT_unsmoted_estimators, avoid_scores=True)
VT_unsmoted_features
# Out:
#         troop spell common  rare  epic legendary conf_synergy lift_synergy  \
# fold_1   True  True   True  True  True      True         True         True
# fold_2   True  True   True  True  True      True         True         True
# fold_3   True   NaN   True  True  True      True         True         True
# fold_4   True  True   True  True  True      True         True         True
# fold_5   True  True   True  True  True      True         True         True
# fold_6   True  True   True  True  True      True         True         True
# fold_7   True   NaN   True  True  True      True         True         True
# fold_8   True  True   True  True  True      True         True         True
# fold_9   True  True   True  True  True      True         True         True
# fold_10  True  True   True  True  True      True         True         True
#
#         levelSum avgSpeed  ... totalDMG totalUnitsCount abilityCount avgRange  \
# fold_1      True     True  ...     True            True         True     True
# fold_2      True     True  ...     True            True         True     True
# fold_3      True     True  ...     True            True         True     True
# fold_4      True     True  ...     True            True         True     True
# fold_5      True     True  ...     True            True         True     True
# fold_6      True     True  ...     True            True         True     True
# fold_7      True     True  ...     True            True         True     True
# fold_8      True     True  ...     True            True         True     True
# fold_9      True     True  ...     True            True         True     True
# fold_10     True     True  ...     True            True         True     True
#
#         totalAirT totalProjectiles commonLevel rareLevel epicLevel  \
# fold_1       True             True        True      True      True
# fold_2       True             True        True      True      True
# fold_3       True             True        True      True      True
# fold_4       True             True        True      True      True
# fold_5       True             True        True      True      True
# fold_6       True             True        True      True      True
# fold_7       True             True        True      True      True
# fold_8       True             True        True      True      True
# fold_9       True             True        True      True      True
# fold_10      True             True        True      True      True
#
#         legendaryLevel
# fold_1            True
# fold_2            True
# fold_3            True
# fold_4            True
# fold_5            True
# fold_6            True
# fold_7            True
# fold_8            True
# fold_9            True
# fold_10           True
#
# [10 rows x 22 columns]

# %%
metricsComparison['KNN + Variance Threshold'] = [accuracies]

VT_unsmoted_scores
# Out:
#   fit_time score_time test_Accuracy test_Precision test_Recall test_F-Measure
# 0     0.03       0.72        55.38%         54.14%      55.38%         53.78%

# %% [markdown]
# ### BOX PLOT OF RESULTS

# %%
final_dict = {}
for metric in metricsComparison:
    for m in metricsComparison[metric]:
        final_dict[metric] = m
mc_df = pd.DataFrame(final_dict)
mc_df.plot.box(return_type='axes', figsize=(40,20), grid=True, fontsize=14)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## ANALYSIS WITHOUT LEVEL

# %%
ranks_nolevel_df = ranks_df.drop(["levelSum"], axis="columns")
ranks_nolevel_df
# Out:
#              rank  troop  building  spell  common  rare  epic  legendary  \
# 0      Challenger      5         0      3       1     1     4          2
# 1      Challenger      5         1      2       1     2     3          2
# 2          Master      7         1      0       3     3     2          0
# 3      Challenger      7         0      1       4     2     1          1
# 4      Challenger      5         0      3       1     1     5          1
# ...           ...    ...       ...    ...     ...   ...   ...        ...
# 10495    Champion      5         1      2       0     4     4          0
# 10496    Champion      6         0      2       1     2     3          2
# 10497    Champion      6         0      2       2     1     2          3
# 10498    Champion      5         1      2       4     2     1          1
# 10499    Champion      6         0      2       0     1     6          1
#
#        elixir  conf_synergy  ...  avgRange  totalGroundT  totalAirT  \
# 0       3.375   2865.990531  ...   2712.50             8          3
# 1       4.250   3980.516610  ...   2018.75             7          5
# 2       4.875      0.000000  ...   1925.00             8          2
# 3       3.750   1389.332225  ...   4175.00             8          6
# 4       4.500   4049.013035  ...   3056.25             8          4
# ...       ...           ...  ...       ...           ...        ...
# 10495   3.625   2191.588585  ...   2800.00             8          4
# 10496   4.000  26569.219252  ...   2581.25             8          4
# 10497   3.750   2671.736517  ...   2275.00             8          4
# 10498   3.125  14365.842341  ...   3868.75             8          3
# 10499   4.625   3303.615309  ...   3006.25             8          5
#
#        totalBuildingT  totalBuffCount  totalProjectiles  commonLevel  \
# 0                   0               0                 3        11.00
# 1                   1               2                 0        13.00
# 2                   2               0                 0        13.00
# 3                   0               0                 1        13.00
# 4                   1               2                 1        13.00
# ...               ...             ...               ...          ...
# 10495               1               1                 1         0.00
# 10496               1               2                 0        13.00
# 10497               1               1                 1        13.00
# 10498               1               0                 2        16.25
# 10499               1               0                 2         0.00
#
#        rareLevel  epicLevel  legendaryLevel
# 0           11.0      10.25            10.5
# 1           13.0      13.00            13.0
# 2           13.0      13.00             0.0
# 3           13.0      13.00            13.0
# 4           13.0      13.00            13.0
# ...          ...        ...             ...
# 10495       13.0      13.00             0.0
# 10496       13.0      13.00            13.0
# 10497       13.0      13.00            13.0
# 10498       13.0       0.00            13.0
# 10499       13.0      13.00            13.0
#
# [10500 rows x 28 columns]

# %%
y = np.array([x for x in ranks_nolevel_df["rank"]])
X = np.array([x for x in ranks_nolevel_df.drop(["rank"], axis="columns").values])
metricsComparison = {}

# %% [markdown]
# ### SMOTE NO ATTRIBUT SELECTION

# %%
smoted_ = cross_validate(smoted_pipeline, X, y, scoring=scoring, cv=skf, n_jobs=8, return_estimator=True)
mean_smoted, smoted_estimators, accuracies = converter(smoted_)

metricsComparison['KNN+SMOTE'] = [accuracies]

mean_smoted
# Out:
#   fit_time score_time test_Accuracy test_Precision test_Recall test_F-Measure
# 0     0.03       0.71        55.57%         54.36%      55.57%         54.00%

# %% [markdown]
# ### NO SMOTE NO ATTRIBUTE SELECTION

# %%
unsmoted_ = cross_validate(unsmoted_pipeline, X, y, scoring=scoring, cv=skf, n_jobs=8, return_estimator=True)
mean_unsmoted, unsmoted_estimators, accuracies = converter(unsmoted_)

metricsComparison['KNN'] = [accuracies]

mean_unsmoted
# Out:
#   fit_time score_time test_Accuracy test_Precision test_Recall test_F-Measure
# 0     0.01       0.74        55.57%         54.36%      55.57%         54.00%

# %% [markdown]
# ### SMOTE KBEST SELECTION

# %%
kbest_smoted_ = cross_validate(kbest_smoted, X, y, scoring=scoring, cv=skf, n_jobs=8, return_estimator=True)

mean_kbest_smoted, kbest_smoted_estimators, accuracies = converter(kbest_smoted_)
    
kbest_features = feat_extraction(kbest_smoted_estimators)
kbest_features
# Out:
#                         spell         conf_synergy          lift_synergy  \
# fold_1    [311.1859573815729]  [8438011.862129148]  [218400470.65836045]
# fold_2   [280.39797794117646]   [8388647.25270739]   [215138291.9096845]
# fold_3   [297.42200614124874]  [8365645.679946916]  [215674337.66412026]
# fold_4   [290.50882307810343]   [8454315.71339073]  [218410495.73813957]
# fold_5   [302.50995852746917]  [8320926.917106697]  [216814520.31966653]
# fold_6    [296.5227040294539]  [8900416.018479113]  [231735060.46655792]
# fold_7    [286.4516227801592]  [8199859.198191839]  [212366746.34123906]
# fold_8   [291.45198895592597]  [8915604.604000445]  [238236136.11995432]
# fold_9   [286.61640889070986]  [8375232.335531646]  [219707894.57672152]
# fold_10  [299.55693475584735]  [8747687.377840146]  [228683222.26307344]
#
#                      avgSpeed      avgSpellDuration               totalHP  \
# fold_1   [436.62667849861214]  [100762.14090379392]  [22315.353096034283]
# fold_2   [435.78604643268744]  [105158.81799928837]  [26611.039730686498]
# fold_3    [508.2837929351699]  [102235.32515749196]  [26057.842062469193]
# fold_4    [515.7742985704888]   [93884.94994415599]  [21472.978584068485]
# fold_5    [522.9520753506929]   [99260.71324981545]  [25409.478604715354]
# fold_6    [487.1862670651951]   [96884.24042702827]    [22413.1596559485]
# fold_7    [463.9789579065445]   [95930.14153662769]  [25641.536864722315]
# fold_8     [455.881220601794]   [93887.48369546173]   [23260.94247602368]
# fold_9   [506.43041478736814]   [96939.65572110799]   [24114.93795987955]
# fold_10  [495.18339365685597]  [107872.36734732697]  [23975.809351027387]
#
#                         avgAS          abilityCount      totalProjectiles  \
# fold_1    [1919.149488054608]  [18119.976958128547]  [376.55751341818996]
# fold_2   [1889.4126481919195]  [16429.251988242835]  [350.75630457214027]
# fold_3    [1940.929226626273]   [20059.54557610143]   [357.1109105726346]
# fold_4   [1927.7173524150269]  [16594.508141599632]   [364.4859564230096]
# fold_5    [2024.692607003891]  [16174.937471123965]  [346.60727209314075]
# fold_6    [2054.486667722197]   [17572.07345610701]  [321.24036493444396]
# fold_7   [1993.0830088247653]  [15878.885196969153]   [368.5461423786189]
# fold_8   [1957.0981753050487]  [16667.003081380593]  [339.28084275590777]
# fold_9   [1977.8014361419753]  [17092.125183046894]   [377.2782341185847]
# fold_10  [2025.4366268210686]  [18048.456473796665]   [374.1879436253971]
#
#                   commonLevel             rareLevel             epicLevel
# fold_1    [432.7548054502747]  [386.89126190111966]  [1217.5413313449724]
# fold_2   [410.49973138885383]  [363.74531930618946]  [1160.3023540560193]
# fold_3    [416.3025453533189]  [369.34000335294803]  [1199.1282576664983]
# fold_4    [407.1072884275655]   [372.1613746467842]   [1188.093158603672]
# fold_5   [409.72589463469774]  [369.02338983429513]  [1195.7963416076725]
# fold_6    [432.9959371920085]   [364.8325366641795]   [1208.604040415474]
# fold_7    [406.8355737549688]     [384.22861566767]  [1161.8539829223575]
# fold_8    [402.3778380067081]   [354.2971799778599]  [1172.4760543127488]
# fold_9    [372.7746167691738]   [359.9284302149809]  [1155.8580804891556]
# fold_10   [424.7268772664086]  [368.77626969693085]  [1180.6416896002127]

# %%
metricsComparison['KNN+SMOTE+KBEST and chi2'] = [accuracies]

mean_kbest_smoted
# Out:
#   fit_time score_time test_Accuracy test_Precision test_Recall test_F-Measure
# 0     0.08       0.07        55.45%         54.23%      55.45%         53.89%

# %% [markdown]
# ### NO SMOTE KBEST SELECTION

# %%
kbest_unsmoted_scores = cross_validate(kbest_unsmoted, X, y, scoring=scoring, cv=skf, n_jobs=8, return_estimator=True)
mean_kbest_unsmoted, kbest_unsmoted_estimators, accuracies = converter(kbest_unsmoted_scores)

kbest_unsmoted_features = feat_extraction(kbest_unsmoted_estimators)

kbest_unsmoted_features
# Out:
#                         spell         conf_synergy          lift_synergy  \
# fold_1    [311.1859573815729]  [8438011.862129148]  [218400470.65836045]
# fold_2   [280.39797794117646]   [8388647.25270739]   [215138291.9096845]
# fold_3   [297.42200614124874]  [8365645.679946916]  [215674337.66412026]
# fold_4   [290.50882307810343]   [8454315.71339073]  [218410495.73813957]
# fold_5   [302.50995852746917]  [8320926.917106697]  [216814520.31966653]
# fold_6    [296.5227040294539]  [8900416.018479113]  [231735060.46655792]
# fold_7    [286.4516227801592]  [8199859.198191839]  [212366746.34123906]
# fold_8   [291.45198895592597]  [8915604.604000445]  [238236136.11995432]
# fold_9   [286.61640889070986]  [8375232.335531646]  [219707894.57672152]
# fold_10  [299.55693475584735]  [8747687.377840146]  [228683222.26307344]
#
#                      avgSpeed      avgSpellDuration               totalHP  \
# fold_1   [436.62667849861214]  [100762.14090379392]  [22315.353096034283]
# fold_2   [435.78604643268744]  [105158.81799928837]  [26611.039730686498]
# fold_3    [508.2837929351699]  [102235.32515749196]  [26057.842062469193]
# fold_4    [515.7742985704888]   [93884.94994415599]  [21472.978584068485]
# fold_5    [522.9520753506929]   [99260.71324981545]  [25409.478604715354]
# fold_6    [487.1862670651951]   [96884.24042702827]    [22413.1596559485]
# fold_7    [463.9789579065445]   [95930.14153662769]  [25641.536864722315]
# fold_8     [455.881220601794]   [93887.48369546173]   [23260.94247602368]
# fold_9   [506.43041478736814]   [96939.65572110799]   [24114.93795987955]
# fold_10  [495.18339365685597]  [107872.36734732697]  [23975.809351027387]
#
#                         avgAS          abilityCount      totalProjectiles  \
# fold_1    [1919.149488054608]  [18119.976958128547]  [376.55751341818996]
# fold_2   [1889.4126481919195]  [16429.251988242835]  [350.75630457214027]
# fold_3    [1940.929226626273]   [20059.54557610143]   [357.1109105726346]
# fold_4   [1927.7173524150269]  [16594.508141599632]   [364.4859564230096]
# fold_5    [2024.692607003891]  [16174.937471123965]  [346.60727209314075]
# fold_6    [2054.486667722197]   [17572.07345610701]  [321.24036493444396]
# fold_7   [1993.0830088247653]  [15878.885196969153]   [368.5461423786189]
# fold_8   [1957.0981753050487]  [16667.003081380593]  [339.28084275590777]
# fold_9   [1977.8014361419753]  [17092.125183046894]   [377.2782341185847]
# fold_10  [2025.4366268210686]  [18048.456473796665]   [374.1879436253971]
#
#                   commonLevel             rareLevel             epicLevel
# fold_1    [432.7548054502747]  [386.89126190111966]  [1217.5413313449724]
# fold_2   [410.49973138885383]  [363.74531930618946]  [1160.3023540560193]
# fold_3    [416.3025453533189]  [369.34000335294803]  [1199.1282576664983]
# fold_4    [407.1072884275655]   [372.1613746467842]   [1188.093158603672]
# fold_5   [409.72589463469774]  [369.02338983429513]  [1195.7963416076725]
# fold_6    [432.9959371920085]   [364.8325366641795]   [1208.604040415474]
# fold_7    [406.8355737549688]     [384.22861566767]  [1161.8539829223575]
# fold_8    [402.3778380067081]   [354.2971799778599]  [1172.4760543127488]
# fold_9    [372.7746167691738]   [359.9284302149809]  [1155.8580804891556]
# fold_10   [424.7268772664086]  [368.77626969693085]  [1180.6416896002127]

# %%
metricsComparison['KNN+KBEST and chi2'] = [accuracies]

mean_kbest_unsmoted
# Out:
#   fit_time score_time test_Accuracy test_Precision test_Recall test_F-Measure
# 0     0.05       0.07        55.45%         54.23%      55.45%         53.89%

# %% [markdown]
# ### KBEST SELECTOR WITH MUTUAL INFO CLASSIFIER

# %% [markdown]
# ###### SMOTED

# %%
kbest_smoted_mutual_ = cross_validate(kbest_smoted_mutual, X, y, scoring=scoring, cv=skf, n_jobs=8, return_estimator=True)
kbest_smoted_mutual_scores, kbest_smoted_mutual_estimators, accuracies = converter(kbest_smoted_mutual_)

kbest_smoted_mutual_features = feat_extraction(kbest_smoted_mutual_estimators)
kbest_smoted_mutual_features
# Out:
#                   conf_synergy           lift_synergy               levelSum  \
# fold_1   [0.18399190599295667]  [0.18021169969855255]  [0.07570441143689655]
# fold_2   [0.18501653641224158]  [0.17760788350373846]  [0.07088563660476588]
# fold_3   [0.17858206565652757]  [0.17675038287817757]  [0.07888235322596504]
# fold_4     [0.183120287935868]  [0.17153550340602441]                    NaN
# fold_5    [0.1806178956700446]  [0.18120675046515067]  [0.07407105684830495]
# fold_6    [0.1652242536705133]  [0.17406218462336498]  [0.08146051575846691]
# fold_7   [0.18071676153820682]  [0.17799755988885946]  [0.07875296961627698]
# fold_8   [0.17827835283765392]  [0.17467358094851182]  [0.07049790016098711]
# fold_9   [0.17702283276929798]  [0.16763054111232023]  [0.07352184295701947]
# fold_10  [0.18924474797863833]   [0.1823964765331776]  [0.08234115101638695]
#
#                       avgSpeed       avgSpellDuration                totalHP  \
# fold_1   [0.11181162768543995]  [0.20379224038908195]  [0.17577825351752985]
# fold_2    [0.1096339009707894]   [0.1981951499720076]  [0.16998609083514604]
# fold_3   [0.11310587508229064]  [0.20149886998439204]  [0.18261730904299278]
# fold_4   [0.10596932311293705]   [0.2075688304308212]  [0.18360442124726983]
# fold_5    [0.1011114075949262]  [0.20093384713121343]  [0.18090993969871483]
# fold_6   [0.10285743359980248]  [0.21015568090343573]  [0.18087318947048803]
# fold_7   [0.10756476921963354]   [0.1954271646198047]  [0.17667194057764735]
# fold_8   [0.11187090659606747]  [0.20215319026752887]  [0.18196085449935073]
# fold_9      [0.11113808651085]  [0.19537062763217583]  [0.18916729733855653]
# fold_10  [0.11858834353247705]    [0.201109061856251]   [0.1787728931607271]
#
#                       totalDMG           abilityCount       totalProjectiles  \
# fold_1   [0.12773091533277614]   [0.0879053089366526]    [0.193936290255333]
# fold_2   [0.11763021344833069]  [0.09366973611459795]   [0.1967762722113866]
# fold_3   [0.11370435054101202]   [0.0923654334490347]  [0.19835695674202536]
# fold_4   [0.11633939697765605]  [0.08911956062145565]  [0.18831548634901019]
# fold_5   [0.11484093865652123]  [0.09912652089472918]  [0.19884096554892783]
# fold_6   [0.11318611106522458]  [0.08761265059222967]   [0.1969438950830189]
# fold_7   [0.11224125733580337]  [0.08726761287101148]   [0.1910357481018896]
# fold_8    [0.1189235881883628]   [0.0908087084914817]  [0.20213998035231628]
# fold_9   [0.10993294806522624]  [0.09077798620547717]  [0.19287773251856954]
# fold_10  [0.11741085241580573]  [0.08149626252516984]  [0.20150014484317014]
#
#                    commonLevel              rareLevel              epicLevel  \
# fold_1   [0.22565401148034692]  [0.25616313833341686]   [0.3211131811356329]
# fold_2   [0.23665793140885816]  [0.25339340931524257]  [0.31539956522065205]
# fold_3   [0.23391846397780136]   [0.2505536322638662]  [0.32270903890729774]
# fold_4   [0.22690189910009595]   [0.2522994530173588]   [0.3242595455727766]
# fold_5   [0.22506214930989432]  [0.25100711158774414]  [0.31741778581632585]
# fold_6   [0.23766060276278655]  [0.25341464589351825]  [0.32084410633775695]
# fold_7   [0.23862964422230104]   [0.2555347415052489]   [0.3234114360023994]
# fold_8   [0.23760493338111655]  [0.24656571195858779]   [0.3282347117945761]
# fold_9   [0.23472162542085862]  [0.25132308009187554]  [0.32598056089080507]
# fold_10  [0.22702509131950332]   [0.2510258135565302]  [0.31956036467138893]
#
#                          spell
# fold_1                     NaN
# fold_2                     NaN
# fold_3                     NaN
# fold_4   [0.07398382187187069]
# fold_5                     NaN
# fold_6                     NaN
# fold_7                     NaN
# fold_8                     NaN
# fold_9                     NaN
# fold_10                    NaN

# %%
metricsComparison['KNN+SMOTE+KBest and mutual info'] = [accuracies]

kbest_smoted_mutual_scores
# Out:
#   fit_time score_time test_Accuracy test_Precision test_Recall test_F-Measure
# 0     1.99       0.06        55.46%         54.24%      55.46%         53.90%

# %% [markdown]
# ###### UNSMOTED

# %%
kbest_unsmoted_mutual_ = cross_validate(kbest_unsmoted_mutual, X, y, scoring=scoring, cv=skf, n_jobs=8, return_estimator=True)
kbest_unsmoted_mutual_scores, kbest_unsmoted_mutual_estimators, accuracies = converter(kbest_unsmoted_mutual_)

kbest_unsmoted_mutual_features = feat_extraction(kbest_unsmoted_mutual_estimators)
kbest_unsmoted_mutual_features
# Out:
#                   conf_synergy           lift_synergy               levelSum  \
# fold_1   [0.18107658393369275]  [0.18459534658558896]  [0.07436423542095949]
# fold_2   [0.18043896435130713]  [0.17483637694718435]  [0.07589282588238344]
# fold_3   [0.18821449645921406]   [0.1804913070915728]  [0.08109714606585605]
# fold_4   [0.17191264728400024]     [0.17114338470764]    [0.069368109357832]
# fold_5   [0.17600376896183678]  [0.17241960476993445]                    NaN
# fold_6    [0.1706890058082915]  [0.16626281189434722]  [0.06845017848289703]
# fold_7   [0.18741188331889602]  [0.17852279605974353]  [0.07517494654732548]
# fold_8   [0.17661878323891367]   [0.1750122500840403]  [0.07440610093290845]
# fold_9   [0.17645101108305106]  [0.16704662557633254]  [0.06445294587481931]
# fold_10  [0.18671480546491015]  [0.18202417810542593]   [0.0873265829028429]
#
#                       avgSpeed       avgSpellDuration                totalHP  \
# fold_1   [0.10559310575732717]  [0.20071975216879956]  [0.18549796806149121]
# fold_2   [0.10389734394412575]  [0.19700176542808756]  [0.17504233065490915]
# fold_3   [0.11710185037393095]  [0.19995439193936138]  [0.17893376107524928]
# fold_4    [0.1093015336125267]  [0.20726392983755382]  [0.18344792912018204]
# fold_5   [0.11361601952093925]   [0.2015202653551944]  [0.18160990654871867]
# fold_6   [0.11807853285161718]  [0.20642707562893614]  [0.18083972089814293]
# fold_7   [0.10854322861331545]  [0.20095872731341347]  [0.18206453342996576]
# fold_8   [0.10905187590290621]  [0.20173728372683963]  [0.18388769463724897]
# fold_9   [0.10263728675958594]  [0.19715092270841894]  [0.18504693469756983]
# fold_10  [0.12015716338765348]  [0.19668223729532386]  [0.17947710593533284]
#
#                       totalDMG           abilityCount       totalProjectiles  \
# fold_1   [0.11121873391293535]  [0.09158206976664629]  [0.20164618421652358]
# fold_2   [0.11152439096498723]  [0.08406554229669938]  [0.19232896660097065]
# fold_3   [0.11796358417175234]  [0.10010288186978555]   [0.2089240457208228]
# fold_4   [0.10826427012579964]  [0.08941182279551319]  [0.19796731315705207]
# fold_5   [0.11215597480907902]  [0.09094178396166597]  [0.21485156750642442]
# fold_6    [0.1101513287450675]  [0.09350067028285602]    [0.205746939836853]
# fold_7    [0.1137570789862068]  [0.08511568386366086]  [0.20696309519238665]
# fold_8   [0.11164187276486914]   [0.0849472463086065]  [0.19743121464152158]
# fold_9   [0.11435987323967778]  [0.08264961286938188]   [0.1882585757540538]
# fold_10  [0.12128582735050153]  [0.08540171260473661]  [0.19792884751940165]
#
#                    commonLevel              rareLevel              epicLevel  \
# fold_1    [0.2326289397310466]   [0.2557996316466591]  [0.31782710592506214]
# fold_2   [0.23380689593566828]  [0.25036084066255815]  [0.31922945890059373]
# fold_3    [0.2317286547495756]   [0.2513100407689677]  [0.32382821651755367]
# fold_4    [0.2287058957073156]   [0.2523476553382178]  [0.31547365594674237]
# fold_5   [0.23573516644864778]   [0.2553973592146279]   [0.3233608917213806]
# fold_6    [0.2254069474302649]  [0.25302481067754234]  [0.31692844226900263]
# fold_7   [0.24143378718649644]  [0.25140061676677483]   [0.3197275909732602]
# fold_8   [0.22931619858125596]  [0.24687431538661664]  [0.31221890653516904]
# fold_9    [0.2326099403253561]   [0.2403661688206158]  [0.32263193928283274]
# fold_10  [0.23722460106570442]  [0.24833724533786317]  [0.32046846026577813]
#
#                          spell
# fold_1                     NaN
# fold_2                     NaN
# fold_3                     NaN
# fold_4                     NaN
# fold_5   [0.06449834276031274]
# fold_6                     NaN
# fold_7                     NaN
# fold_8                     NaN
# fold_9                     NaN
# fold_10                    NaN

# %%
metricsComparison['KNN+KBest and mutual info'] = [accuracies]

kbest_unsmoted_mutual_scores
# Out:
#   fit_time score_time test_Accuracy test_Precision test_Recall test_F-Measure
# 0     1.95       0.06        55.46%         54.24%      55.46%         53.90%

# %% [markdown]
# ### VARIANCE THRESHOLD SELECTION

# %% [markdown]
# ###### SMOTED

# %%
VT_smoted_ = cross_validate(VT_smoted, X, y, scoring=scoring, cv=skf, n_jobs=8, return_estimator=True)
VT_smoted_scores, VT_smoted_estimators, accuracies = converter(VT_smoted_)

VT_smoted_features = feat_extraction(VT_smoted_estimators, avoid_scores=True)
VT_smoted_features.transpose()
# Out:
#                  fold_1 fold_2 fold_3 fold_4 fold_5 fold_6 fold_7 fold_8  \
# troop              True   True   True   True   True   True   True   True
# spell              True   True    NaN   True   True   True    NaN   True
# common             True   True   True   True   True   True   True   True
# rare               True   True   True   True   True   True   True   True
# epic               True   True   True   True   True   True   True   True
# legendary          True   True   True   True   True   True   True   True
# conf_synergy       True   True   True   True   True   True   True   True
# lift_synergy       True   True   True   True   True   True   True   True
# levelSum           True   True   True   True   True   True   True   True
# avgSpeed           True   True   True   True   True   True   True   True
# avgSpellDuration   True   True   True   True   True   True   True   True
# totalHP            True   True   True   True   True   True   True   True
# avgAS              True   True   True   True   True   True   True   True
# totalUnitsCount    True   True   True   True   True   True   True   True
# abilityCount       True   True   True   True   True   True   True   True
# totalGroundT       True   True   True   True   True   True   True   True
# totalBuffCount     True   True   True   True   True   True   True   True
# totalProjectiles   True   True   True   True   True   True   True   True
# commonLevel        True   True   True   True   True   True   True   True
# rareLevel          True   True   True   True   True   True   True   True
# epicLevel          True   True   True   True   True   True   True   True
#
#                  fold_9 fold_10
# troop              True    True
# spell              True    True
# common             True    True
# rare               True    True
# epic               True    True
# legendary          True    True
# conf_synergy       True    True
# lift_synergy       True    True
# levelSum           True    True
# avgSpeed           True    True
# avgSpellDuration   True    True
# totalHP            True    True
# avgAS              True    True
# totalUnitsCount    True    True
# abilityCount       True    True
# totalGroundT       True    True
# totalBuffCount     True    True
# totalProjectiles   True    True
# commonLevel        True    True
# rareLevel          True    True
# epicLevel          True    True

# %%
metricsComparison['KNN+SMOTE+VT'] = [accuracies]

VT_smoted_scores
# Out:
#   fit_time score_time test_Accuracy test_Precision test_Recall test_F-Measure
# 0     0.04       0.71        55.41%         54.17%      55.41%         53.81%

# %% [markdown]
# ###### UNSMOTED

# %%
VT_unsmoted_ = cross_validate(VT_unsmoted, X, y, scoring=scoring, cv=skf, n_jobs=8, return_estimator=True)
VT_unsmoted_scores, VT_unsmoted_estimators, accuracies = converter(VT_unsmoted_)

VT_unsmoted_features = feat_extraction(VT_unsmoted_estimators, avoid_scores=True)
VT_unsmoted_features
# Out:
#         troop spell common  rare  epic legendary conf_synergy lift_synergy  \
# fold_1   True  True   True  True  True      True         True         True
# fold_2   True  True   True  True  True      True         True         True
# fold_3   True   NaN   True  True  True      True         True         True
# fold_4   True  True   True  True  True      True         True         True
# fold_5   True  True   True  True  True      True         True         True
# fold_6   True  True   True  True  True      True         True         True
# fold_7   True   NaN   True  True  True      True         True         True
# fold_8   True  True   True  True  True      True         True         True
# fold_9   True  True   True  True  True      True         True         True
# fold_10  True  True   True  True  True      True         True         True
#
#         levelSum avgSpeed  ... totalHP avgAS totalUnitsCount abilityCount  \
# fold_1      True     True  ...    True  True            True         True
# fold_2      True     True  ...    True  True            True         True
# fold_3      True     True  ...    True  True            True         True
# fold_4      True     True  ...    True  True            True         True
# fold_5      True     True  ...    True  True            True         True
# fold_6      True     True  ...    True  True            True         True
# fold_7      True     True  ...    True  True            True         True
# fold_8      True     True  ...    True  True            True         True
# fold_9      True     True  ...    True  True            True         True
# fold_10     True     True  ...    True  True            True         True
#
#         totalGroundT totalBuffCount totalProjectiles commonLevel rareLevel  \
# fold_1          True           True             True        True      True
# fold_2          True           True             True        True      True
# fold_3          True           True             True        True      True
# fold_4          True           True             True        True      True
# fold_5          True           True             True        True      True
# fold_6          True           True             True        True      True
# fold_7          True           True             True        True      True
# fold_8          True           True             True        True      True
# fold_9          True           True             True        True      True
# fold_10         True           True             True        True      True
#
#         epicLevel
# fold_1       True
# fold_2       True
# fold_3       True
# fold_4       True
# fold_5       True
# fold_6       True
# fold_7       True
# fold_8       True
# fold_9       True
# fold_10      True
#
# [10 rows x 21 columns]

# %%
metricsComparison['KNN+VT'] = [accuracies]

VT_unsmoted_scores.transpose()
# Out:
#                       0
# fit_time           0.03
# score_time         0.78
# test_Accuracy    55.43%
# test_Precision   54.20%
# test_Recall      55.43%
# test_F-Measure   53.83%

# %% [markdown]
# ### BOX PLOT OF RESULTS

# %%
final_dict = {}
for metric in metricsComparison:
    for m in metricsComparison[metric]:
        final_dict[metric] = m
mc_df = pd.DataFrame(final_dict)
mc_df.plot.box(return_type='axes', figsize=(40,20), grid=True, fontsize=14)
# Out:
# <AxesSubplot:>
