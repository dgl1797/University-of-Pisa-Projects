# %% [markdown]
# ## ANALYSIS WITH LEVEL

# %%
import pandas as pd
import numpy as np

# 76,42% -> classico
# 76,22% -> kbest

ranks_df = pd.read_csv("../csv_sources/leveled_for_rarity.csv").drop(["index", "crowns"], axis="columns")
print("---------------------------------------------------")
print(ranks_df[["rank", "commonLevel"]].groupby("rank").mean())
print(ranks_df[["rank", "commonLevel"]].groupby("rank").std())
print("---------------------------------------------------")
print("---------------------------------------------------")
print(ranks_df[["rank", "rareLevel"]].groupby("rank").mean())
print(ranks_df[["rank", "rareLevel"]].groupby("rank").std())
print("---------------------------------------------------")
print("---------------------------------------------------")
print(ranks_df[["rank", "epicLevel"]].groupby("rank").mean())
print(ranks_df[["rank", "epicLevel"]].groupby("rank").std())
print("---------------------------------------------------")
print("---------------------------------------------------")
print(ranks_df[["rank", "legendaryLevel"]].groupby("rank").mean())
print(ranks_df[["rank", "legendaryLevel"]].groupby("rank").std())
print("---------------------------------------------------")
print("---------------------------------------------------")
print(ranks_df[["rank", "troop"]].groupby("rank").mean())
print(ranks_df[["rank", "troop"]].groupby("rank").std())
print("---------------------------------------------------")
print("---------------------------------------------------")
print(ranks_df[["rank", "building"]].groupby("rank").mean())
print(ranks_df[["rank", "building"]].groupby("rank").std())
print("---------------------------------------------------")
print("---------------------------------------------------")
print(ranks_df[["rank", "spell"]].groupby("rank").mean())
print(ranks_df[["rank", "spell"]].groupby("rank").std())
print("---------------------------------------------------")
print("---------------------------------------------------")
print(ranks_df[["rank", "common"]].groupby("rank").mean())
print(ranks_df[["rank", "common"]].groupby("rank").std())
print("---------------------------------------------------")
print("---------------------------------------------------")
print(ranks_df[["rank", "rare"]].groupby("rank").mean())
print(ranks_df[["rank", "rare"]].groupby("rank").std())
print("---------------------------------------------------")
print("---------------------------------------------------")
print(ranks_df[["rank", "epic"]].groupby("rank").mean())
print(ranks_df[["rank", "epic"]].groupby("rank").std())
print("---------------------------------------------------")
print("---------------------------------------------------")
print(ranks_df[["rank", "legendary"]].groupby("rank").mean())
print(ranks_df[["rank", "legendary"]].groupby("rank").std())
print("---------------------------------------------------")
print("---------------------------------------------------")
print(ranks_df[["rank", "elixir"]].groupby("rank").mean())
print(ranks_df[["rank", "elixir"]].groupby("rank").std())
print("---------------------------------------------------")
print("---------------------------------------------------")
print(ranks_df[["rank", "conf_synergy"]].groupby("rank").mean())
print(ranks_df[["rank", "conf_synergy"]].groupby("rank").std())
print("---------------------------------------------------")
print("---------------------------------------------------")
print(ranks_df[["rank", "lift_synergy"]].groupby("rank").mean())
print(ranks_df[["rank", "lift_synergy"]].groupby("rank").std())
print("---------------------------------------------------")
print("---------------------------------------------------")
print(ranks_df[["rank", "levelSum"]].groupby("rank").mean())
print(ranks_df[["rank", "levelSum"]].groupby("rank").std())
print("---------------------------------------------------")
print("---------------------------------------------------")
print(ranks_df[["rank", "avgSpeed"]].groupby("rank").mean())
print(ranks_df[["rank", "avgSpeed"]].groupby("rank").std())
print("---------------------------------------------------")
print("---------------------------------------------------")
print(ranks_df[["rank", "avgSpellDuration"]].groupby("rank").mean())
print(ranks_df[["rank", "avgSpellDuration"]].groupby("rank").std())
print("---------------------------------------------------")
print("---------------------------------------------------")
print(ranks_df[["rank", "totalHP"]].groupby("rank").mean())
print(ranks_df[["rank", "totalHP"]].groupby("rank").std())
print("---------------------------------------------------")
print("---------------------------------------------------")
print(ranks_df[["rank", "totalDMG"]].groupby("rank").mean())
print(ranks_df[["rank", "totalDMG"]].groupby("rank").std())
print("---------------------------------------------------")
print("---------------------------------------------------")
print(ranks_df[["rank", "avgAS"]].groupby("rank").mean())
print(ranks_df[["rank", "avgAS"]].groupby("rank").std())
print("---------------------------------------------------")
print("---------------------------------------------------")
print(ranks_df[["rank", "totalUnitsCount"]].groupby("rank").mean())
print(ranks_df[["rank", "totalUnitsCount"]].groupby("rank").std())
print("---------------------------------------------------")
print("---------------------------------------------------")
print(ranks_df[["rank", "abilityCount"]].groupby("rank").mean())
print(ranks_df[["rank", "abilityCount"]].groupby("rank").std())
print("---------------------------------------------------")
print("---------------------------------------------------")
print(ranks_df[["rank", "avgRange"]].groupby("rank").mean())
print(ranks_df[["rank", "avgRange"]].groupby("rank").std())
print("---------------------------------------------------")
print("---------------------------------------------------")
print(ranks_df[["rank", "totalGroundT"]].groupby("rank").mean())
print(ranks_df[["rank", "totalGroundT"]].groupby("rank").std())
print("---------------------------------------------------")
print("---------------------------------------------------")
print(ranks_df[["rank", "totalAirT"]].groupby("rank").mean())
print(ranks_df[["rank", "totalAirT"]].groupby("rank").std())
print("---------------------------------------------------")
print("---------------------------------------------------")
print(ranks_df[["rank", "totalBuildingT"]].groupby("rank").mean())
print(ranks_df[["rank", "totalBuildingT"]].groupby("rank").std())
print("---------------------------------------------------")
print("---------------------------------------------------")
print(ranks_df[["rank", "totalBuffCount"]].groupby("rank").mean())
print(ranks_df[["rank", "totalBuffCount"]].groupby("rank").std())
print("---------------------------------------------------")
print("---------------------------------------------------")
print(ranks_df[["rank", "totalProjectiles"]].groupby("rank").mean())
print(ranks_df[["rank", "totalProjectiles"]].groupby("rank").std())
print("---------------------------------------------------")
print("---------------------------------------------------")

ranks_df
# Out:
# ---------------------------------------------------
#             commonLevel
# rank
# Challenger    10.690651
# Champion      11.416195
# Master        12.300905
#             commonLevel
# rank
# Challenger     4.419529
# Champion       5.015028
# Master         4.719482
# ---------------------------------------------------
# ---------------------------------------------------
#             rareLevel
# rank
# Challenger  10.266118
# Champion    11.414667
# Master      11.938400
#             rareLevel
# rank
# Challenger   3.885835
# Champion     4.244760
# Master       3.491473
# ---------------------------------------------------
# ---------------------------------------------------
#             epicLevel
# rank
# Challenger  10.159476
# Champion    11.761420
# Master      11.045602
#             epicLevel
# rank
# Challenger   3.605283
# Champion     3.542040
# Master       4.199834
# ---------------------------------------------------
# ---------------------------------------------------
#             legendaryLevel
# rank
# Challenger        9.324943
# Champion         12.168552
# Master           10.789619
#             legendaryLevel
# rank
# Challenger        4.296314
# Champion          3.124183
# Master            4.730177
# ---------------------------------------------------
# ---------------------------------------------------
#                troop
# rank
# Challenger  5.889429
# Champion    5.137143
# Master      5.368857
#                troop
# rank
# Challenger  1.115021
# Champion    0.950650
# Master      1.013316
# ---------------------------------------------------
# ---------------------------------------------------
#             building
# rank
# Challenger  0.372857
# Champion    0.508571
# Master      0.516571
#             building
# rank
# Challenger   0.55465
# Champion     0.58287
# Master       0.60342
# ---------------------------------------------------
# ---------------------------------------------------
#                spell
# rank
# Challenger  1.737714
# Champion    2.354286
# Master      2.114571
#                spell
# rank
# Challenger  0.902700
# Champion    0.688925
# Master      0.792047
# ---------------------------------------------------
# ---------------------------------------------------
#               common
# rank
# Challenger  2.013143
# Champion    2.072000
# Master      2.136571
#               common
# rank
# Challenger  1.294281
# Champion    1.376305
# Master      1.301693
# ---------------------------------------------------
# ---------------------------------------------------
#                 rare
# rank
# Challenger  2.021143
# Champion    1.655429
# Master      2.154286
#                 rare
# rank
# Challenger  1.248999
# Champion    1.116844
# Master      1.283559
# ---------------------------------------------------
# ---------------------------------------------------
#                 epic
# rank
# Challenger  2.185714
# Champion    2.470857
# Master      2.216857
#                 epic
# rank
# Challenger  1.298458
# Champion    1.577567
# Master      1.415668
# ---------------------------------------------------
# ---------------------------------------------------
#             legendary
# rank
# Challenger   1.780000
# Champion     1.801714
# Master       1.492286
#             legendary
# rank
# Challenger   1.344450
# Champion     1.019444
# Master       1.047158
# ---------------------------------------------------
# ---------------------------------------------------
#               elixir
# rank
# Challenger  3.941923
# Champion    3.663602
# Master      3.789852
#               elixir
# rank
# Challenger  0.537450
# Champion    0.489592
# Master      0.496820
# ---------------------------------------------------
# ---------------------------------------------------
#             conf_synergy
# rank
# Challenger   5166.317494
# Champion    11960.667065
# Master       8512.293683
#             conf_synergy
# rank
# Challenger  11910.223708
# Champion    16885.578943
# Master      14923.715174
# ---------------------------------------------------
# ---------------------------------------------------
#              lift_synergy
# rank
# Challenger  171762.530769
# Champion    366761.641239
# Master      273465.345554
#              lift_synergy
# rank
# Challenger  431438.047552
# Champion    543340.957634
# Master      517453.027176
# ---------------------------------------------------
# ---------------------------------------------------
#               levelSum
# rank
# Challenger   91.497714
# Champion    103.779429
# Master      103.326571
#              levelSum
# rank
# Challenger  11.262933
# Champion     0.590900
# Master       1.403027
# ---------------------------------------------------
# ---------------------------------------------------
#              avgSpeed
# rank
# Challenger  76.585816
# Champion    75.893459
# Master      77.657602
#              avgSpeed
# rank
# Challenger   9.492413
# Champion    10.364504
# Master       9.948391
# ---------------------------------------------------
# ---------------------------------------------------
#             avgSpellDuration
# rank
# Challenger          5.644639
# Champion            5.840915
# Master              6.916762
#             avgSpellDuration
# rank
# Challenger          8.355736
# Champion            6.088218
# Master              8.031840
# ---------------------------------------------------
# ---------------------------------------------------
#                 totalHP
# rank
# Challenger  8081.543429
# Champion    8247.429143
# Master      8776.516000
#                 totalHP
# rank
# Challenger  2481.123329
# Champion    2348.916699
# Master      2527.995296
# ---------------------------------------------------
# ---------------------------------------------------
#                totalDMG
# rank
# Challenger  2122.466571
# Champion    2219.544857
# Master      2306.429429
#               totalDMG
# rank
# Challenger  736.051547
# Champion    771.445512
# Master      757.911465
# ---------------------------------------------------
# ---------------------------------------------------
#                avgAS
# rank
# Challenger  1.564996
# Champion    1.717283
# Master      1.681641
#                avgAS
# rank
# Challenger  0.469242
# Champion    0.658200
# Master      0.618986
# ---------------------------------------------------
# ---------------------------------------------------
#             totalUnitsCount
# rank
# Challenger        13.337714
# Champion           9.594571
# Master            11.098000
#             totalUnitsCount
# rank
# Challenger         7.276297
# Champion           5.809535
# Master             6.554788
# ---------------------------------------------------
# ---------------------------------------------------
#             abilityCount
# rank
# Challenger      2.488857
# Champion        2.569143
# Master          2.147143
#             abilityCount
# rank
# Challenger      1.472096
# Champion        1.367807
# Master          1.312026
# ---------------------------------------------------
# ---------------------------------------------------
#                avgRange
# rank
# Challenger  2863.975000
# Champion    2976.914286
# Master      2801.794643
#               avgRange
# rank
# Challenger  637.938937
# Champion    688.172799
# Master      640.297747
# ---------------------------------------------------
# ---------------------------------------------------
#             totalGroundT
# rank
# Challenger      7.923429
# Champion        7.982286
# Master          7.953714
#             totalGroundT
# rank
# Challenger      0.275450
# Champion        0.131930
# Master          0.212836
# ---------------------------------------------------
# ---------------------------------------------------
#             totalAirT
# rank
# Challenger   4.072286
# Champion     4.089714
# Master       3.991714
#             totalAirT
# rank
# Challenger   1.023406
# Champion     0.895167
# Master       0.966835
# ---------------------------------------------------
# ---------------------------------------------------
#             totalBuildingT
# rank
# Challenger        0.910000
# Champion          0.920000
# Master            0.947429
#             totalBuildingT
# rank
# Challenger        0.750088
# Champion          0.636509
# Master            0.632168
# ---------------------------------------------------
# ---------------------------------------------------
#             totalBuffCount
# rank
# Challenger        0.672571
# Champion          0.956000
# Master            0.821143
#             totalBuffCount
# rank
# Challenger        0.711793
# Champion          0.743309
# Master            0.739224
# ---------------------------------------------------
# ---------------------------------------------------
#             totalProjectiles
# rank
# Challenger          1.123714
# Champion            1.377429
# Master              1.324000
#             totalProjectiles
# rank
# Challenger          0.850908
# Champion            0.865062
# Master              0.866740
# ---------------------------------------------------
# ---------------------------------------------------
#              rank  troop  building  spell  common  rare  epic  legendary  \
# 0      Challenger      5         0      3       1     1     4          2
# 1      Challenger      5         1      2       1     2     3          2
# 2          Master      7         1      0       3     3     2          0
# 3      Challenger      7         0      1       4     2     1          1
# 4      Challenger      5         0      3       1     1     5          1
# ...           ...    ...       ...    ...     ...   ...   ...        ...
# 10495    Champion      5         1      2       0     4     4          0
# 10496    Champion      6         0      2       1     2     3          2
# 10497    Champion      6         0      2       2     1     2          3
# 10498    Champion      5         1      2       4     2     1          1
# 10499    Champion      6         0      2       0     1     6          1
#
#        elixir  conf_synergy  ...  avgRange  totalGroundT  totalAirT  \
# 0       3.375   2865.990531  ...   2712.50             8          3
# 1       4.250   3980.516610  ...   2018.75             7          5
# 2       4.875      0.000000  ...   1925.00             8          2
# 3       3.750   1389.332225  ...   4175.00             8          6
# 4       4.500   4049.013035  ...   3056.25             8          4
# ...       ...           ...  ...       ...           ...        ...
# 10495   3.625   2191.588585  ...   2800.00             8          4
# 10496   4.000  26569.219252  ...   2581.25             8          4
# 10497   3.750   2671.736517  ...   2275.00             8          4
# 10498   3.125  14365.842341  ...   3868.75             8          3
# 10499   4.625   3303.615309  ...   3006.25             8          5
#
#        totalBuildingT  totalBuffCount  totalProjectiles  commonLevel  \
# 0                   0               0                 3        11.00
# 1                   1               2                 0        13.00
# 2                   2               0                 0        13.00
# 3                   0               0                 1        13.00
# 4                   1               2                 1        13.00
# ...               ...             ...               ...          ...
# 10495               1               1                 1         0.00
# 10496               1               2                 0        13.00
# 10497               1               1                 1        13.00
# 10498               1               0                 2        16.25
# 10499               1               0                 2         0.00
#
#        rareLevel  epicLevel  legendaryLevel
# 0           11.0      10.25            10.5
# 1           13.0      13.00            13.0
# 2           13.0      13.00             0.0
# 3           13.0      13.00            13.0
# 4           13.0      13.00            13.0
# ...          ...        ...             ...
# 10495       13.0      13.00             0.0
# 10496       13.0      13.00            13.0
# 10497       13.0      13.00            13.0
# 10498       13.0       0.00            13.0
# 10499       13.0      13.00            13.0
#
# [10500 rows x 29 columns]

# %%
from sklearn.model_selection import StratifiedKFold
from imblearn.pipeline import Pipeline
from imblearn.over_sampling import SMOTE
from sklearn.feature_selection import SelectKBest, chi2, mutual_info_classif, VarianceThreshold
from sklearn.metrics import classification_report, plot_confusion_matrix
from sklearn.model_selection import cross_validate, cross_val_predict
from sklearn.tree import DecisionTreeClassifier
from random import randrange
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn.metrics import make_scorer
from sklearn.ensemble import RandomForestClassifier

y = np.array([x for x in ranks_df["rank"]])
X = np.array([x for x in ranks_df.drop(["rank"], axis="columns").values])

scoring = {
    'Accuracy': make_scorer(accuracy_score),
    'Precision': make_scorer(precision_score, average='macro', zero_division=0),
    'Recall': make_scorer(recall_score, average="macro", zero_division=0),
    'F-Measure': make_scorer(f1_score, average="macro", zero_division=0)
}

def converter(df):
    scores = {
        'fit_time': df['fit_time'],
        'score_time': df['score_time'],
        'test_Accuracy': df['test_Accuracy'],
        'test_Precision': df['test_Precision'],
        'test_Recall': df['test_Recall'],
        'test_F-Measure': df['test_F-Measure']
    }
    estimators = df['estimator']
    accuracies = df['test_Accuracy']
    for key in scores.keys():
        if "test_" in key:
            scores[key] = [f"{scores[key].mean() * 100: .2f}%"]
        else:
            scores[key] = [f"{scores[key].mean(): .2f}"]
    return [pd.DataFrame(scores), estimators, accuracies]

def feat_extraction(estimators, avoid_scores = False):
    features_per_fold = {}
    fold_index = 0
    for estim in estimators:
        fold_index += 1
        feature = 0
        sel_features = {}
        feat_scores = []
        if not avoid_scores:
            feat_scores = estim['feat_sel'].scores_
        for selected in estim['feat_sel'].get_support():
            feature+=1
            if(selected == True):
                if len(feat_scores) > 0:
                    sel_features[ranks_df.columns[feature]] = [feat_scores[feature-1]]
                else:
                    sel_features[ranks_df.columns[feature]] = True
        features_per_fold[f"fold_{fold_index}"] = sel_features
    return pd.DataFrame(features_per_fold).transpose()

skf = StratifiedKFold(n_splits=10, shuffle=True)

# %% [markdown]
# ### ANALYSIS

# %%
n_estim = 200

smoted_pipeline = Pipeline([
    ('sampler', SMOTE()),
    ('clf', RandomForestClassifier(n_estimators=n_estim))
])
# fold_1                      NaN                     NaN
# fold_2    [0.02443833535042539]                     NaN
# fold_3                      NaN  [0.016298778522624957]
# fold_4    [0.02567959699291622]                     NaN
# fold_5                      NaN                     NaN
# fold_6   [0.018762764601034654]                     NaN
# fold_7                      NaN                     NaN
# fold_8                      NaN                     NaN
# fold_9                      NaN                     NaN
# fold_10   [0.02527360730078776]                     NaN
#
#                  totalBuildingT        totalProjectiles  \
# fold_1                      NaN                     NaN
# fold_2                      NaN                     NaN
# fold_3   [0.014592427469061864]                     NaN
# fold_4                      NaN                     NaN
# fold_5                      NaN   [0.01885125020619194]
# fold_6                      NaN                     NaN
# fold_7                      NaN                     NaN
# fold_8                      NaN  [0.012407839764243533]
# fold_9                      NaN                     NaN
# fold_10                     NaN                     NaN
#
#                  totalBuffCount
# fold_1                      NaN
# fold_2                      NaN
# fold_3                      NaN
# fold_4                      NaN
# fold_5                      NaN
# fold_6                      NaN
# fold_7    [0.01993583243296948]
# fold_8                      NaN
# fold_9   [0.020420731862849095]
# fold_10  [0.023869069518810182]
#
# [10 rows x 25 columns]

# %%
metricsComparison['RF + SMOTE + KBEST and mutual_info'] = [accuracies]

kbest_smoted_mutual_scores
# Out:
#   fit_time score_time test_Accuracy test_Precision test_Recall test_F-Measure
# 0     6.30       0.17        76.06%         77.01%      76.06%         76.29%

# %% [markdown]
# ###### UNSMOTED

# %%
kbest_unsmoted_mutual_ = cross_validate(kbest_unsmoted_mutual, X, y, scoring=scoring, cv=skf, n_jobs=8, return_estimator=True)
kbest_unsmoted_mutual_scores, kbest_unsmoted_mutual_estimators, accuracies = converter(kbest_unsmoted_mutual_)

kbest_unsmoted_mutual_features = feat_extraction(kbest_unsmoted_mutual_estimators)
kbest_unsmoted_mutual_features
# Out:
#                           troop                   spell  \
# fold_1    [0.05465228582802428]   [0.07005369060794298]
# fold_2   [0.057579752056504674]   [0.06380743525717714]
# fold_3    [0.06921768734948697]   [0.06369566864242282]
# fold_4    [0.07036119645876115]   [0.06617051994628542]
# fold_5   [0.061916537778565095]   [0.05959312319137955]
# fold_6    [0.06726446608190861]   [0.06340471678428417]
# fold_7    [0.06495293389671031]   [0.06173084131138329]
# fold_8    [0.05844589726790583]  [0.057481821671670597]
# fold_9   [0.049640157925839645]   [0.06081698207267694]
# fold_10  [0.051453008954385426]  [0.059184757681456146]
#
#                            rare               legendary  \
# fold_1   [0.018387994739592184]  [0.018901149367755554]
# fold_2                      NaN   [0.01999215306691271]
# fold_3   [0.028663790513955956]   [0.01552799365400892]
# fold_4    [0.02540499441363453]   [0.02388076422873686]
# fold_5                      NaN   [0.02297851734449763]
# fold_6    [0.02359378661505196]                     NaN
# fold_7                      NaN   [0.01785195346631463]
# fold_8   [0.017132178594716496]  [0.020979606544288654]
# fold_9   [0.019414411037447454]  [0.019940407284397832]
# fold_10  [0.028770966499876094]  [0.018544379753609785]
#
#                          elixir           conf_synergy           lift_synergy  \
# fold_1   [0.037690639316483976]   [0.1840135087302721]  [0.17923134533467522]
# fold_2    [0.03928199059980231]  [0.17808655023533237]  [0.18537097320918616]
# fold_3     [0.0462051229260656]   [0.1693571201050348]  [0.16955180306446738]
# fold_4    [0.05157773015442557]  [0.17796231363832504]  [0.17640143285729515]
# fold_5    [0.05005694525841431]   [0.1820965371593437]   [0.1824937852431081]
# fold_6   [0.038776496288543294]  [0.18054042377179824]  [0.18209968413740185]
# fold_7    [0.04150349884858362]  [0.17846471710446532]  [0.17562826171058998]
# fold_8   [0.041125473811951085]  [0.18071649530042855]  [0.18217943151014127]
# fold_9    [0.03427558293549393]  [0.18304337186325959]   [0.1808788745454306]
# fold_10   [0.04925897495943676]   [0.1750331348186125]   [0.1770942498036714]
#
#                       levelSum               avgSpeed       avgSpellDuration  \
# fold_1   [0.35671720841210286]  [0.09209631464171064]  [0.12182419997338512]
# fold_2    [0.3427980323116373]  [0.08327687282485896]  [0.10055573439605392]
# fold_3    [0.3372594881996933]  [0.07290398732740955]  [0.11629037342729132]
# fold_4   [0.33728677817016983]  [0.08643978276943431]  [0.11214981010193226]
# fold_5   [0.33358815214477233]  [0.08077548887996877]    [0.107285534342626]
# fold_6    [0.3375433867013893]  [0.08517017575586938]  [0.10817452686713591]
# fold_7   [0.33668409308187974]  [0.07476083542620726]  [0.11471232876245807]
# fold_8    [0.3465917243803094]    [0.073429671205403]  [0.10643043853371625]
# fold_9   [0.34629585231498616]  [0.08360047090942735]  [0.11302112969536116]
# fold_10  [0.33825518321280845]  [0.07706809112047819]  [0.11417946202565643]
#
#          ...               avgRange          totalBuffCount  \
# fold_1   ...  [0.08469460378650262]  [0.027961136116545493]
# fold_2   ...  [0.08773679972706283]  [0.022863985093523054]
# fold_3   ...  [0.09504331337835192]  [0.014531675098615526]
# fold_4   ...  [0.08111409856376595]                     NaN
# fold_5   ...  [0.09365001672182394]                     NaN
# fold_6   ...  [0.09151471504167508]   [0.02513723066404161]
# fold_7   ...   [0.0822800080276227]                     NaN
# fold_8   ...  [0.09232632192420098]                     NaN
# fold_9   ...  [0.09603341283767541]   [0.01740644340886499]
# fold_10  ...  [0.08396697153669774]                     NaN
#
#                    commonLevel              rareLevel              epicLevel  \
# fold_1   [0.20149384655337088]  [0.22917713860447075]   [0.2501908331166578]
# fold_2     [0.193379002790653]   [0.2398835527690628]    [0.251455241009932]
# fold_3   [0.18719301710283753]  [0.23661909868125597]   [0.2581070906761662]
# fold_4   [0.20194989406667485]  [0.23152994717759356]  [0.24739712469603403]
# fold_5    [0.2042401639944904]  [0.23136656162006153]   [0.2465027914502489]
# fold_6   [0.19004433359042916]   [0.2414315573654049]  [0.24898689532700669]
# fold_7    [0.1960548371369184]  [0.23473739709878028]  [0.23869829455616465]
# fold_8   [0.19761723481808446]  [0.23795030080241308]   [0.2469569086968315]
# fold_9   [0.20546090609895162]   [0.2317583254327067]  [0.25692297602508907]
# fold_10  [0.19420397794765565]   [0.2349256896280889]   [0.2531762285994663]
#
#                 legendaryLevel                building  \
# fold_1   [0.32790057701560094]                     NaN
# fold_2   [0.31872924271114234]  [0.018820023840624867]
# fold_3     [0.317269009217265]                     NaN
# fold_4    [0.3135839557373876]                     NaN
# fold_5    [0.3186162858284036]  [0.012168421034164378]
# fold_6    [0.3293541407914635]                     NaN
# fold_7   [0.32036782479318093]                     NaN
# fold_8    [0.3183430253596231]                     NaN
# fold_9    [0.3230099282382599]                     NaN
# fold_10  [0.32787799218318603]                     NaN
#
#                    abilityCount              totalAirT                   epic
# fold_1                      NaN                    NaN                    NaN
# fold_2                      NaN                    NaN                    NaN
# fold_3                      NaN                    NaN                    NaN
# fold_4   [0.021907661016881796]                    NaN                    NaN
# fold_5     [0.0130043060885483]                    NaN                    NaN
# fold_6   [0.024777888556785088]                    NaN                    NaN
# fold_7    [0.01789763219095697]  [0.01542706258284321]                    NaN
# fold_8   [0.017194469170811466]                    NaN                    NaN
# fold_9                      NaN                    NaN                    NaN
# fold_10                     NaN                    NaN  [0.01517235789517013]
#
# [10 rows x 24 columns]

# %%
import matplotlib.pyplot as plt

plot_confusion_matrix(kbest_unsmoted_mutual_estimators[0], X, y)
plot_confusion_matrix(kbest_unsmoted_mutual_estimators[1], X, y)
plot_confusion_matrix(kbest_unsmoted_mutual_estimators[2], X, y)
plot_confusion_matrix(kbest_unsmoted_mutual_estimators[3], X, y)
plot_confusion_matrix(kbest_unsmoted_mutual_estimators[4], X, y)
plot_confusion_matrix(kbest_unsmoted_mutual_estimators[5], X, y)
plot_confusion_matrix(kbest_unsmoted_mutual_estimators[6], X, y)
plot_confusion_matrix(kbest_unsmoted_mutual_estimators[7], X, y)
plot_confusion_matrix(kbest_unsmoted_mutual_estimators[8], X, y)
plot_confusion_matrix(kbest_unsmoted_mutual_estimators[9], X, y)
plt.show()

# %%
metricsComparison['RF + KBEST and mutual_info'] = [accuracies]

kbest_unsmoted_mutual_scores
# Out:
#   fit_time score_time test_Accuracy test_Precision test_Recall test_F-Measure
# 0     6.64       0.15        76.03%         77.03%      76.03%         76.26%

# %% [markdown]
# ### VARIANCE THRESHOLD SELECTION

# %% [markdown]
# ###### SMOTED

# %%
VT_smoted_ = cross_validate(VT_smoted, X, y, scoring=scoring, cv=skf, n_jobs=8, return_estimator=True)
VT_smoted_scores, VT_smoted_estimators, accuracies = converter(VT_smoted_)

VT_smoted_features = feat_extraction(VT_smoted_estimators, avoid_scores=True)
VT_smoted_features
# Out:
#         troop common  rare  epic legendary conf_synergy lift_synergy levelSum  \
# fold_1   True   True  True  True      True         True         True     True
# fold_2   True   True  True  True      True         True         True     True
# fold_3   True   True  True  True      True         True         True     True
# fold_4   True   True  True  True      True         True         True     True
# fold_5   True   True  True  True      True         True         True     True
# fold_6   True   True  True  True      True         True         True     True
# fold_7   True   True  True  True      True         True         True     True
# fold_8   True   True  True  True      True         True         True     True
# fold_9   True   True  True  True      True         True         True     True
# fold_10  True   True  True  True      True         True         True     True
#
#         avgSpeed avgSpellDuration  ... totalUnitsCount abilityCount avgRange  \
# fold_1      True             True  ...            True         True     True
# fold_2      True             True  ...            True         True     True
# fold_3      True             True  ...            True         True     True
# fold_4      True             True  ...            True         True     True
# fold_5      True             True  ...            True         True     True
# fold_6      True             True  ...            True         True     True
# fold_7      True             True  ...            True         True     True
# fold_8      True             True  ...            True         True     True
# fold_9      True             True  ...            True         True     True
# fold_10     True             True  ...            True         True     True
#
#         totalAirT totalProjectiles commonLevel rareLevel epicLevel  \
# fold_1       True             True        True      True      True
# fold_2       True             True        True      True      True
# fold_3       True             True        True      True      True
# fold_4       True             True        True      True      True
# fold_5       True             True        True      True      True
# fold_6       True             True        True      True      True
# fold_7       True             True        True      True      True
# fold_8       True             True        True      True      True
# fold_9       True             True        True      True      True
# fold_10      True             True        True      True      True
#
#         legendaryLevel spell
# fold_1            True   NaN
# fold_2            True  True
# fold_3            True  True
# fold_4            True  True
# fold_5            True  True
# fold_6            True  True
# fold_7            True  True
# fold_8            True   NaN
# fold_9            True  True
# fold_10           True  True
#
# [10 rows x 22 columns]

# %%
metricsComparison['RF + SMOTE + Variance Threshold'] = [accuracies]

VT_smoted_scores
# Out:
#   fit_time score_time test_Accuracy test_Precision test_Recall test_F-Measure
# 0     3.60       0.14        75.80%         76.76%      75.80%         76.04%

# %% [markdown]
# ###### UNSMOTED

# %%
VT_unsmoted_ = cross_validate(VT_unsmoted, X, y, scoring=scoring, cv=skf, n_jobs=8, return_estimator=True)
VT_unsmoted_scores, VT_unsmoted_estimators, accuracies = converter(VT_unsmoted_)

VT_unsmoted_features = feat_extraction(VT_unsmoted_estimators, avoid_scores=True)
VT_unsmoted_features
# Out:
#         troop spell common  rare  epic legendary conf_synergy lift_synergy  \
# fold_1   True  True   True  True  True      True         True         True
# fold_2   True   NaN   True  True  True      True         True         True
# fold_3   True  True   True  True  True      True         True         True
# fold_4   True   NaN   True  True  True      True         True         True
# fold_5   True  True   True  True  True      True         True         True
# fold_6   True  True   True  True  True      True         True         True
# fold_7   True  True   True  True  True      True         True         True
# fold_8   True  True   True  True  True      True         True         True
# fold_9   True  True   True  True  True      True         True         True
# fold_10  True  True   True  True  True      True         True         True
#
#         levelSum avgSpeed  ... totalDMG totalUnitsCount abilityCount avgRange  \
# fold_1      True     True  ...     True            True         True     True
# fold_2      True     True  ...     True            True         True     True
# fold_3      True     True  ...     True            True         True     True
# fold_4      True     True  ...     True            True         True     True
# fold_5      True     True  ...     True            True         True     True
# fold_6      True     True  ...     True            True         True     True
# fold_7      True     True  ...     True            True         True     True
# fold_8      True     True  ...     True            True         True     True
# fold_9      True     True  ...     True            True         True     True
# fold_10     True     True  ...     True            True         True     True
#
#         totalAirT totalProjectiles commonLevel rareLevel epicLevel  \
# fold_1       True             True        True      True      True
# fold_2       True             True        True      True      True
# fold_3       True             True        True      True      True
# fold_4       True             True        True      True      True
# fold_5       True             True        True      True      True
# fold_6       True             True        True      True      True
# fold_7       True             True        True      True      True
# fold_8       True             True        True      True      True
# fold_9       True             True        True      True      True
# fold_10      True             True        True      True      True
#
#         legendaryLevel
# fold_1            True
# fold_2            True
# fold_3            True
# fold_4            True
# fold_5            True
# fold_6            True
# fold_7            True
# fold_8            True
# fold_9            True
# fold_10           True
#
# [10 rows x 22 columns]

# %%
metricsComparison['RF + Variance Threshold'] = [accuracies]

VT_unsmoted_scores
# Out:
#   fit_time score_time test_Accuracy test_Precision test_Recall test_F-Measure
# 0     3.70       0.14        75.92%         76.90%      75.92%         76.17%

# %% [markdown]
# ### BOX PLOT OF RESULTS

# %%
final_dict = {}
for metric in metricsComparison:
    for m in metricsComparison[metric]:
        final_dict[metric] = m
mc_df = pd.DataFrame(final_dict)
mc_df.plot.box(return_type='axes', figsize=(40,20), grid=True, fontsize=14)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## ANALYSIS WITHOUT LEVEL

# %%
ranks_nolevel_df = ranks_df.drop(["levelSum"], axis="columns")
ranks_nolevel_df
# Out:
#              rank  troop  building  spell  common  rare  epic  legendary  \
# 0      Challenger      5         0      3       1     1     4          2
# 1      Challenger      5         1      2       1     2     3          2
# 2          Master      7         1      0       3     3     2          0
# 3      Challenger      7         0      1       4     2     1          1
# 4      Challenger      5         0      3       1     1     5          1
# ...           ...    ...       ...    ...     ...   ...   ...        ...
# 10495    Champion      5         1      2       0     4     4          0
# 10496    Champion      6         0      2       1     2     3          2
# 10497    Champion      6         0      2       2     1     2          3
# 10498    Champion      5         1      2       4     2     1          1
# 10499    Champion      6         0      2       0     1     6          1
#
#        elixir  conf_synergy  ...  avgRange  totalGroundT  totalAirT  \
# 0       3.375   2865.990531  ...   2712.50             8          3
# 1       4.250   3980.516610  ...   2018.75             7          5
# 2       4.875      0.000000  ...   1925.00             8          2
# 3       3.750   1389.332225  ...   4175.00             8          6
# 4       4.500   4049.013035  ...   3056.25             8          4
# ...       ...           ...  ...       ...           ...        ...
# 10495   3.625   2191.588585  ...   2800.00             8          4
# 10496   4.000  26569.219252  ...   2581.25             8          4
# 10497   3.750   2671.736517  ...   2275.00             8          4
# 10498   3.125  14365.842341  ...   3868.75             8          3
# 10499   4.625   3303.615309  ...   3006.25             8          5
#
#        totalBuildingT  totalBuffCount  totalProjectiles  commonLevel  \
# 0                   0               0                 3        11.00
# 1                   1               2                 0        13.00
# 2                   2               0                 0        13.00
# 3                   0               0                 1        13.00
# 4                   1               2                 1        13.00
# ...               ...             ...               ...          ...
# 10495               1               1                 1         0.00
# 10496               1               2                 0        13.00
# 10497               1               1                 1        13.00
# 10498               1               0                 2        16.25
# 10499               1               0                 2         0.00
#
#        rareLevel  epicLevel  legendaryLevel
# 0           11.0      10.25            10.5
# 1           13.0      13.00            13.0
# 2           13.0      13.00             0.0
# 3           13.0      13.00            13.0
# 4           13.0      13.00            13.0
# ...          ...        ...             ...
# 10495       13.0      13.00             0.0
# 10496       13.0      13.00            13.0
# 10497       13.0      13.00            13.0
# 10498       13.0       0.00            13.0
# 10499       13.0      13.00            13.0
#
# [10500 rows x 28 columns]

# %%
y = np.array([x for x in ranks_nolevel_df["rank"]])
X = np.array([x for x in ranks_nolevel_df.drop(["rank"], axis="columns").values])
metricsComparison = {}

# %% [markdown]
# ### SMOTE NO ATTRIBUT SELECTION

# %%
smoted_ = cross_validate(smoted_pipeline, X, y, scoring=scoring, cv=skf, n_jobs=8, return_estimator=True)
mean_smoted, smoted_estimators, accuracies = converter(smoted_)

metricsComparison['RF+SMOTE'] = [accuracies]

mean_smoted
# Out:
#   fit_time score_time test_Accuracy test_Precision test_Recall test_F-Measure
# 0     4.40       0.15        76.30%         77.25%      76.30%         76.54%

# %% [markdown]
# ### NO SMOTE NO ATTRIBUTE SELECTION

# %%
unsmoted_ = cross_validate(unsmoted_pipeline, X, y, scoring=scoring, cv=skf, n_jobs=8, return_estimator=True)
mean_unsmoted, unsmoted_estimators, accuracies = converter(unsmoted_)

metricsComparison['RF'] = [accuracies]

mean_unsmoted
# Out:
#   fit_time score_time test_Accuracy test_Precision test_Recall test_F-Measure
# 0     3.94       0.11        76.06%         76.98%      76.06%         76.29%

# %% [markdown]
# ### SMOTE KBEST SELECTION

# %%
kbest_smoted_ = cross_validate(kbest_smoted, X, y, scoring=scoring, cv=skf, n_jobs=8, return_estimator=True)

mean_kbest_smoted, kbest_smoted_estimators, accuracies = converter(kbest_smoted_)
    
kbest_features = feat_extraction(kbest_smoted_estimators)
kbest_features
# Out:
#                         troop             building                 spell  \
# fold_1   [178.73692361299317]  [95.93230349840981]  [301.24431934493344]
# fold_2   [165.95783155856728]  [90.86908841672377]  [281.17948193940634]
# fold_3    [179.0336113314886]  [98.10516731163216]    [302.405878738222]
# fold_4   [169.17232694654865]  [83.22795115332428]   [295.1107816573795]
# fold_5   [171.65746476691965]  [83.36386306959874]   [300.0546767009676]
# fold_6    [163.4690114657577]  [80.51801495581236]  [282.12129890053694]
# fold_7   [173.47155558138184]  [95.83382654222629]  [295.06036772216555]
# fold_8    [173.9474030752547]  [82.20018075011296]   [302.7920761670761]
# fold_9   [171.01161845009878]   [88.7293796864349]   [294.3653934652554]
# fold_10   [165.2123816714095]  [85.52534666969765]  [288.19842406876796]
#
#                          rare                 epic             legendary  \
# fold_1   [207.46035708471265]  [54.96914952751529]  [113.12057003562722]
# fold_2   [209.36357695240173]                  NaN  [108.54458977407847]
# fold_3    [203.9373774776737]                  NaN  [105.91631746825944]
# fold_4   [217.97945205479454]  [70.15090319592406]  [110.68809926677946]
# fold_5   [215.07709898725906]                  NaN  [115.24924774322969]
# fold_6    [217.4939011108691]                  NaN   [110.1461490294302]
# fold_7   [223.75383110531462]  [74.09314538419017]  [110.76077990251218]
# fold_8   [219.55757906215922]  [65.96700859439979]  [112.59600575971955]
# fold_9    [221.4607207108979]  [79.54230184681988]  [110.48202880400753]
# fold_10  [227.84017915665288]  [77.21419658949121]  [114.37867830423941]
#
#                  conf_synergy          lift_synergy              avgSpeed  \
# fold_1    [8351979.718910708]  [218181596.45522955]  [472.89339578421414]
# fold_2     [8283111.69362172]   [217334576.4633414]  [494.11670655588387]
# fold_3    [8942186.662821313]  [235363631.60182598]   [472.9981585888438]
# fold_4   [8372870.5224131895]   [218075908.7602973]   [480.4520084606128]
# fold_5    [8340950.516761105]  [216491069.96760595]    [460.813308196835]
# fold_6    [8057867.713423382]  [206537988.28286788]    [403.656992941068]
# fold_7    [8623831.145189598]  [224235379.14878544]   [606.1990883613902]
# fold_8    [9210499.551268067]   [241185263.3089736]   [399.8351639315433]
# fold_9    [8354165.209926349]  [215557597.34815162]   [520.1051242499459]
# fold_10   [8626174.181636106]  [224048359.26996496]   [539.5812795259783]
#
#              avgSpellDuration  ...                 avgAS  \
# fold_1                      NaN                     NaN
# fold_2                      NaN                     NaN
# fold_3   [0.014750700149245066]                     NaN
# fold_4                      NaN  [0.013414065095366023]
# fold_5                      NaN  [0.014382954447459628]
# fold_6                      NaN                     NaN
# fold_7                      NaN                     NaN
# fold_8                      NaN   [0.02452706838982155]
# fold_9   [0.016238126024831434]  [0.015964151533626847]
# fold_10                     NaN   [0.01684014043665094]
#
#                    totalGroundT                avgRange
# fold_1                      NaN                     NaN
# fold_2                      NaN                     NaN
# fold_3                      NaN                     NaN
# fold_4                      NaN                     NaN
# fold_5    [0.01769513422381319]                     NaN
# fold_6   [0.016230179685577717]  [0.018016315536737437]
# fold_7                      NaN                     NaN
# fold_8                      NaN                     NaN
# fold_9                      NaN                     NaN
# fold_10                     NaN                     NaN
#
# [10 rows x 26 columns]

# %%
metricsComparison['RF+SMOTE+KBest and mutual info'] = [accuracies]

kbest_smoted_mutual_scores
# Out:
#   fit_time score_time test_Accuracy test_Precision test_Recall test_F-Measure
# 0     5.61       0.13        76.15%         77.00%      76.15%         76.35%

# %% [markdown]
# ###### UNSMOTED

# %%
kbest_unsmoted_mutual_ = cross_validate(kbest_unsmoted_mutual, X, y, scoring=scoring, cv=skf, n_jobs=8, return_estimator=True)
kbest_unsmoted_mutual_scores, kbest_unsmoted_mutual_estimators, accuracies = converter(kbest_unsmoted_mutual_)

kbest_unsmoted_mutual_features = feat_extraction(kbest_unsmoted_mutual_estimators)
kbest_unsmoted_mutual_features
# Out:
#                           troop                building  \
# fold_1   [0.055346252692993536]   [0.02011684005186476]
# fold_2    [0.04860425805673452]                     NaN
# fold_3   [0.054394330144331926]                     NaN
# fold_4   [0.051696367826879364]                     NaN
# fold_5   [0.058008507027983214]                     NaN
# fold_6   [0.057563266391301715]                     NaN
# fold_7   [0.058342860615262726]  [0.013127686301332986]
# fold_8     [0.0535091568523236]  [0.020399888307938152]
# fold_9    [0.06269706956602561]                     NaN
# fold_10   [0.05117845371720353]  [0.009592805255250969]
#
#                           spell                    rare  \
# fold_1    [0.06545893959835136]  [0.022750649453460836]
# fold_2    [0.06609927588186104]                     NaN
# fold_3    [0.04921492547249939]   [0.02025575730079643]
# fold_4    [0.06538101840754873]  [0.016358065984854786]
# fold_5    [0.06782884471059036]   [0.02339143050253245]
# fold_6    [0.05863452006033065]  [0.023053245232186326]
# fold_7    [0.06282839365333381]                     NaN
# fold_8    [0.04865987298568242]                     NaN
# fold_9    [0.06202950265520624]                     NaN
# fold_10  [0.061056021717885045]    [0.0192973828496652]
#
#                       legendary                  elixir  \
# fold_1   [0.019302799854195474]   [0.05665665773551165]
# fold_2   [0.033546595572303994]    [0.0494135372530915]
# fold_3                      NaN    [0.0554316663797747]
# fold_4   [0.027132555414224324]    [0.0540546978032892]
# fold_5    [0.03101113833831337]   [0.04679606051262519]
# fold_6   [0.023105220105594793]   [0.04049227482969431]
# fold_7   [0.016352761780971115]   [0.05064411340299202]
# fold_8    [0.02223710660060818]  [0.041459644714362254]
# fold_9   [0.013901556013711236]  [0.043402225251689686]
# fold_10    [0.0236481134864559]  [0.043447991935965824]
#
#                   conf_synergy           lift_synergy               levelSum  \
# fold_1    [0.1760147930652085]  [0.17743874359710854]  [0.07946192171511068]
# fold_2   [0.18040655305626463]  [0.18243242219801759]  [0.08201798570541263]
# fold_3    [0.1780542511404899]   [0.1819817327076385]  [0.07129546460397918]
# fold_4   [0.17590064685610618]   [0.1750938555232091]  [0.06933020097078613]
# fold_5   [0.18347382688662295]   [0.1712973773003863]  [0.07597057849833955]
# fold_6   [0.17787453039686296]   [0.1783865496197854]  [0.08458197700553005]
# fold_7   [0.17334585994821072]  [0.16899613149450787]   [0.0832618923196018]
# fold_8   [0.18001931358770173]   [0.1794352165723474]  [0.07560172253049369]
# fold_9    [0.1760804695682825]  [0.17165397359835688]  [0.08056206073104999]
# fold_10  [0.18623963530983456]  [0.17969077314717596]   [0.0829726579204777]
#
#                       avgSpeed  ...           abilityCount  \
# fold_1   [0.11066420190060255]  ...  [0.09279468189626816]
# fold_2   [0.09308240277207624]  ...  [0.09936726639589555]
# fold_3    [0.1073338288956367]  ...  [0.09507491261197587]
# fold_4    [0.1048624027077445]  ...  [0.08974991911664354]
# fold_5   [0.11612431660302569]  ...   [0.0836453493252205]
# fold_6   [0.10273145701902386]  ...   [0.1013310812468764]
# fold_7   [0.10538337832740097]  ...  [0.08251750611376996]
# fold_8   [0.11590922397946168]  ...  [0.09516518117396311]
# fold_9   [0.10672083830737367]  ...  [0.09626663373368416]
# fold_10  [0.11285243158881975]  ...  [0.08388879453389841]
#
#               totalProjectiles            commonLevel              rareLevel  \
# fold_1   [0.20578787841675883]  [0.22834720705444922]   [0.2597219237323325]
# fold_2   [0.18701682800856845]  [0.23037631608418674]  [0.25441616309108994]
# fold_3   [0.19856258266840832]   [0.2310568094599994]   [0.2572396004290318]
# fold_4   [0.20182009437655157]  [0.22484539375836277]  [0.25637530846283707]
# fold_5   [0.19343792860575748]   [0.2355074428453352]  [0.25233701966484334]
# fold_6     [0.190274946611382]     [0.22820274598946]  [0.26074435945476915]
# fold_7   [0.19254760941346927]    [0.239495176130595]   [0.2555287950144016]
# fold_8   [0.20814905306941456]  [0.22593537920910745]   [0.2562211344243124]
# fold_9   [0.19513330507813587]    [0.238694706000659]  [0.25596260950931127]
# fold_10  [0.19738730500040202]  [0.23015113525685793]   [0.2549613033991329]
#
#                      epicLevel                avgRange  \
# fold_1    [0.3154898610705663]                     NaN
# fold_2   [0.31847127939470266]  [0.014265347999196099]
# fold_3    [0.3250606200439585]                     NaN
# fold_4    [0.3275014295397445]                     NaN
# fold_5   [0.32004679530786295]                     NaN
# fold_6    [0.3210701316692961]                     NaN
# fold_7   [0.32783627935351745]                     NaN
# fold_8   [0.33236692774870047]                     NaN
# fold_9    [0.3129311821633227]                     NaN
# fold_10  [0.31124762180301135]                     NaN
#
#                  totalBuildingT            totalGroundT  \
# fold_1                      NaN                     NaN
# fold_2    [0.02724420737378974]                     NaN
# fold_3   [0.018938822710836245]  [0.016079094479166223]
# fold_4                      NaN                     NaN
# fold_5                      NaN                     NaN
# fold_6                      NaN                     NaN
# fold_7   [0.018251055401834027]                     NaN
# fold_8     [0.0243090160991275]                     NaN
# fold_9   [0.015616591739842534]                     NaN
# fold_10                     NaN                     NaN
#
#                  totalBuffCount                    epic
# fold_1                      NaN                     NaN
# fold_2                      NaN                     NaN
# fold_3   [0.012181929466386077]                     NaN
# fold_4                      NaN  [0.012910177219979335]
# fold_5                      NaN  [0.012679108933996375]
# fold_6                      NaN  [0.017782605134065488]
# fold_7                      NaN  [0.016947715309169276]
# fold_8                      NaN  [0.018120599898830747]
# fold_9                      NaN  [0.020014558797428528]
# fold_10                     NaN   [0.01122603455386706]
#
# [10 rows x 25 columns]

# %%
metricsComparison['RF+KBest and mutual info'] = [accuracies]

kbest_unsmoted_mutual_scores
# Out:
#   fit_time score_time test_Accuracy test_Precision test_Recall test_F-Measure
# 0     5.65       0.13        75.76%         76.65%      75.76%         75.98%

# %% [markdown]
# ### VARIANCE THRESHOLD SELECTION

# %% [markdown]
# ###### SMOTED

# %%
VT_smoted_ = cross_validate(VT_smoted, X, y, scoring=scoring, cv=skf, n_jobs=8, return_estimator=True)
VT_smoted_scores, VT_smoted_estimators, accuracies = converter(VT_smoted_)

VT_smoted_features = feat_extraction(VT_smoted_estimators, avoid_scores=True)
VT_smoted_features
# Out:
#         troop spell common  rare  epic legendary conf_synergy lift_synergy  \
# fold_1   True  True   True  True  True      True         True         True
# fold_2   True   NaN   True  True  True      True         True         True
# fold_3   True  True   True  True  True      True         True         True
# fold_4   True  True   True  True  True      True         True         True
# fold_5   True  True   True  True  True      True         True         True
# fold_6   True   NaN   True  True  True      True         True         True
# fold_7   True  True   True  True  True      True         True         True
# fold_8   True  True   True  True  True      True         True         True
# fold_9   True  True   True  True  True      True         True         True
# fold_10  True  True   True  True  True      True         True         True
#
#         levelSum avgSpeed  ... totalHP avgAS totalUnitsCount abilityCount  \
# fold_1      True     True  ...    True  True            True         True
# fold_2      True     True  ...    True  True            True         True
# fold_3      True     True  ...    True  True            True         True
# fold_4      True     True  ...    True  True            True         True
# fold_5      True     True  ...    True  True            True         True
# fold_6      True     True  ...    True  True            True         True
# fold_7      True     True  ...    True  True            True         True
# fold_8      True     True  ...    True  True            True         True
# fold_9      True     True  ...    True  True            True         True
# fold_10     True     True  ...    True  True            True         True
#
#         totalGroundT totalBuffCount totalProjectiles commonLevel rareLevel  \
# fold_1          True           True             True        True      True
# fold_2          True           True             True        True      True
# fold_3          True           True             True        True      True
# fold_4          True           True             True        True      True
# fold_5          True           True             True        True      True
# fold_6          True           True             True        True      True
# fold_7          True           True             True        True      True
# fold_8          True           True             True        True      True
# fold_9          True           True             True        True      True
# fold_10         True           True             True        True      True
#
#         epicLevel
# fold_1       True
# fold_2       True
# fold_3       True
# fold_4       True
# fold_5       True
# fold_6       True
# fold_7       True
# fold_8       True
# fold_9       True
# fold_10      True
#
# [10 rows x 21 columns]

# %%
metricsComparison['RF+SMOTE+VT'] = [accuracies]

VT_smoted_scores
# Out:
#   fit_time score_time test_Accuracy test_Precision test_Recall test_F-Measure
# 0     3.70       0.17        75.74%         76.65%      75.74%         75.96%

# %% [markdown]
# ###### UNSMOTED

# %%
VT_unsmoted_ = cross_validate(VT_unsmoted, X, y, scoring=scoring, cv=skf, n_jobs=8, return_estimator=True)
VT_unsmoted_scores, VT_unsmoted_estimators, accuracies = converter(VT_unsmoted_)

VT_unsmoted_features = feat_extraction(VT_unsmoted_estimators, avoid_scores=True)
VT_unsmoted_features
# Out:
#          troop  spell  common  rare  epic  legendary  conf_synergy  \
# fold_1    True   True    True  True  True       True          True
# fold_2    True   True    True  True  True       True          True
# fold_3    True   True    True  True  True       True          True
# fold_4    True   True    True  True  True       True          True
# fold_5    True   True    True  True  True       True          True
# fold_6    True   True    True  True  True       True          True
# fold_7    True   True    True  True  True       True          True
# fold_8    True   True    True  True  True       True          True
# fold_9    True   True    True  True  True       True          True
# fold_10   True   True    True  True  True       True          True
#
#          lift_synergy  levelSum  avgSpeed  ...  totalHP  avgAS  \
# fold_1           True      True      True  ...     True   True
# fold_2           True      True      True  ...     True   True
# fold_3           True      True      True  ...     True   True
# fold_4           True      True      True  ...     True   True
# fold_5           True      True      True  ...     True   True
# fold_6           True      True      True  ...     True   True
# fold_7           True      True      True  ...     True   True
# fold_8           True      True      True  ...     True   True
# fold_9           True      True      True  ...     True   True
# fold_10          True      True      True  ...     True   True
#
#          totalUnitsCount  abilityCount  totalGroundT  totalBuffCount  \
# fold_1              True          True          True            True
# fold_2              True          True          True            True
# fold_3              True          True          True            True
# fold_4              True          True          True            True
# fold_5              True          True          True            True
# fold_6              True          True          True            True
# fold_7              True          True          True            True
# fold_8              True          True          True            True
# fold_9              True          True          True            True
# fold_10             True          True          True            True
#
#          totalProjectiles  commonLevel  rareLevel  epicLevel
# fold_1               True         True       True       True
# fold_2               True         True       True       True
# fold_3               True         True       True       True
# fold_4               True         True       True       True
# fold_5               True         True       True       True
# fold_6               True         True       True       True
# fold_7               True         True       True       True
# fold_8               True         True       True       True
# fold_9               True         True       True       True
# fold_10              True         True       True       True
#
# [10 rows x 21 columns]

# %%
metricsComparison['RF+VT'] = [accuracies]

VT_unsmoted_scores
# Out:
#   fit_time score_time test_Accuracy test_Precision test_Recall test_F-Measure
# 0     3.58       0.13        75.90%         76.88%      75.90%         76.13%

# %% [markdown]
# ### BOX PLOT OF RESULTS

# %%
final_dict = {}
for metric in metricsComparison:
    for m in metricsComparison[metric]:
        final_dict[metric] = m
mc_df = pd.DataFrame(final_dict)
mc_df.plot.box(return_type='axes', figsize=(40,20), grid=True, fontsize=14)
# Out:
# <AxesSubplot:>
