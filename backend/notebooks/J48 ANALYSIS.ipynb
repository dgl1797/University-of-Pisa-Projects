# %% [markdown]
# ## ANALYSIS WITH LEVEL

# %%
import pandas as pd
import numpy as np

ranks_df = pd.read_csv("../csv_sources/leveled_for_rarity.csv").drop(["index", "crowns"], axis="columns")
print("---------------------------------------------------")
print(ranks_df[["rank", "troop"]].groupby("rank").mean())
print(ranks_df[["rank", "troop"]].groupby("rank").std())
print("---------------------------------------------------")
print("---------------------------------------------------")
print(ranks_df[["rank", "building"]].groupby("rank").mean())
print(ranks_df[["rank", "building"]].groupby("rank").std())
print("---------------------------------------------------")
print("---------------------------------------------------")
print(ranks_df[["rank", "spell"]].groupby("rank").mean())
print(ranks_df[["rank", "spell"]].groupby("rank").std())
print("---------------------------------------------------")
print("---------------------------------------------------")
print(ranks_df[["rank", "common"]].groupby("rank").mean())
print(ranks_df[["rank", "common"]].groupby("rank").std())
print("---------------------------------------------------")
print("---------------------------------------------------")
print(ranks_df[["rank", "rare"]].groupby("rank").mean())
print(ranks_df[["rank", "rare"]].groupby("rank").std())
print("---------------------------------------------------")
print("---------------------------------------------------")
print(ranks_df[["rank", "epic"]].groupby("rank").mean())
print(ranks_df[["rank", "epic"]].groupby("rank").std())
print("---------------------------------------------------")
print("---------------------------------------------------")
print(ranks_df[["rank", "legendary"]].groupby("rank").mean())
print(ranks_df[["rank", "legendary"]].groupby("rank").std())
print("---------------------------------------------------")
print("---------------------------------------------------")
print(ranks_df[["rank", "elixir"]].groupby("rank").mean())
print(ranks_df[["rank", "elixir"]].groupby("rank").std())
print("---------------------------------------------------")
print("---------------------------------------------------")
print(ranks_df[["rank", "conf_synergy"]].groupby("rank").mean())
print(ranks_df[["rank", "conf_synergy"]].groupby("rank").std())
print("---------------------------------------------------")
print("---------------------------------------------------")
print(ranks_df[["rank", "lift_synergy"]].groupby("rank").mean())
print(ranks_df[["rank", "lift_synergy"]].groupby("rank").std())
print("---------------------------------------------------")
print("---------------------------------------------------")
print(ranks_df[["rank", "levelSum"]].groupby("rank").mean())
print(ranks_df[["rank", "levelSum"]].groupby("rank").std())
print("---------------------------------------------------")
print("---------------------------------------------------")
print(ranks_df[["rank", "avgSpeed"]].groupby("rank").mean())
print(ranks_df[["rank", "avgSpeed"]].groupby("rank").std())
print("---------------------------------------------------")
print("---------------------------------------------------")
print(ranks_df[["rank", "avgSpellDuration"]].groupby("rank").mean())
print(ranks_df[["rank", "avgSpellDuration"]].groupby("rank").std())
print("---------------------------------------------------")
print("---------------------------------------------------")
print(ranks_df[["rank", "totalHP"]].groupby("rank").mean())
print(ranks_df[["rank", "totalHP"]].groupby("rank").std())
print("---------------------------------------------------")
print("---------------------------------------------------")
print(ranks_df[["rank", "totalDMG"]].groupby("rank").mean())
print(ranks_df[["rank", "totalDMG"]].groupby("rank").std())
print("---------------------------------------------------")
print("---------------------------------------------------")
print(ranks_df[["rank", "avgAS"]].groupby("rank").mean())
print(ranks_df[["rank", "avgAS"]].groupby("rank").std())
print("---------------------------------------------------")
print("---------------------------------------------------")
print(ranks_df[["rank", "totalUnitsCount"]].groupby("rank").mean())
print(ranks_df[["rank", "totalUnitsCount"]].groupby("rank").std())
print("---------------------------------------------------")
print("---------------------------------------------------")
print(ranks_df[["rank", "abilityCount"]].groupby("rank").mean())
print(ranks_df[["rank", "abilityCount"]].groupby("rank").std())
print("---------------------------------------------------")
print("---------------------------------------------------")
print(ranks_df[["rank", "avgRange"]].groupby("rank").mean())
print(ranks_df[["rank", "avgRange"]].groupby("rank").std())
print("---------------------------------------------------")
print("---------------------------------------------------")
print(ranks_df[["rank", "totalGroundT"]].groupby("rank").mean())
print(ranks_df[["rank", "totalGroundT"]].groupby("rank").std())
print("---------------------------------------------------")
print("---------------------------------------------------")
print(ranks_df[["rank", "totalAirT"]].groupby("rank").mean())
print(ranks_df[["rank", "totalAirT"]].groupby("rank").std())
print("---------------------------------------------------")
print("---------------------------------------------------")
print(ranks_df[["rank", "totalBuildingT"]].groupby("rank").mean())
print(ranks_df[["rank", "totalBuildingT"]].groupby("rank").std())
print("---------------------------------------------------")
print("---------------------------------------------------")
print(ranks_df[["rank", "totalBuffCount"]].groupby("rank").mean())
print(ranks_df[["rank", "totalBuffCount"]].groupby("rank").std())
print("---------------------------------------------------")
print("---------------------------------------------------")
print(ranks_df[["rank", "totalProjectiles"]].groupby("rank").mean())
print(ranks_df[["rank", "totalProjectiles"]].groupby("rank").std())
print("---------------------------------------------------")
print("---------------------------------------------------")

ranks_df
# Out:
# ---------------------------------------------------
#                troop
# rank
# Challenger  5.889429
# Champion    5.137143
# Master      5.368857
#                troop
# rank
# Challenger  1.115021
# Champion    0.950650
# Master      1.013316
# ---------------------------------------------------
# ---------------------------------------------------
#             building
# rank
# Challenger  0.372857
# Champion    0.508571
# Master      0.516571
#             building
# rank
# Challenger   0.55465
# Champion     0.58287
# Master       0.60342
# ---------------------------------------------------
# ---------------------------------------------------
#                spell
# rank
# Challenger  1.737714
# Champion    2.354286
# Master      2.114571
#                spell
# rank
# Challenger  0.902700
# Champion    0.688925
# Master      0.792047
# ---------------------------------------------------
# ---------------------------------------------------
#               common
# rank
# Challenger  2.013143
# Champion    2.072000
# Master      2.136571
#               common
# rank
# Challenger  1.294281
# Champion    1.376305
# Master      1.301693
# ---------------------------------------------------
# ---------------------------------------------------
#                 rare
# rank
# Challenger  2.021143
# Champion    1.655429
# Master      2.154286
#                 rare
# rank
# Challenger  1.248999
# Champion    1.116844
# Master      1.283559
# ---------------------------------------------------
# ---------------------------------------------------
#                 epic
# rank
# Challenger  2.185714
# Champion    2.470857
# Master      2.216857
#                 epic
# rank
# Challenger  1.298458
# Champion    1.577567
# Master      1.415668
# ---------------------------------------------------
# ---------------------------------------------------
#             legendary
# rank
# Challenger   1.780000
# Champion     1.801714
# Master       1.492286
#             legendary
# rank
# Challenger   1.344450
# Champion     1.019444
# Master       1.047158
# ---------------------------------------------------
# ---------------------------------------------------
#               elixir
# rank
# Challenger  3.941923
# Champion    3.663602
# Master      3.789852
#               elixir
# rank
# Challenger  0.537450
# Champion    0.489592
# Master      0.496820
# ---------------------------------------------------
# ---------------------------------------------------
#             conf_synergy
# rank
# Challenger   5166.317494
# Champion    11960.667065
# Master       8512.293683
#             conf_synergy
# rank
# Challenger  11910.223708
# Champion    16885.578943
# Master      14923.715174
# ---------------------------------------------------
# ---------------------------------------------------
#              lift_synergy
# rank
# Challenger  171762.530769
# Champion    366761.641239
# Master      273465.345554
#              lift_synergy
# rank
# Challenger  431438.047552
# Champion    543340.957634
# Master      517453.027176
# ---------------------------------------------------
# ---------------------------------------------------
#               levelSum
# rank
# Challenger   91.497714
# Champion    103.779429
# Master      103.326571
#              levelSum
# rank
# Challenger  11.262933
# Champion     0.590900
# Master       1.403027
# ---------------------------------------------------
# ---------------------------------------------------
#              avgSpeed
# rank
# Challenger  76.585816
# Champion    75.893459
# Master      77.657602
#              avgSpeed
# rank
# Challenger   9.492413
# Champion    10.364504
# Master       9.948391
# ---------------------------------------------------
# ---------------------------------------------------
#             avgSpellDuration
# rank
# Challenger          5.644639
# Champion            5.840915
# Master              6.916762
#             avgSpellDuration
# rank
# Challenger          8.355736
# Champion            6.088218
# Master              8.031840
# ---------------------------------------------------
# ---------------------------------------------------
#                 totalHP
# rank
# Challenger  8081.543429
# Champion    8247.429143
# Master      8776.516000
#                 totalHP
# rank
# Challenger  2481.123329
# Champion    2348.916699
# Master      2527.995296
# ---------------------------------------------------
# ---------------------------------------------------
#                totalDMG
# rank
# Challenger  2122.466571
# Champion    2219.544857
# Master      2306.429429
#               totalDMG
# rank
# Challenger  736.051547
# Champion    771.445512
# Master      757.911465
# ---------------------------------------------------
# ---------------------------------------------------
#                avgAS
# rank
# Challenger  1.564996
# Champion    1.717283
# Master      1.681641
#                avgAS
# rank
# Challenger  0.469242
# Champion    0.658200
# Master      0.618986
# ---------------------------------------------------
# ---------------------------------------------------
#             totalUnitsCount
# rank
# Challenger        13.337714
# Champion           9.594571
# Master            11.098000
#             totalUnitsCount
# rank
# Challenger         7.276297
# Champion           5.809535
# Master             6.554788
# ---------------------------------------------------
# ---------------------------------------------------
#             abilityCount
# rank
# Challenger      2.488857
# Champion        2.569143
# Master          2.147143
#             abilityCount
# rank
# Challenger      1.472096
# Champion        1.367807
# Master          1.312026
# ---------------------------------------------------
# ---------------------------------------------------
#                avgRange
# rank
# Challenger  2863.975000
# Champion    2976.914286
# Master      2801.794643
#               avgRange
# rank
# Challenger  637.938937
# Champion    688.172799
# Master      640.297747
# ---------------------------------------------------
# ---------------------------------------------------
#             totalGroundT
# rank
# Challenger      7.923429
# Champion        7.982286
# Master          7.953714
#             totalGroundT
# rank
# Challenger      0.275450
# Champion        0.131930
# Master          0.212836
# ---------------------------------------------------
# ---------------------------------------------------
#             totalAirT
# rank
# Challenger   4.072286
# Champion     4.089714
# Master       3.991714
#             totalAirT
# rank
# Challenger   1.023406
# Champion     0.895167
# Master       0.966835
# ---------------------------------------------------
# ---------------------------------------------------
#             totalBuildingT
# rank
# Challenger        0.910000
# Champion          0.920000
# Master            0.947429
#             totalBuildingT
# rank
# Challenger        0.750088
# Champion          0.636509
# Master            0.632168
# ---------------------------------------------------
# ---------------------------------------------------
#             totalBuffCount
# rank
# Challenger        0.672571
# Champion          0.956000
# Master            0.821143
#             totalBuffCount
# rank
# Challenger        0.711793
# Champion          0.743309
# Master            0.739224
# ---------------------------------------------------
# ---------------------------------------------------
#             totalProjectiles
# rank
# Challenger          1.123714
# Champion            1.377429
# Master              1.324000
#             totalProjectiles
# rank
# Challenger          0.850908
# Champion            0.865062
# Master              0.866740
# ---------------------------------------------------
# ---------------------------------------------------
#              rank  troop  building  spell  common  rare  epic  legendary  \
# 0      Challenger      5         0      3       1     1     4          2
# 1      Challenger      5         1      2       1     2     3          2
# 2          Master      7         1      0       3     3     2          0
# 3      Challenger      7         0      1       4     2     1          1
# 4      Challenger      5         0      3       1     1     5          1
# ...           ...    ...       ...    ...     ...   ...   ...        ...
# 10495    Champion      5         1      2       0     4     4          0
# 10496    Champion      6         0      2       1     2     3          2
# 10497    Champion      6         0      2       2     1     2          3
# 10498    Champion      5         1      2       4     2     1          1
# 10499    Champion      6         0      2       0     1     6          1
#
#        elixir  conf_synergy  ...  avgRange  totalGroundT  totalAirT  \
# 0       3.375   2865.990531  ...   2712.50             8          3
# 1       4.250   3980.516610  ...   2018.75             7          5
# 2       4.875      0.000000  ...   1925.00             8          2
# 3       3.750   1389.332225  ...   4175.00             8          6
# 4       4.500   4049.013035  ...   3056.25             8          4
# ...       ...           ...  ...       ...           ...        ...
# 10495   3.625   2191.588585  ...   2800.00             8          4
# 10496   4.000  26569.219252  ...   2581.25             8          4
# 10497   3.750   2671.736517  ...   2275.00             8          4
# 10498   3.125  14365.842341  ...   3868.75             8          3
# 10499   4.625   3303.615309  ...   3006.25             8          5
#
#        totalBuildingT  totalBuffCount  totalProjectiles  commonLevel  \
# 0                   0               0                 3        11.00
# 1                   1               2                 0        13.00
# 2                   2               0                 0        13.00
# 3                   0               0                 1        13.00
# 4                   1               2                 1        13.00
# ...               ...             ...               ...          ...
# 10495               1               1                 1         0.00
# 10496               1               2                 0        13.00
# 10497               1               1                 1        13.00
# 10498               1               0                 2        16.25
# 10499               1               0                 2         0.00
#
#        rareLevel  epicLevel  legendaryLevel
# 0           11.0      10.25            10.5
# 1           13.0      13.00            13.0
# 2           13.0      13.00             0.0
# 3           13.0      13.00            13.0
# 4           13.0      13.00            13.0
# ...          ...        ...             ...
# 10495       13.0      13.00             0.0
# 10496       13.0      13.00            13.0
# 10497       13.0      13.00            13.0
# 10498       13.0       0.00            13.0
# 10499       13.0      13.00            13.0
#
# [10500 rows x 29 columns]

# %%
from sklearn.model_selection import StratifiedKFold
from imblearn.pipeline import Pipeline
from imblearn.over_sampling import SMOTE
from sklearn.feature_selection import SelectKBest, chi2, mutual_info_classif, VarianceThreshold
from sklearn.metrics import classification_report
from sklearn.model_selection import cross_validate
from sklearn.tree import DecisionTreeClassifier
from sklearn import tree
from random import randrange
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn.metrics import make_scorer

y = np.array([x for x in ranks_df["rank"]])
X = np.array([x for x in ranks_df.drop(["rank"], axis="columns").values])

scoring = {
    'Accuracy': make_scorer(accuracy_score),
    'Precision': make_scorer(precision_score, average='macro', zero_division=0),
    'Recall': make_scorer(recall_score, average="macro", zero_division=0),
    'F-Measure': make_scorer(f1_score, average="macro", zero_division=0)
}

def converter(df):
    scores = {
        'fit_time': df['fit_time'],
        'score_time': df['score_time'],
        'test_Accuracy': df['test_Accuracy'],
        'test_Precision': df['test_Precision'],
        'test_Recall': df['test_Recall'],
        'test_F-Measure': df['test_F-Measure']
    }
    estimators = df['estimator']
    accuracies = df['test_Accuracy']
    for key in scores.keys():
        if "test_" in key:
            scores[key] = [f"{scores[key].mean() * 100: .2f}%"]
        else:
            scores[key] = [f"{scores[key].mean(): .2f}"]
    return [pd.DataFrame(scores), estimators, accuracies]

def feat_extraction(estimators, avoid_scores = False):
    features_per_fold = {}
    fold_index = 0
    for estim in estimators:
        fold_index += 1
        feature = 0
        sel_features = {}
        feat_scores = []
        if not avoid_scores:
            feat_scores = estim['feat_sel'].scores_
        for selected in estim['feat_sel'].get_support():
            feature+=1
            if(selected == True):
                if len(feat_scores) > 0:
                    sel_features[ranks_df.columns[feature]] = [feat_scores[feature-1]]
                else:
                    sel_features[ranks_df.columns[feature]] = True
        features_per_fold[f"fold_{fold_index}"] = sel_features
    return pd.DataFrame(features_per_fold).transpose()

skf = StratifiedKFold(n_splits=10, shuffle=True)

# %% [markdown]
# ### ANALYSIS

# %%
smoted_pipeline = Pipeline([
    ('sampler', SMOTE()),
    ('clf', DecisionTreeClassifier())
])
unsmoted_pipeline = Pipeline([
    ('clf', DecisionTreeClassifier())
])
#######################################################
kbest_smoted = Pipeline([
    ('feat_sel', SelectKBest(chi2, k=20)),
    ('sampler', SMOTE()),
    ('clf', DecisionTreeClassifier())
])
kbest_unsmoted = Pipeline([
    ('feat_sel', SelectKBest(chi2, k=20)),
    ('clf', DecisionTreeClassifier())
])
########################################################
kbest_smoted_mutual = Pipeline([
    ('feat_sel', SelectKBest(mutual_info_classif, k=20)),
    ('sampler', SMOTE()),
    ('clf', DecisionTreeClassifier())
])
kbest_unsmoted_mutual = Pipeline([
    ('feat_sel', SelectKBest(mutual_info_classif, k=20)),
    ('clf', DecisionTreeClassifier())
])
########################################################
VT_smoted = Pipeline([
    ('feat_sel', VarianceThreshold(threshold=0.7)),
    ('sampler', SMOTE()),
    ('clf', DecisionTreeClassifier())
])
VT_unsmoted = Pipeline([
    ('feat_sel', VarianceThreshold(threshold=0.7)),
    ('clf', DecisionTreeClassifier())
])

metricsComparison = {}

# %% [markdown]
# ### SMOTE NO ATTRIBUT SELECTION

# %%
smoted_ = cross_validate(smoted_pipeline, X, y, scoring=scoring, cv=skf, n_jobs=4, return_estimator=True)
mean_smoted, smoted_estimators, accuracies = converter(smoted_)

metricsComparison['J48 + SMOTE'] = [accuracies]

mean_smoted
# Out:
#   fit_time score_time test_Accuracy test_Precision test_Recall test_F-Measure
# 0     0
# totalUnitsCount    [1920.085481733157]  [1921.8340406876418]
# abilityCount      [123.69328230170252]  [131.30301693719125]
# avgRange          [16452.794101326326]   [16880.33806338346]
# totalBuffCount     [162.3482316362223]  [152.64152410575426]
# totalProjectiles   [78.21980576077033]   [88.31471660589989]
# commonLevel       [354.68294459906133]    [363.492002083223]
# rareLevel         [414.13833855938594]   [406.9152592772211]
# epicLevel         [374.10026635630504]   [380.5342277323945]
# legendaryLevel    [1154.5974581554858]  [1206.7543664283398]
#
#                                 fold_9               fold_10
# troop             [171.04155939683707]  [168.76564526431932]
# building           [88.61772727272728]   [88.30734049851361]
# spell             [295.13066175341623]  [289.35265256056425]
# rare               [229.8351762078545]   [215.3455934515689]
# legendary         [113.17874819873443]  [111.13493253373314]
# conf_synergy       [8402971.677157631]   [8910566.838500682]
# lift_synergy      [218444364.57588166]   [233898350.5425356]
# levelSum          [3065.6165803108815]  [3087.1042933435683]
# avgSpellDuration   [495.5398667524405]   [458.2735810847471]
# totalHP           [101802.57927900147]  [100250.24351723322]
# totalDMG          [27271.419668725168]   [25203.14515885718]
# totalUnitsCount    [2079.383759919526]  [2044.4953757225435]
# abilityCount      [137.10093927768224]   [128.7258758451137]
# avgRange           [17330.34225126997]  [18907.685533939184]
# totalBuffCount    [157.46226782699054]  [147.01267787839586]
# totalProjectiles   [90.13635232644936]   [90.94907944932825]
# commonLevel        [363.5460338779014]  [358.33070852159915]
# rareLevel          [396.0877325978413]  [429.73998957183005]
# epicLevel          [380.7048772091043]   [362.9650253171782]
# legendaryLevel    [1182.7660113842644]  [1225.8698106474721]

# %%
metricsComparison['J48 + KBEST and chi2'] = [accuracies]

mean_kbest_unsmoted
# Out:
#   fit_time score_time test_Accuracy test_Precision test_Recall test_F-Measure
# 0     0.12       0.02        69.89%         69.45%      69.89%         69.32%

# %% [markdown]
# ### KBEST SELECTOR WITH MUTUAL INFO CLASSIFIER

# %% [markdown]
# ###### SMOTED

# %%
kbest_smoted_mutual_ = cross_validate(kbest_smoted_mutual, X, y, scoring=scoring, cv=skf, n_jobs=4, return_estimator=True)
kbest_smoted_mutual_scores, kbest_smoted_mutual_estimators, accuracies = converter(kbest_smoted_mutual_)

kbest_smoted_mutual_features = feat_extraction(kbest_smoted_mutual_estimators)
kbest_smoted_mutual_features
# Out:
#                          troop                   spell  \
# fold_1    [0.0546932092757364]   [0.06766858260825881]
# fold_2   [0.07437179502640778]  [0.060088951002900126]
# fold_3   [0.06309138253772528]   [0.06422826160743011]
# fold_4   [0.04558608627794447]  [0.057859492417599245]
# fold_5   [0.06718243456540973]  [0.051128952808367156]
# fold_6   [0.05321239625699414]  [0.054025331188165104]
# fold_7   [0.06368365583517122]   [0.05353597716801195]
# fold_8   [0.05480854407131863]   [0.04693750449231349]
# fold_9   [0.04647187638555583]   [0.06899069585271733]
# fold_10  [0.05931234834739341]   [0.05838480861055162]
#
#                            epic               legendary  \
# fold_1    [0.01917441755873206]  [0.019935992727033724]
# fold_2    [0.02198002570909896]                     NaN
# fold_3                      NaN   [0.01700875927750589]
# fold_4                      NaN  [0.017791085271151363]
# fold_5   [0.013143170798614268]                     NaN
# fold_6                      NaN  [0.016914877200809197]
# fold_7                      NaN  [0.027639444919828504]
# fold_8   [0.017053007159758327]   [0.02560278604487043]
# fold_9    [0.01920054708300034]  [0.021664543385759627]
# fold_10  [0.014629358756773847]    [0.0239312896736803]
#
#                          elixir           conf_synergy           lift_synergy  \
# fold_1   [0.035744797618227686]   [0.1710856206482867]   [0.1771357567127021]
# fold_2     [0.0516414987518139]       [0.178311140413]   [0.1794207630026976]
# fold_3   [0.053512239996089894]  [0.17053109010678025]  [0.18077404830488897]
# fold_1                      NaN                     NaN
# fold_2                      NaN                     NaN
# fold_3                      NaN                     NaN
# fold_4   [0.023099432351824545]  [0.014534642522061159]
# fold_5                      NaN                     NaN
# fold_6                      NaN                     NaN
# fold_7                      NaN  [0.018578716757380764]
# fold_8                      NaN                     NaN
# fold_9                      NaN                     NaN
# fold_10                     NaN                     NaN
#
#                        building
# fold_1                      NaN
# fold_2                      NaN
# fold_3                      NaN
# fold_4                      NaN
# fold_5   [0.013942186321997951]
# fold_6                      NaN
# fold_7                      NaN
# fold_8                      NaN
# fold_9                      NaN
# fold_10                     NaN
#
# [10 rows x 25 columns]

# %%
metricsComparison['J48 + SMOTE + KBEST and mutual_info'] = [accuracies]

kbest_smoted_mutual_scores
# Out:
#   fit_time score_time test_Accuracy test_Precision test_Recall test_F-Measure
# 0     1.57       0.01        69.40%         68.93%      69.40%         68.73%

# %% [markdown]
# ###### UNSMOTED

# %%
kbest_unsmoted_mutual_ = cross_validate(kbest_unsmoted_mutual, X, y, scoring=scoring, cv=skf, n_jobs=4, return_estimator=True)
kbest_unsmoted_mutual_scores, kbest_unsmoted_mutual_estimators, accuracies = converter(kbest_unsmoted_mutual_)

kbest_unsmoted_mutual_features = feat_extraction(kbest_unsmoted_mutual_estimators)
kbest_unsmoted_mutual_features.transpose()
# Out:
#                                   fold_1                  fold_2  \
# troop              [0.06070706046811147]   [0.05355258743674729]
# spell              [0.05795534620518383]   [0.05386922104180636]
# rare                [0.0193461267464885]  [0.017544049376082782]
# legendary          [0.03033101136889793]   [0.02014130214526011]
# elixir             [0.05175611988993167]   [0.04921482579738701]
# conf_synergy        [0.1781019346992343]    [0.1783202361137699]
# lift_synergy       [0.17477822685822564]    [0.1794642071494179]
# levelSum            [0.3287196701573154]   [0.33708585647745504]
# avgSpeed           [0.08417156124333092]   [0.07386514609726724]
# avgSpellDuration   [0.11200073196358806]    [0.1079693380999438]
# totalHP            [0.20185781985867957]   [0.20011302643058593]
# totalDMG           [0.17747767209078913]   [0.18329355421124727]
# avgAS               [0.1154234781650394]   [0.11165557352277289]
# totalUnitsCount    [0.04330748199649803]   [0.03848239718740687]
# avgRange           [0.10072944282970919]    [0.0955643942261184]
# totalBuildingT    [0.014037194128885488]                     NaN
# commonLevel         [0.1966133990129686]   [0.19061207203638575]
# rareLevel          [0.23570981349399744]   [0.23185653122180283]
# epicLevel          [0.26019606673307316]   [0.24740961413367613]
# legendaryLevel     [0.32292880956526404]    [0.3141141543829966]
# epic                                 NaN   [0.02255481558657091]
# common                               NaN                     NaN
# totalGroundT                         NaN                     NaN
# totalBuffCount                       NaN                     NaN
# abilityCount                         NaN                     NaN
# totalAirT                            NaN                     NaN
# totalProjectiles                     NaN                     NaN
#
#                                   fold_3                  fold_4  \
# troop              [0.06177395422192733]  [0.054144504515263536]
# spell              [0.05670947132632609]   [0.05779870318186053]
# rare              [0.020570589469580014]  [0.021402464005879196]
# legendary         [0.022071710945715584]                     NaN
# elixir             [0.04669212084101404]   [0.05019954368984525]
# conf_synergy       [0.17743749710982115]    [0.1845487865012203]
# lift_synergy       [0.17011013189537105]   [0.18064006873264282]
# levelSum            [0.3284737816128125]    [0.3355567581205898]
# avgSpeed           [0.07372393702656832]   [0.07127103174922333]
# avgSpellDuration   [0.11205135353864248]   [0.11125184821609979]
# totalHP            [0.20668004587042454]   [0.21013743263736506]
# totalDMG           [0.17940915593960027]   [0.18790525210753306]
# avgAS              [0.12326017733125272]   [0.11393822634899764]
# totalUnitsCount    [0.02986903560001708]   [0.04575529089963548]
# avgRange           [0.09007983405568787]   [0.08384444655356971]
# totalBuildingT                       NaN                     NaN
# commonLevel        [0.19035457107826037]    [0.2035873896717384]
# rareLevel           [0.2266400032334157]   [0.23940585193536368]
# epicLevel            [0.250169709985117]   [0.25560913258374374]
# legendaryLevel     [0.31357751545333046]   [0.31920783937161357]
# epic                                 NaN                     NaN
# common            [0.016944963906862842]                     NaN
# totalGroundT                         NaN  [0.016991654932372313]
# totalBuffCount                       NaN  [0.014788042169592508]
# abilityCount                         NaN                     NaN
# totalAirT                            NaN                     NaN
# totalProjectiles                     NaN                     NaN
#
#                                   fold_5                  fold_6  \
# troop              [0.05443690350964858]   [0.05942560616343062]
# spell             [0.047257340313086926]   [0.04832386737556926]
# rare               [0.02047902405743285]   [0.01438080709245071]
# legendary         [0.030944071658755457]   [0.02429010077976601]
# elixir             [0.05223239862387219]     [0.037451464007767]
# conf_synergy       [0.17479596647695694]    [0.1725677072039158]
# lift_synergy       [0.17909824870289603]   [0.18021190577268964]
# levelSum            [0.3443265231930017]   [0.32967974550164514]
# avgSpeed           [0.08130353990723593]   [0.07594460769575151]
# avgSpellDuration   [0.10386123250992241]   [0.11194305057002629]
# totalHP            [0.19897393115831963]    [0.2001561737932902]
# totalDMG           [0.17864606485623113]   [0.16978853451662967]
# avgAS              [0.11366910279001696]   [0.11622319440344309]
# totalUnitsCount    [0.03827547060433867]    [0.0456955850630163]
# avgRange           [0.08900018510701879]   [0.09926346216164994]
# totalBuildingT                       NaN                     NaN
# commonLevel         [0.1977825003237932]   [0.20349819878965758]
# rareLevel           [0.2400884955705962]   [0.22652782650285852]
# epicLevel          [0.25339078861553643]    [0.2554641489095113]
# legendaryLevel     [0.31782434528099346]    [0.3153040260198372]
# epic                                 NaN  [0.018263928952042985]
# common                               NaN                     NaN
# totalGroundT                         NaN                     NaN
# totalBuffCount    [0.014687789947862573]                     NaN
# abilityCount                         NaN                     NaN
# totalAirT                            NaN                     NaN
# totalProjectiles                     NaN                     NaN
#
#                                   fold_7                  fold_8  \
# troop              [0.05116737677225758]   [0.06649712028781374]
# spell               [0.0582233137964161]   [0.06329963190913612]
# rare                                 NaN   [0.02301618367348346]
# legendary         [0.017213487071900513]  [0.029000464659074687]
# elixir              [0.0549273714894829]   [0.04438045461280504]
# conf_synergy       [0.17302304730331675]    [0.1771181854274213]
# lift_synergy       [0.17544442725438092]    [0.1765093407199405]
# levelSum           [0.33955516320724444]    [0.3332598386308927]
# avgSpeed           [0.07201267952062307]   [0.06847585871774542]
# avgSpellDuration   [0.10642030211183862]     [0.114758132015373]
# totalHP            [0.20035063262616237]   [0.20781150952116922]
# totalDMG           [0.18236620847584106]   [0.18480137802500574]
# avgAS              [0.11922847955664806]   [0.11002460535871217]
# totalUnitsCount    [0.04243311355455903]   [0.03095101627068697]
# avgRange           [0.08619650441947857]   [0.08519418093076347]
# totalBuildingT                       NaN                     NaN
# commonLevel        [0.20760428273867637]   [0.19814621815631317]
# rareLevel          [0.24267155474180702]    [0.2348086334899553]
# epicLevel          [0.25617655591883337]    [0.2541526634041096]
# legendaryLevel      [0.3267219049572889]   [0.31148491202475515]
# epic              [0.021345560795303253]                     NaN
# common                               NaN                     NaN
# totalGroundT                         NaN                     NaN
# totalBuffCount     [0.01716682833451877]                     NaN
# abilityCount                         NaN   [0.01881788609232027]
# totalAirT                            NaN                     NaN
# totalProjectiles                     NaN                     NaN
#
#                                   fold_9                 fold_10
# troop             [0.057586461573667425]   [0.05425697718904243]
# spell              [0.06380266224769682]   [0.06677121525802643]
# rare                                 NaN                     NaN
# legendary         [0.022071867025481584]   [0.02296424137355868]
# elixir             [0.05351360958349849]  [0.031315854616650096]
# conf_synergy       [0.18960844358024387]   [0.18139004130037484]
# lift_synergy       [0.17466123135312728]   [0.17976426162036985]
# levelSum            [0.3317957559641713]     [0.338432024003527]
# avgSpeed            [0.0847649749717192]   [0.07468609129035042]
# avgSpellDuration   [0.10302464030777259]   [0.10644692632289376]
# totalHP             [0.1989481469026304]    [0.1949715680905002]
# totalDMG            [0.1877621051531253]    [0.1816474961017609]
# avgAS              [0.11829391321962768]   [0.11654833352501148]
# totalUnitsCount   [0.044229432832962656]   [0.04485201505531888]
# avgRange           [0.08642095512292602]   [0.09128354266826966]
# totalBuildingT                       NaN                     NaN
# commonLevel         [0.1958799146427781]   [0.19791340908148292]
# rareLevel           [0.2308867387754061]   [0.23359721912893083]
# epicLevel          [0.23980497163619696]    [0.2559494967964582]
# legendaryLevel     [0.32332806367454303]   [0.32264972739426656]
# epic                                 NaN  [0.020010042665806527]
# common                               NaN                     NaN
# totalGroundT                         NaN                     NaN
# totalBuffCount                       NaN                     NaN
# abilityCount                         NaN   [0.02805932751326279]
# totalAirT         [0.018680472198492115]                     NaN
# totalProjectiles   [0.02009209244898358]                     NaN

# %%
metricsComparison['J48 + KBEST and mutual_info'] = [accuracies]

kbest_unsmoted_mutual_scores
# Out:
#   fit_time score_time test_Accuracy test_Precision test_Recall test_F-Measure
# 0     1.54       0.01        69.96%         69.55%      69.96%         69.34%

# %% [markdown]
# ### VARIANCE THRESHOLD SELECTION

# %% [markdown]
# ###### SMOTED

# %%
VT_smoted_ = cross_validate(VT_smoted, X, y, scoring=scoring, cv=skf, n_jobs=4, return_estimator=True)
VT_smoted_scores, VT_smoted_estimators, accuracies = converter(VT_smoted_)

VT_smoted_features = feat_extraction(VT_smoted_estimators, avoid_scores=True)
VT_smoted_features
# Out:
#         troop spell common  rare  epic legendary conf_synergy lift_synergy  \
# fold_1   True  True   True  True  True      True         True         True
# fold_2   True  True   True  True  True      True         True         True
# fold_3   True  True   True  True  True      True         True         True
# fold_4   True  True   True  True  True      True         True         True
# fold_5   True  True   True  True  True      True         True         True
# fold_6   True  True   True  True  True      True         True         True
# fold_7   True  True   True  True  True      True         True         True
# fold_8   True  True   True  True  True      True         True         True
# fold_9   True   NaN   True  True  True      True         True         True
# fold_10  True  True   True  True  True      True         True         True
#
#         levelSum avgSpeed  ... totalDMG totalUnitsCount abilityCount avgRange  \
# fold_1      True     True  ...     True            True         True     True
# fold_2      True     True  ...     True            True         True     True
# fold_3      True     True  ...     True            True         True     True
# fold_4      True     True  ...     True            True         True     True
# fold_5      True     True  ...     True            True         True     True
# fold_6      True     True  ...     True            True         True     True
# fold_7      True     True  ...     True            True         True     True
# fold_8      True     True  ...     True            True         True     True
# fold_9      True     True  ...     True            True         True     True
# fold_10     True     True  ...     True            True         True     True
#
#         totalAirT totalProjectiles commonLevel rareLevel epicLevel  \
# fold_1       True             True        True      True      True
# fold_2       True             True        True      True      True
# fold_3       True             True        True      True      True
# fold_4       True             True        True      True      True
# fold_5       True             True        True      True      True
# fold_6       True             True        True      True      True
# fold_7       True             True        True      True      True
# fold_8       True             True        True      True      True
# fold_9       True             True        True      True      True
# fold_10      True             True        True      True      True
#
#         legendaryLevel
# fold_1            True
# fold_2            True
# fold_3            True
# fold_4            True
# fold_5            True
# fold_6            True
# fold_7            True
# fold_8            True
# fold_9            True
# fold_10           True
#
# [10 rows x 22 columns]

# %%
metricsComparison['J48 + SMOTE + Variance Threshold'] = [accuracies]

VT_smoted_scores
# Out:
#   fit_time score_time test_Accuracy test_Precision test_Recall test_F-Measure
# 0     0.09       0.01        69.75%         69.29%      69.75%         69.08%

# %% [markdown]
# ###### UNSMOTED

# %%
VT_unsmoted_ = cross_validate(VT_unsmoted, X, y, scoring=scoring, cv=skf, n_jobs=4, return_estimator=True)
VT_unsmoted_scores, VT_unsmoted_estimators, accuracies = converter(VT_unsmoted_)

VT_unsmoted_features = feat_extraction(VT_unsmoted_estimators, avoid_scores=True)
VT_unsmoted_features.transpose()
# Out:
#                  fold_1 fold_2 fold_3 fold_4 fold_5 fold_6 fold_7 fold_8  \
# troop              True   True   True   True   True   True   True   True
# spell              True   True   True   True   True   True   True    NaN
# common             True   True   True   True   True   True   True   True
# rare               True   True   True   True   True   True   True   True
# epic               True   True   True   True   True   True   True   True
# legendary          True   True   True   True   True   True   True   True
# conf_synergy       True   True   True   True   True   True   True   True
# lift_synergy       True   True   True   True   True   True   True   True
# levelSum           True   True   True   True   True   True   True   True
# avgSpeed           True   True   True   True   True   True   True   True
# avgSpellDuration   True   True   True   True   True   True   True   True
# totalHP            True   True   True   True   True   True   True   True
# totalDMG           True   True   True   True   True   True   True   True
# totalUnitsCount    True   True   True   True   True   True   True   True
# abilityCount       True   True   True   True   True   True   True   True
# avgRange           True   True   True   True   True   True   True   True
# totalAirT          True   True   True   True   True   True   True   True
# totalProjectiles   True   True   True   True   True   True   True   True
# commonLevel        True   True   True   True   True   True   True   True
# rareLevel          True   True   True   True   True   True   True   True
# epicLevel          True   True   True   True   True   True   True   True
# legendaryLevel     True   True   True   True   True   True   True   True
#
#                  fold_9 fold_10
# troop              True    True
# spell               NaN    True
# common             True    True
# rare               True    True
# epic               True    True
# legendary          True    True
# conf_synergy       True    True
# lift_synergy       True    True
# levelSum           True    True
# avgSpeed           True    True
# avgSpellDuration   True    True
# totalHP            True    True
# totalDMG           True    True
# totalUnitsCount    True    True
# abilityCount       True    True
# avgRange           True    True
# totalAirT          True    True
# totalProjectiles   True    True
# commonLevel        True    True
# rareLevel          True    True
# epicLevel          True    True
# legendaryLevel     True    True

# %%
metricsComparison['J48 + Variance Threshold'] = [accuracies]

VT_unsmoted_scores
# Out:
#   fit_time score_time test_Accuracy test_Precision test_Recall test_F-Measure
# 0     0.08       0.01        69.75%         69.26%      69.75%         69.03%

# %% [markdown]
# ### BOX PLOT OF RESULTS

# %%
final_dict = {}
for metric in metricsComparison:
    for m in metricsComparison[metric]:
        final_dict[metric] = m
mc_df = pd.DataFrame(final_dict)
mc_df.plot.box(return_type='axes', figsize=(40,20), grid=True, fontsize=14)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## ANALYSIS WITHOUT LEVEL

# %%
ranks_nolevel_df = ranks_df.drop(["levelSum"], axis="columns")
ranks_nolevel_df
# Out:
#              rank  troop  building  spell  common  rare  epic  legendary  \
# 0      Challenger      5         0      3       1     1     4          2
# 1      Challenger      5         1      2       1     2     3          2
# 2          Master      7         1      0       3     3     2          0
# 3      Challenger      7         0      1       4     2     1          1
# 4      Challenger      5         0      3       1     1     5          1
# ...           ...    ...       ...    ...     ...   ...   ...        ...
# 10495    Champion      5         1      2       0     4     4          0
# 10496    Champion      6         0      2       1     2     3          2
# 10497    Champion      6         0      2       2     1     2          3
# 10498    Champion      5         1      2       4     2     1          1
# 10499    Champion      6         0      2       0     1     6          1
#
#        elixir  conf_synergy  ...  avgRange  totalGroundT  totalAirT  \
# 0       3.375   2865.990531  ...   2712.50             8          3
# 1       4.250   3980.516610  ...   2018.75             7          5
# 2       4.875      0.000000  ...   1925.00             8          2
# 3       3.750   1389.332225  ...   4175.00             8          6
# 4       4.500   4049.013035  ...   3056.25             8          4
# ...       ...           ...  ...       ...           ...        ...
# 10495   3.625   2191.588585  ...   2800.00             8          4
# 10496   4.000  26569.219252  ...   2581.25             8          4
# 10497   3.750   2671.736517  ...   2275.00             8          4
# 10498   3.125  14365.842341  ...   3868.75             8          3
# 10499   4.625   3303.615309  ...   3006.25             8          5
#
#        totalBuildingT  totalBuffCount  totalProjectiles  commonLevel  \
# 0                   0               0                 3        11.00
# 1                   1               2                 0        13.00
# 2                   2               0                 0        13.00
# 3                   0               0                 1        13.00
# 4                   1               2                 1        13.00
# ...               ...             ...               ...          ...
# 10495               1               1                 1         0.00
# 10496               1               2                 0        13.00
# 10497               1               1                 1        13.00
# 10498               1               0                 2        16.25
# 10499               1               0                 2         0.00
#
#        rareLevel  epicLevel  legendaryLevel
# 0           11.0      10.25            10.5
# 1           13.0      13.00            13.0
# 2           13.0      13.00             0.0
# 3           13.0      13.00            13.0
# 4           13.0      13.00            13.0
# ...          ...        ...             ...
# 10495       13.0      13.00             0.0
# 10496       13.0      13.00            13.0
# 10497       13.0      13.00            13.0
# 10498       13.0       0.00            13.0
# 10499       13.0      13.00            13.0
#
# [10500 rows x 28 columns]

# %%
y = np.array([x for x in ranks_nolevel_df["rank"]])
X = np.array([x for x in ranks_nolevel_df.drop(["rank"], axis="columns").values])
metricsComparison = {}

# %% [markdown]
# ### SMOTE NO ATTRIBUT SELECTION

# %%
smoted_ = cross_validate(smoted_pipeline, X, y, scoring=scoring, cv=skf, n_jobs=4, return_estimator=True)
mean_smoted, smoted_estimators, accuracies = converter(smoted_)

metricsComparison['J48+SMOTE'] = [accuracies]

mean_smoted
# Out:
#   fit_time score_time test_Accuracy test_Precision test_Recall test_F-Measure
# 0     0.10       0.01        69.45%         69.01%      69.45%         68.78%

# %% [markdown]
# ### NO SMOTE NO ATTRIBUTE SELECTION

# %%
unsmoted_ = cross_validate(unsmoted_pipeline, X, y, scoring=scoring, cv=skf, n_jobs=4, return_estimator=True)
mean_unsmoted, unsmoted_estimators, accuracies = converter(unsmoted_)

metricsComparison['J48'] = [accuracies]

mean_unsmoted
# Out:
#   fit_time score_time test_Accuracy test_Precision test_Recall test_F-Measure
# 0     0.10       0.01        69.88%         69.51%      69.88%         69.22%

# %% [markdown]
# ### SMOTE KBEST SELECTION

# %%
kbest_smoted_ = cross_validate(kbest_smoted, X, y, scoring=scoring, cv=skf, n_jobs=4, return_estimator=True)

mean_kbest_smoted, kbest_smoted_estimators, accuracies = converter(kbest_smoted_)
    
kbest_features = feat_extraction(kbest_smoted_estimators)
kbest_features.transpose()
# Out:
#                                 fold_1                fold_2  \
# troop             [174.23085701023155]  [172.00708437372975]
# building           [91.66006825938567]   [88.09413369713505]
# spell              [299.1008101733156]  [300.38261937663134]
# rare              [219.43570265870864]   [221.1553551051459]
# epic               [75.48909628534467]   [70.71143727499309]
# legendary         [104.48300131967575]  [112.35991743291424]
# conf_synergy       [8486457.559925903]   [8703403.235492408]
# lift_synergy      [218339093.58499807]   [225883263.4756267]
# avgSpeed          [500.81275818738015]   [522.2844301997416]
# avgSpellDuration  [100767.66253673298]   [98616.95131145189]
# totalHP           [25131.723838793343]  [23539.904908285236]
# avgAS             [2077.2303836478573]  [2042.0761665269629]
# totalUnitsCount   [141.56181810150625]  [129.94452015650415]
# abilityCount       [17124.51039655174]  [15818.650691942552]
# totalBuildingT    [152.94647013188518]    [156.993783993784]
# totalBuffCount     [94.32782782782782]     [91.960448691317]
# totalProjectiles  [359.91361813282094]    [334.885046975681]
# commonLevel       [417.53023751435506]   [421.9497741602406]
# rareLevel         [386.69198962971245]  [366.61339560049373]
# epicLevel          [1231.210636425394]  [1185.3532222524382]
# levelSum                           NaN                   NaN
#
#                                 fold_3                fold_4  \
# troop             [170.54677456826454]  [161.88309146920352]
# building             [84.743711760707]   [86.23275862068965]
# spell              [297.9910929101613]  [275.96945707135194]
# rare              [227.78260869565216]   [216.4252535165195]
# epic               [70.27161293306814]   [72.75370755370756]
# legendary         [120.53047446396201]  [107.92598602096855]
# conf_synergy       [7837045.151679107]   [8486629.593473222]
# lift_synergy       [201149894.7233564]  [220088383.79855686]
# avgSpeed           [472.8813716634934]   [503.1335154268771]
# rare               [199.9505997818975]  [222.43975805133235]
# epic                               NaN   [61.80148216767022]
# legendary          [110.5491231378465]  [111.04012017274833]
# conf_synergy       [8690847.734283678]     [8684318.2412157]
# lift_synergy      [226662839.21717587]  [226633080.78926295]
# avgSpeed            [415.591017397669]   [434.2988258848908]
# avgSpellDuration  [101475.83706149846]  [103883.69564777552]
# totalHP           [22305.258505534977]  [24133.283339586593]
# avgAS             [1897.1969091742524]  [1870.8336778308817]
# totalUnitsCount   [134.57294289121506]  [126.91516913319239]
# abilityCount         [17810.903964466]   [16990.67462417408]
# totalBuildingT    [144.50459071511705]    [151.251166407465]
# totalBuffCount     [90.59011772508705]    [90.7753984063745]
# totalProjectiles  [363.32960745761335]   [364.9211542780886]
# commonLevel       [403.88234427279747]   [401.5025404281383]
# rareLevel          [357.5341137265268]  [364.85106205373154]
# epicLevel         [1185.2459075994132]   [1209.856152129873]
# levelSum           [61.46548130268335]                   NaN

# %%
metricsComparison['J48+SMOTE+KBEST and chi2'] = [accuracies]

mean_kbest_smoted
# Out:
#   fit_time score_time test_Accuracy test_Precision test_Recall test_F-Measure
# 0     0.14       0.02        68.85%         68.37%      68.85%         68.18%

# %% [markdown]
# ### NO SMOTE KBEST SELECTION

# %%
kbest_unsmoted_scores = cross_validate(kbest_unsmoted, X, y, scoring=scoring, cv=skf, n_jobs=4, return_estimator=True)
mean_kbest_unsmoted, kbest_unsmoted_estimators, accuracies = converter(kbest_unsmoted_scores)

kbest_unsmoted_features = feat_extraction(kbest_unsmoted_estimators)

kbest_unsmoted_features
# Out:
#                         troop             building                 spell  \
# fold_1   [173.56332435939652]  [86.41276306856756]   [299.4660869565218]
# fold_2     [174.703614923642]  [88.94885201182088]   [303.7114683375276]
# fold_3   [172.72030666176218]  [96.36227612786217]    [292.426597051597]
# fold_4    [170.4182508033606]  [88.23376623376623]  [292.66588247327775]
# fold_5   [169.18298020684048]  [85.00567536889898]   [291.7127958693318]
# fold_6   [174.22291549595985]  [86.25266500340214]   [298.6161151960784]
# fold_7    [168.8048189970753]  [90.29793977812996]   [286.7023626879411]
# fold_8   [169.04976271186445]  [87.69431117203564]  [291.92407388509037]
# fold_9   [167.52573686045162]  [88.66470588235295]  [287.91280319312256]
# fold_10   [171.2413312423767]  [84.90503302209065]  [297.23908375089474]
#
#                          rare                 epic             legendary  \
# fold_1   [228.25616460726147]   [73.4855900448721]   [118.8274311410905]
# fold_2   [212.29679521998912]   [72.2145863201221]  [112.72905972204833]
# fold_3   [219.80406433384047]  [71.13599703346621]  [110.19223082687984]
# fold_4   [209.88556424703245]  [62.25778554671328]    [109.645382981382]
# fold_5   [230.26684812193795]  [66.86000461573967]  [107.18481806775407]
# fold_6   [206.70382477933964]                  NaN  [108.64905897114178]
# fold_7   [218.75352227601587]                  NaN  [123.79622072948712]
# fold_8    [226.4780120974334]  [81.01158443716251]  [115.17629426091302]
# fold_9   [201.01221697344843]  [63.43666789940829]  [104.30183727034121]
# fold_10  [210.86781954066885]                  NaN  [102.66783304173958]
#
#                 conf_synergy          lift_synergy              avgSpeed  \
# fold_1   [8365813.555499394]   [215676901.6035552]  [439.31482270883026]
# fold_2   [8163907.050778013]   [212246684.3531074]   [520.5777490652769]
# fold_3   [8562955.821861053]   [221128353.3954852]   [533.8427528591292]
# fold_7    [381.5660767566228]  [1189.8542541647962]    [62.6319476272308]
# fold_8    [370.7195456596452]  [1165.9824531205231]                   NaN
# fold_9   [359.18812941276747]  [1169.3613226302423]                   NaN
# fold_10  [360.14225450535395]  [1161.2542105619336]  [61.395235641611684]
#
# [10 rows x 21 columns]

# %%
metricsComparison['J48+KBEST and chi2'] = [accuracies]

mean_kbest_unsmoted
# Out:
#   fit_time score_time test_Accuracy test_Precision test_Recall test_F-Measure
# 0     0.13       0.02        69.62%         69.19%      69.62%         69.00%

# %% [markdown]
# ### KBEST SELECTOR WITH MUTUAL INFO CLASSIFIER

# %% [markdown]
# ###### SMOTED

# %%
kbest_smoted_mutual_ = cross_validate(kbest_smoted_mutual, X, y, scoring=scoring, cv=skf, n_jobs=4, return_estimator=True)
kbest_smoted_mutual_scores, kbest_smoted_mutual_estimators, accuracies = converter(kbest_smoted_mutual_)

kbest_smoted_mutual_features = feat_extraction(kbest_smoted_mutual_estimators)
kbest_smoted_mutual_features
# Out:
#                           troop                   spell  \
# fold_1    [0.05275326998251262]  [0.058362406097008046]
# fold_2    [0.05275062990663115]   [0.05594579036833691]
# fold_3    [0.05506867545581051]   [0.06639713366129563]
# fold_4    [0.06036335778533153]   [0.06603334364897528]
# fold_5    [0.05865744104668935]   [0.05587863035819329]
# fold_6   [0.060489077237006805]   [0.06715180473000859]
# fold_7     [0.0673809121084532]   [0.06353829001789624]
# fold_8   [0.041608354855948715]  [0.056020320125515166]
# fold_9    [0.05899349027530332]    [0.0644220291022346]
# fold_10   [0.05785402564799913]    [0.0659941481559918]
#
#                            rare                    epic  \
# fold_1    [0.02104484713953747]   [0.02656715045800362]
# fold_2                      NaN  [0.014558664152729328]
# fold_3                      NaN   [0.02571487628237179]
# fold_4                      NaN  [0.012784886587860811]
# fold_5   [0.018518038685651383]  [0.018018374585774932]
# fold_6   [0.023543024111998934]   [0.01649414937074356]
# fold_7                      NaN                     NaN
# fold_8   [0.017710713629768282]  [0.024558185227891993]
# fold_9    [0.02376085101639336]                     NaN
# fold_10  [0.014146255407876396]  [0.021121312210744758]
#
#                       legendary                  elixir  \
# fold_1   [0.019223718327445738]  [0.058008875845924734]
# fold_2   [0.025641023973374644]   [0.04526561219932579]
# fold_3   [0.028062338614656346]   [0.04431238070727006]
# fold_4    [0.03081976398655617]   [0.06381834985207857]
# fold_5   [0.030676023494097038]   [0.05157408310172107]
# fold_6   [0.022320636733823118]  [0.059322151083520014]
# fold_7   [0.021506739500932515]   [0.04519122420861721]
# fold_8   [0.017997626063858352]  [0.057258575413575485]
# fold_9    [0.02352377424813401]   [0.03574717133982652]
# fold_10  [0.023216138035201617]   [0.04024224675074528]
#
#                   conf_synergy           lift_synergy               levelSum  \
# fold_1    [0.1791938326703817]  [0.17741028737791642]  [0.07500583901559454]
# fold_2   [0.17451887413895584]  [0.18388003714164358]   [0.0798097535323472]
# fold_3   [0.17981645426795367]  [0.17911685894702023]  [0.08499276680964418]
# fold_4     [0.183648190774782]  [0.17482459697792896]  [0.07188898247641728]
# fold_5   [0.17442040982358886]  [0.17223278012757204]  [0.06711987778996797]
# fold_6   [0.17654039211186756]  [0.17499672285740075]  [0.08109645244212516]
# fold_7   [0.17890160700042768]   [0.1803957399552374]  [0.06986283374795543]
# fold_8   [0.18589899199805493]  [0.16852672941141988]  [0.08709445222888546]
# fold_9   [0.18222579287555551]  [0.17677698216315818]  [0.08259459457023488]
# fold_10  [0.17924908088357916]  [0.18042500230886227]  [0.07770484109840536]
#
#                       avgSpeed  ...       totalProjectiles  \
# fold_1   [0.11047834874912565]  ...  [0.19228845325969512]
# fold_2   [0.12000740769102558]  ...   [0.2000798097410721]
# fold_3   [0.11072432981774738]  ...  [0.19036227238385606]
# fold_4    [0.1147652308330871]  ...   [0.1890592355666707]
# fold_5   [0.11267411274878958]  ...  [0.19741971617171417]
# fold_6   [0.10998230014925059]  ...  [0.19146803709016114]
# fold_7   [0.11600839526807505]  ...  [0.19750660667326447]
# fold_8   [0.10867215413256415]  ...  [0.18465739225192168]
# fold_9   [0.10621209559206735]  ...   [0.2007013001768898]
# fold_10  [0.11142861819460625]  ...   [0.2020474597590447]
#
#                    commonLevel              rareLevel              epicLevel  \
# fold_1   [0.24037644918301426]   [0.2441806654064007]  [0.31737736744494716]
# fold_2   [0.23742599986981094]   [0.2439861806657313]  [0.32493773882338006]
# fold_3   [0.24631105644774332]  [0.26459216142056197]   [0.3195087738041229]
# fold_4   [0.22584558813777433]   [0.2461226648662449]  [0.32053818019702573]
# fold_5   [0.23236119418105594]   [0.2553549109606723]   [0.3230691144037665]
# fold_6    [0.2373243382561916]   [0.2491651377815467]  [0.31713909005453655]
# fold_7   [0.23251666948763616]  [0.25471289134619424]   [0.3123650611910316]
# fold_8   [0.23621035732665985]   [0.2502795158108746]  [0.32308216421560965]
# fold_9    [0.2317955245938459]   [0.2500600255720007]  [0.32199790753506297]
# fold_10  [0.23321766687782786]   [0.2580920015961019]    [0.313055296887617]
#
#                          common            totalGroundT  \
# fold_1                      NaN                     NaN
# fold_2   [0.016007814525527575]                     NaN
# fold_3                      NaN  [0.019389534055050284]
# fold_4                      NaN                     NaN
# fold_5                      NaN                     NaN
# fold_6                      NaN                     NaN
# fold_7    [0.02019372244879314]  [0.016487929112684707]
# fold_8                      NaN                     NaN
# fold_9   [0.025759094599377752]                     NaN
# fold_10                     NaN                     NaN
#
#                  totalBuildingT          totalBuffCount  \
# fold_1                      NaN                     NaN
# fold_2                      NaN                     NaN
# fold_3                      NaN                     NaN
# fold_4    [0.01932830056394108]  [0.022288858197889727]
# fold_5    [0.01883257804787153]                     NaN
# fold_6                      NaN                     NaN
# fold_7   [0.017887448430522035]                     NaN
# fold_8                      NaN                     NaN
# fold_9                      NaN                     NaN
# fold_10                     NaN                     NaN
#
#                       avgRange              totalAirT
# fold_1                     NaN                    NaN
# fold_2                     NaN                    NaN
# fold_3                     NaN                    NaN
# fold_4                     NaN                    NaN
# fold_5                     NaN                    NaN
# fold_6   [0.02192120105963924]                    NaN
# fold_7                     NaN                    NaN
# fold_8                     NaN                    NaN
# fold_9                     NaN  [0.02054915096069898]
# fold_10                    NaN                    NaN
#
# [10 rows x 26 columns]

# %%
metricsComparison['J48+SMOTE+KBest and mutual info'] = [accuracies]

kbest_smoted_mutual_scores
# Out:
#   fit_time score_time test_Accuracy test_Precision test_Recall test_F-Measure
# 0     1.50       0.01        69.36%         68.97%      69.36%         68.77%

# %% [markdown]
# ###### UNSMOTED

# %%
kbest_unsmoted_mutual_ = cross_validate(kbest_unsmoted_mutual, X, y, scoring=scoring, cv=skf, n_jobs=4, return_estimator=True)
kbest_unsmoted_mutual_scores, kbest_unsmoted_mutual_estimators, accuracies = converter(kbest_unsmoted_mutual_)

kbest_unsmoted_mutual_features = feat_extraction(kbest_unsmoted_mutual_estimators)
kbest_unsmoted_mutual_features.transpose()
# Out:
#                                   fold_1                  fold_2  \
# troop             [0.057653429387720445]   [0.05674048742940396]
# spell              [0.07105585444538964]   [0.06419955352998463]
# rare               [0.02112101249778675]  [0.029823115316834903]
# legendary          [0.04102004831613448]  [0.020792032279199013]
# elixir             [0.04388045645482741]   [0.04745837134649067]
# conf_synergy       [0.17501882554121972]   [0.18313250006259985]
# lift_synergy       [0.17992148079583914]   [0.18294618709991184]
# levelSum           [0.06782870289504017]   [0.07466330490344442]
# avgSpeed           [0.11976052559094197]   [0.10817780885303208]
# avgSpellDuration    [0.2020492131173055]    [0.1995517000164344]
# totalHP             [0.1823893604528164]    [0.1860320444216006]
# totalDMG           [0.11164074146940361]    [0.1058367021268769]
# avgAS              [0.04345152563045995]  [0.043615558929382514]
# totalUnitsCount   [0.011365687027536264]                     NaN
# abilityCount       [0.09823835324496932]    [0.0994371724062757]
# totalBuffCount    [0.013182014028759514]                     NaN
# totalProjectiles   [0.19572943051750302]    [0.1904843857720253]
# commonLevel        [0.22741976084281168]   [0.23722419384317472]
# rareLevel          [0.24614580281490217]   [0.25618144512945706]
# epicLevel          [0.31861413063227007]     [0.323651341604267]
# epic                                 NaN  [0.014278428021039069]
# totalBuildingT                       NaN  [0.017190348369908737]
# common                               NaN                     NaN
# totalGroundT                         NaN                     NaN
# avgRange                             NaN                     NaN
#
#                                   fold_3                  fold_4  \
# troop             [0.050791495690144295]  [0.053673074470647064]
# spell               [0.0652985685348626]   [0.06063737920953072]
# rare              [0.019945771598623097]   [0.01898851531372836]
# legendary         [0.015147415717570833]  [0.032184121049236625]
# elixir             [0.04929965406220571]   [0.05700574136669334]
# conf_synergy        [0.1747932477361296]   [0.18354925946186396]
# lift_synergy       [0.17861554677687397]   [0.17779853964023573]
# levelSum           [0.08614659445824513]   [0.07034106450470579]
# avgSpeed            [0.1107257409099649]   [0.11334703128523516]
# avgSpellDuration     [0.199382903498027]   [0.20285357703033657]
# totalHP             [0.1860234738494697]   [0.17904774772072107]
# totalDMG           [0.11274987129001701]   [0.11246968321636475]
# avgAS             [0.043413389370788646]   [0.04176191459960643]
# totalUnitsCount                      NaN  [0.017763970366350357]
# abilityCount       [0.09203254603678723]   [0.09201581942946735]
# totalBuffCount                       NaN                     NaN
# totalProjectiles   [0.20002486710438738]   [0.20047572534417224]
# commonLevel         [0.2362786088662363]   [0.23256904447431626]
# rareLevel          [0.25299923649265543]    [0.2556783219265355]
# epicLevel           [0.3184156213312934]   [0.32101380817822234]
# epic                                 NaN  [0.017475116382267064]
# totalBuildingT    [0.015265757821022241]                     NaN
# common            [0.011181931605070972]                     NaN
# totalGroundT                         NaN                     NaN
# avgRange                             NaN                     NaN
#
#                                   fold_5                  fold_6  \
# troop             [0.059333271053016556]   [0.05471146221695866]
# spell              [0.05006367122208433]   [0.06415195969098297]
# rare              [0.015778974631725173]  [0.016970162476955153]
# legendary         [0.019035528590269024]  [0.024872447502083173]
# elixir            [0.059924001659825255]   [0.04832779814364674]
# conf_synergy        [0.1786081073603205]    [0.1839400172027974]
# lift_synergy        [0.1770802454990137]    [0.1792094070009682]
# levelSum           [0.07270297840062434]   [0.07393232929069482]
# avgSpeed            [0.1194667697356171]   [0.11545966658282292]
# avgSpellDuration    [0.2004239850515548]   [0.20250824938685108]
# totalHP             [0.1764130701668627]   [0.18083502684295216]
# totalDMG            [0.1101349375841576]   [0.11924792563824882]
# avgAS             [0.037004862926377724]   [0.03643900561452473]
# totalUnitsCount                      NaN  [0.012063840672656312]
# abilityCount       [0.08967024381088007]   [0.09488266012448276]
# totalBuffCount                       NaN                     NaN
# totalProjectiles   [0.19154034438082723]    [0.1963120814276309]
# commonLevel          [0.232129064924411]   [0.22979125508439968]
# rareLevel          [0.25928542618656225]    [0.2418899579762679]
# epicLevel           [0.3104081821515201]    [0.3202103024180778]
# epic                                 NaN                     NaN
# totalBuildingT     [0.01997521317155826]   [0.01313464993315927]
# common                               NaN                     NaN
# totalGroundT      [0.011070503106755059]                     NaN
# avgRange                             NaN                     NaN
#
#                                   fold_7                  fold_8  \
# troop             [0.054018052380725656]   [0.05668402531702865]
# spell               [0.0597290608885801]  [0.054336596667915016]
# rare              [0.017344312031833287]   [0.02020077166076817]
# legendary         [0.029931384647875703]   [0.03040620160454477]
# elixir              [0.0493990415447334]  [0.047109037349697624]
# conf_synergy       [0.18274417370448437]   [0.17757388491626958]
# lift_synergy       [0.17742433894728205]   [0.17499785114200117]
# levelSum           [0.08343166761652054]   [0.06893456063549674]
# avgSpeed           [0.10555015802205392]   [0.11919553007530737]
# avgSpellDuration   [0.19802519934806284]   [0.20298653307827563]
# totalHP            [0.17157259062534225]   [0.17978719241760133]
# totalDMG             [0.129025640105479]   [0.11201125955959434]
# avgAS              [0.04065231629912236]   [0.04077212579901479]
# totalUnitsCount                      NaN  [0.021103396514504436]
# abilityCount       [0.08539007526460685]    [0.0861985084783703]
# totalBuffCount                       NaN                     NaN
# totalProjectiles   [0.20072300530486675]    [0.2063483266225712]
# commonLevel         [0.2377409027702786]   [0.22637174473347677]
# rareLevel          [0.24392466719189332]   [0.24460450245370735]
# epicLevel          [0.32078059479148724]   [0.32268417782956593]
# epic               [0.01853306486144346]                     NaN
# totalBuildingT    [0.016975087888943197]   [0.01650894512073542]
# common                               NaN                     NaN
# totalGroundT                         NaN                     NaN
# avgRange                             NaN                     NaN
#
#                                   fold_9                 fold_10
# troop              [0.06277909732441334]   [0.05354787366217795]
# spell              [0.05907134480487386]   [0.04562101418780018]
# rare               [0.01257988401579846]  [0.019851903268151894]
# legendary           [0.0184400694172675]   [0.03554602425851727]
# elixir              [0.0581046409669248]   [0.04133600043771479]
# conf_synergy        [0.1789308674486203]    [0.1830216558728448]
# lift_synergy        [0.1790653272898668]   [0.18370506018486865]
# levelSum           [0.06786140046885003]   [0.07367554217156691]
# avgSpeed            [0.1169638636286876]   [0.09913377688315239]
# avgSpellDuration    [0.2036972603580991]   [0.20249580936058686]
# totalHP            [0.18299304657600146]   [0.18748396948256696]
# totalDMG           [0.11723044579670727]   [0.11287825829325682]
# avgAS              [0.03470242983895089]  [0.044671972532764226]
# totalUnitsCount                      NaN                     NaN
# abilityCount        [0.0825753924196404]   [0.09183727885818249]
# totalBuffCount                       NaN                     NaN
# totalProjectiles   [0.19590177634981698]   [0.18699269234665672]
# commonLevel        [0.23841406741065785]    [0.2316508302708069]
# rareLevel            [0.250448979817929]    [0.2466436762114248]
# epicLevel           [0.3209593847751109]   [0.31444424832210016]
# epic              [0.017101708256519466]  [0.020458276228546346]
# totalBuildingT                       NaN                     NaN
# common                               NaN                     NaN
# totalGroundT                         NaN  [0.018958099859725408]
# avgRange          [0.013668382876709906]                     NaN

# %%
metricsComparison['J48+KBest and mutual info'] = [accuracies]

kbest_unsmoted_mutual_scores
# Out:
#   fit_time score_time test_Accuracy test_Precision test_Recall test_F-Measure
# 0     1.47       0.01        69.70%         69.27%      69.70%         69.02%

# %% [markdown]
# ### VARIANCE THRESHOLD SELECTION

# %% [markdown]
# ###### SMOTED

# %%
VT_smoted_ = cross_validate(VT_smoted, X, y, scoring=scoring, cv=skf, n_jobs=4, return_estimator=True)
VT_smoted_scores, VT_smoted_estimators, accuracies = converter(VT_smoted_)

VT_smoted_features = feat_extraction(VT_smoted_estimators, avoid_scores=True)
VT_smoted_features
# Out:
#         troop spell common  rare  epic legendary conf_synergy lift_synergy  \
# fold_1   True  True   True  True  True      True         True         True
# fold_2   True  True   True  True  True      True         True         True
# fold_3   True  True   True  True  True      True         True         True
# fold_4   True   NaN   True  True  True      True         True         True
# fold_5   True  True   True  True  True      True         True         True
# fold_6   True  True   True  True  True      True         True         True
# fold_7   True  True   True  True  True      True         True         True
# fold_8   True  True   True  True  True      True         True         True
# fold_9   True  True   True  True  True      True         True         True
# fold_10  True   NaN   True  True  True      True         True         True
#
#         levelSum avgSpeed  ... totalHP avgAS totalUnitsCount abilityCount  \
# fold_1      True     True  ...    True  True            True         True
# fold_2      True     True  ...    True  True            True         True
# fold_3      True     True  ...    True  True            True         True
# fold_4      True     True  ...    True  True            True         True
# fold_5      True     True  ...    True  True            True         True
# fold_6      True     True  ...    True  True            True         True
# fold_7      True     True  ...    True  True            True         True
# fold_8      True     True  ...    True  True            True         True
# fold_9      True     True  ...    True  True            True         True
# fold_10     True     True  ...    True  True            True         True
#
#         totalGroundT totalBuffCount totalProjectiles commonLevel rareLevel  \
# fold_1          True           True             True        True      True
# fold_2          True           True             True        True      True
# fold_3          True           True             True        True      True
# fold_4          True           True             True        True      True
# fold_5          True           True             True        True      True
# fold_6          True           True             True        True      True
# fold_7          True           True             True        True      True
# fold_8          True           True             True        True      True
# fold_9          True           True             True        True      True
# fold_10         True           True             True        True      True
#
#         epicLevel
# fold_1       True
# fold_2       True
# fold_3       True
# fold_4       True
# fold_5       True
# fold_6       True
# fold_7       True
# fold_8       True
# fold_9       True
# fold_10      True
#
# [10 rows x 21 columns]

# %%
metricsComparison['J48+SMOTE+VT'] = [accuracies]

VT_smoted_scores
# Out:
#   fit_time score_time test_Accuracy test_Precision test_Recall test_F-Measure
# 0     0.09       0.01        69.65%         69.18%      69.65%         68.95%

# %% [markdown]
# ###### UNSMOTED

# %%
VT_unsmoted_ = cross_validate(VT_unsmoted, X, y, scoring=scoring, cv=skf, n_jobs=4, return_estimator=True)
VT_unsmoted_scores, VT_unsmoted_estimators, accuracies = converter(VT_unsmoted_)

VT_unsmoted_features = feat_extraction(VT_unsmoted_estimators, avoid_scores=True)
VT_unsmoted_features.transpose()
# Out:
#                  fold_1 fold_2 fold_3 fold_4 fold_5 fold_6 fold_7 fold_8  \
# troop              True   True   True   True   True   True   True   True
# spell              True   True   True    NaN   True   True   True   True
# common             True   True   True   True   True   True   True   True
# rare               True   True   True   True   True   True   True   True
# epic               True   True   True   True   True   True   True   True
# legendary          True   True   True   True   True   True   True   True
# conf_synergy       True   True   True   True   True   True   True   True
# lift_synergy       True   True   True   True   True   True   True   True
# levelSum           True   True   True   True   True   True   True   True
# avgSpeed           True   True   True   True   True   True   True   True
# avgSpellDuration   True   True   True   True   True   True   True   True
# totalHP            True   True   True   True   True   True   True   True
# avgAS              True   True   True   True   True   True   True   True
# totalUnitsCount    True   True   True   True   True   True   True   True
# abilityCount       True   True   True   True   True   True   True   True
# totalGroundT       True   True   True   True   True   True   True   True
# totalBuffCount     True   True   True   True   True   True   True   True
# totalProjectiles   True   True   True   True   True   True   True   True
# commonLevel        True   True   True   True   True   True   True   True
# rareLevel          True   True   True   True   True   True   True   True
# epicLevel          True   True   True   True   True   True   True   True
#
#                  fold_9 fold_10
# troop              True    True
# spell               NaN    True
# common             True    True
# rare               True    True
# epic               True    True
# legendary          True    True
# conf_synergy       True    True
# lift_synergy       True    True
# levelSum           True    True
# avgSpeed           True    True
# avgSpellDuration   True    True
# totalHP            True    True
# avgAS              True    True
# totalUnitsCount    True    True
# abilityCount       True    True
# totalGroundT       True    True
# totalBuffCount     True    True
# totalProjectiles   True    True
# commonLevel        True    True
# rareLevel          True    True
# epicLevel          True    True

# %%
metricsComparison['J48+VT'] = [accuracies]

VT_unsmoted_scores
# Out:
#   fit_time score_time test_Accuracy test_Precision test_Recall test_F-Measure
# 0     0.08       0.01        69.06%         68.51%      69.06%         68.33%

# %% [markdown]
# ### BOX PLOT OF RESULTS

# %%
final_dict = {}
for metric in metricsComparison:
    for m in metricsComparison[metric]:
        final_dict[metric] = m
mc_df = pd.DataFrame(final_dict)
mc_df.plot.box(return_type='axes', figsize=(40,20), grid=True, fontsize=14)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## FEATURES GRAPHICS

# %%
import matplotlib.pyplot as plt

[11910.223708, 14923.715174, 16885.578943]

x = ["Challenger", "Master", "Champion"]
y_avg = [5166.317494, 8512.293683,11960.667065]
y_STD = [5166.317494+(11910.223708/2), 8512.293683+(14923.715174/2), 11960.667065+(16885.578943/2)]
y_std = [5166.317494-(11910.223708/2), 8512.293683-(14923.715174/2), 11960.667065-(16885.578943/2)]
plt.plot(x,y_avg,marker="o", label="avg")
plt.plot(x,y_STD,marker="o", label="positive std")
plt.plot(x,y_std,marker="o", label="negative std")
plt.title("synergy")
plt.legend()
plt.show()

# %%
y = [91.497714, 103.326571, 103.779429]
x = ["Champion", "Master", "Challenger"]

plt.plot(x,y,marker="o")
plt.title("level-sum")
plt.show()
