# %% [markdown]
# ## ANALYSIS WITH LEVEL

# %%
import pandas as pd
import numpy as np

ranks_df = pd.read_csv("../csv_sources/leveled_for_rarity.csv").drop(["index", "crowns"], axis="columns")
print("---------------------------------------------------")
print(ranks_df[["rank", "troop"]].groupby("rank").mean())
print(ranks_df[["rank", "troop"]].groupby("rank").std())
print("---------------------------------------------------")
print("---------------------------------------------------")
print(ranks_df[["rank", "building"]].groupby("rank").mean())
print(ranks_df[["rank", "building"]].groupby("rank").std())
print("---------------------------------------------------")
print("---------------------------------------------------")
print(ranks_df[["rank", "spell"]].groupby("rank").mean())
print(ranks_df[["rank", "spell"]].groupby("rank").std())
print("---------------------------------------------------")
print("---------------------------------------------------")
print(ranks_df[["rank", "common"]].groupby("rank").mean())
print(ranks_df[["rank", "common"]].groupby("rank").std())
print("---------------------------------------------------")
print("---------------------------------------------------")
print(ranks_df[["rank", "rare"]].groupby("rank").mean())
print(ranks_df[["rank", "rare"]].groupby("rank").std())
print("---------------------------------------------------")
print("---------------------------------------------------")
print(ranks_df[["rank", "epic"]].groupby("rank").mean())
print(ranks_df[["rank", "epic"]].groupby("rank").std())
print("---------------------------------------------------")
print("---------------------------------------------------")
print(ranks_df[["rank", "legendary"]].groupby("rank").mean())
print(ranks_df[["rank", "legendary"]].groupby("rank").std())
print("---------------------------------------------------")
print("---------------------------------------------------")
print(ranks_df[["rank", "elixir"]].groupby("rank").mean())
print(ranks_df[["rank", "elixir"]].groupby("rank").std())
print("---------------------------------------------------")
print("---------------------------------------------------")
print(ranks_df[["rank", "conf_synergy"]].groupby("rank").mean())
print(ranks_df[["rank", "conf_synergy"]].groupby("rank").std())
print("---------------------------------------------------")
print("---------------------------------------------------")
print(ranks_df[["rank", "lift_synergy"]].groupby("rank").mean())
print(ranks_df[["rank", "lift_synergy"]].groupby("rank").std())
print("---------------------------------------------------")
print("---------------------------------------------------")
print(ranks_df[["rank", "levelSum"]].groupby("rank").mean())
print(ranks_df[["rank", "levelSum"]].groupby("rank").std())
print("---------------------------------------------------")
print("---------------------------------------------------")
print(ranks_df[["rank", "avgSpeed"]].groupby("rank").mean())
print(ranks_df[["rank", "avgSpeed"]].groupby("rank").std())
print("---------------------------------------------------")
print("---------------------------------------------------")
print(ranks_df[["rank", "avgSpellDuration"]].groupby("rank").mean())
print(ranks_df[["rank", "avgSpellDuration"]].groupby("rank").std())
print("---------------------------------------------------")
print("---------------------------------------------------")
print(ranks_df[["rank", "totalHP"]].groupby("rank").mean())
print(ranks_df[["rank", "totalHP"]].groupby("rank").std())
print("---------------------------------------------------")
print("---------------------------------------------------")
print(ranks_df[["rank", "totalDMG"]].groupby("rank").mean())
print(ranks_df[["rank", "totalDMG"]].groupby("rank").std())
print("---------------------------------------------------")
print("---------------------------------------------------")
print(ranks_df[["rank", "avgAS"]].groupby("rank").mean())
print(ranks_df[["rank", "avgAS"]].groupby("rank").std())
print("---------------------------------------------------")
print("---------------------------------------------------")
print(ranks_df[["rank", "totalUnitsCount"]].groupby("rank").mean())
print(ranks_df[["rank", "totalUnitsCount"]].groupby("rank").std())
print("---------------------------------------------------")
print("---------------------------------------------------")
print(ranks_df[["rank", "abilityCount"]].groupby("rank").mean())
print(ranks_df[["rank", "abilityCount"]].groupby("rank").std())
print("---------------------------------------------------")
print("---------------------------------------------------")
print(ranks_df[["rank", "avgRange"]].groupby("rank").mean())
print(ranks_df[["rank", "avgRange"]].groupby("rank").std())
print("---------------------------------------------------")
print("---------------------------------------------------")
print(ranks_df[["rank", "totalGroundT"]].groupby("rank").mean())
print(ranks_df[["rank", "totalGroundT"]].groupby("rank").std())
print("---------------------------------------------------")
print("---------------------------------------------------")
print(ranks_df[["rank", "totalAirT"]].groupby("rank").mean())
print(ranks_df[["rank", "totalAirT"]].groupby("rank").std())
print("---------------------------------------------------")
print("---------------------------------------------------")
print(ranks_df[["rank", "totalBuildingT"]].groupby("rank").mean())
print(ranks_df[["rank", "totalBuildingT"]].groupby("rank").std())
print("---------------------------------------------------")
print("---------------------------------------------------")
print(ranks_df[["rank", "totalBuffCount"]].groupby("rank").mean())
print(ranks_df[["rank", "totalBuffCount"]].groupby("rank").std())
print("---------------------------------------------------")
print("---------------------------------------------------")
print(ranks_df[["rank", "totalProjectiles"]].groupby("rank").mean())
print(ranks_df[["rank", "totalProjectiles"]].groupby("rank").std())
print("---------------------------------------------------")
print("---------------------------------------------------")

ranks_df
# Out:
# ---------------------------------------------------
#                troop
# rank
# Challenger  5.889429
# Champion    5.137143
# Master      5.368857
#                troop
# rank
# Challenger  1.115021
# Champion    0.950650
# Master      1.013316
# ---------------------------------------------------
# ---------------------------------------------------
#             building
# rank
# Challenger  0.372857
# Champion    0.508571
# Master      0.516571
#             building
# rank
# Challenger   0.55465
# Champion     0.58287
# Master       0.60342
# ---------------------------------------------------
# ---------------------------------------------------
#                spell
# rank
# Challenger  1.737714
# Champion    2.354286
# Master      2.114571
#                spell
# rank
# Challenger  0.902700
# Champion    0.688925
# Master      0.792047
# ---------------------------------------------------
# ---------------------------------------------------
#               common
# rank
# Challenger  2.013143
# Champion    2.072000
# Master      2.136571
#               common
# rank
# Challenger  1.294281
# Champion    1.376305
# Master      1.301693
# ---------------------------------------------------
# ---------------------------------------------------
#                 rare
# rank
# Challenger  2.021143
# Champion    1.655429
# Master      2.154286
#                 rare
# rank
# Challenger  1.248999
# Champion    1.116844
# Master      1.283559
# ---------------------------------------------------
# ---------------------------------------------------
#                 epic
# rank
# Challenger  2.185714
# Champion    2.470857
# Master      2.216857
#                 epic
# rank
# Challenger  1.298458
# Champion    1.577567
# Master      1.415668
# ---------------------------------------------------
# ---------------------------------------------------
#             legendary
# rank
# Challenger   1.780000
# Champion     1.801714
# Master       1.492286
#             legendary
# rank
# Challenger   1.344450
# Champion     1.019444
# Master       1.047158
# ---------------------------------------------------
# ---------------------------------------------------
#               elixir
# rank
# Challenger  3.941923
# Champion    3.663602
# Master      3.789852
#               elixir
# rank
# Challenger  0.537450
# Champion    0.489592
# Master      0.496820
# ---------------------------------------------------
# ---------------------------------------------------
#             conf_synergy
# rank
# Challenger   5166.317494
# Champion    11960.667065
# Master       8512.293683
#             conf_synergy
# rank
# Challenger  11910.223708
# Champion    16885.578943
# Master      14923.715174
# ---------------------------------------------------
# ---------------------------------------------------
#              lift_synergy
# rank
# Challenger  171762.530769
# Champion    366761.641239
# Master      273465.345554
#              lift_synergy
# rank
# Challenger  431438.047552
# Champion    543340.957634
# Master      517453.027176
# ---------------------------------------------------
# ---------------------------------------------------
#               levelSum
# rank
# Challenger   91.497714
# Champion    103.779429
# Master      103.326571
#              levelSum
# rank
# Challenger  11.262933
# Champion     0.590900
# Master       1.403027
# ---------------------------------------------------
# ---------------------------------------------------
#              avgSpeed
# rank
# Challenger  76.585816
# Champion    75.893459
# Master      77.657602
#              avgSpeed
# rank
# Challenger   9.492413
# Champion    10.364504
# Master       9.948391
# ---------------------------------------------------
# ---------------------------------------------------
#             avgSpellDuration
# rank
# Challenger          5.644639
# Champion            5.840915
# Master              6.916762
#             avgSpellDuration
# rank
# Challenger          8.355736
# Champion            6.088218
# Master              8.031840
# ---------------------------------------------------
# ---------------------------------------------------
#                 totalHP
# rank
# Challenger  8081.543429
# Champion    8247.429143
# Master      8776.516000
#                 totalHP
# rank
# Challenger  2481.123329
# Champion    2348.916699
# Master      2527.995296
# ---------------------------------------------------
# ---------------------------------------------------
#                totalDMG
# rank
# Challenger  2137.281143
# Champion    2267.813714
# Master      2335.331143
#               totalDMG
# rank
# Challenger  731.606569
# Champion    753.495305
# Master      744.849398
# ---------------------------------------------------
# ---------------------------------------------------
#                avgAS
# rank
# Challenger  1.564996
# Champion    1.717283
# Master      1.681641
#                avgAS
# rank
# Challenger  0.469242
# Champion    0.658200
# Master      0.618986
# ---------------------------------------------------
# ---------------------------------------------------
#             totalUnitsCount
# rank
# Challenger        13.337714
# Champion           9.594571
# Master            11.098000
#             totalUnitsCount
# rank
# Challenger         7.276297
# Champion           5.809535
# Master             6.554788
# ---------------------------------------------------
# ---------------------------------------------------
#             abilityCount
# rank
# Challenger      2.488857
# Champion        2.569143
# Master          2.147143
#             abilityCount
# rank
# Challenger      1.472096
# Champion        1.367807
# Master          1.312026
# ---------------------------------------------------
# ---------------------------------------------------
#                avgRange
# rank
# Challenger  2863.975000
# Champion    2976.914286
# Master      2801.794643
#               avgRange
# rank
# Challenger  637.938937
# Champion    688.172799
# Master      640.297747
# ---------------------------------------------------
# ---------------------------------------------------
#             totalGroundT
# rank
# Challenger      7.923429
# Champion        7.982286
# Master          7.953714
#             totalGroundT
# rank
# Challenger      0.275450
# Champion        0.131930
# Master          0.212836
# ---------------------------------------------------
# ---------------------------------------------------
#             totalAirT
# rank
# Challenger   4.072286
# Champion     4.089714
# Master       3.991714
#             totalAirT
# rank
# Challenger   1.023406
# Champion     0.895167
# Master       0.966835
# ---------------------------------------------------
# ---------------------------------------------------
#             totalBuildingT
# rank
# Challenger        0.910000
# Champion          0.920000
# Master            0.947429
#             totalBuildingT
# rank
# Challenger        0.750088
# Champion          0.636509
# Master            0.632168
# ---------------------------------------------------
# ---------------------------------------------------
#             totalBuffCount
# rank
# Challenger        0.672571
# Champion          0.956000
# Master            0.821143
#             totalBuffCount
# rank
# Challenger        0.711793
# Champion          0.743309
# Master            0.739224
# ---------------------------------------------------
# ---------------------------------------------------
#             totalProjectiles
# rank
# Challenger          1.123714
# Champion            1.377429
# Master              1.324000
#             totalProjectiles
# rank
# Challenger          0.850908
# Champion            0.865062
# Master              0.866740
# ---------------------------------------------------
# ---------------------------------------------------
#              rank  troop  building  spell  common  rare  epic  legendary  \
# 0      Challenger      5         0      3       1     1     4          2
# 1      Challenger      5         1      2       1     2     3          2
# 2          Master      7         1      0       3     3     2          0
# 3      Challenger      7         0      1       4     2     1          1
# 4      Challenger      5         0      3       1     1     5          1
# ...           ...    ...       ...    ...     ...   ...   ...        ...
# 10495    Champion      5         1      2       0     4     4          0
# 10496    Champion      6         0      2       1     2     3          2
# 10497    Champion      6         0      2       2     1     2          3
# 10498    Champion      5         1      2       4     2     1          1
# 10499    Champion      6         0      2       0     1     6          1
#
#        elixir  conf_synergy  ...  totalDMG     avgAS  totalUnitsCount  \
# 0       3.375   2865.990531  ...      1320  1.420000               19
# 1       4.250   3980.516610  ...      1847  1.316667                5
# 2       4.875      0.000000  ...      2100  2.075000               27
# 3       3.750   1389.332225  ...      2068  1.428571               11
# 4       4.500   4049.013035  ...      1688  1.740000                5
# ...       ...           ...  ...       ...       ...              ...
# 10495   3.625   2191.588585  ...      1505  2.783333                5
# 10496   4.000  26569.219252  ...      2462  1.233333                6
# 10497   3.750   2671.736517  ...      2095  1.316667               10
# 10498   3.125  14365.842341  ...      2351  1.733333               17
# 10499   4.625   3303.615309  ...      2186  1.583333                6
#
#        abilityCount  avgRange  totalGroundT  totalAirT  totalBuildingT  \
# 0                 2   2712.50             8          3               0
# 1                 3   2018.75             7          5               1
# 2                 1   1925.00             8          2               2
# 3                 2   4175.00             8          6               0
# 4                 2   3056.25             8          4               1
# ...             ...       ...           ...        ...             ...
# 10495             4   2800.00             8          4               1
# 10496             4   2581.25             8          4               1
# 10497             3   2275.00             8          4               1
# 10498             0   3868.75             8          3               1
# 10499             4   3006.25             8          5               1
#
#        totalBuffCount  totalProjectiles
# 0                   0                 3
# 1                   2                 0
# 2                   0                 0
# 3                   0                 1
# 4                   2                 1
# ...               ...               ...
# 10495               1                 1
# 10496               2                 0
# 10497               1                 1
# 10498               0                 2
# 10499               0                 2
#
# [10500 rows x 25 columns]

# %%
from sklearn.model_selection import StratifiedKFold
from imblearn.pipeline import Pipeline
from imblearn.over_sampling import SMOTE
from sklearn.feature_selection import SelectKBest, chi2, mutual_info_classif, VarianceThreshold
from sklearn.metrics import classification_report
from sklearn.model_selection import cross_validate
from sklearn.tree import DecisionTreeClassifier
from random import randrange
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn.metrics import make_scorer
from sklearn.naive_bayes import GaussianNB

y = np.array([x for x in ranks_df["rank"]])
X = np.array([x for x in ranks_df.drop(["rank"], axis="columns").values])

scoring = {
    'Accuracy': make_scorer(accuracy_score),
    'Precision': make_scorer(precision_score, average='macro', zero_division=0),
    'Recall': make_scorer(recall_score, average="macro", zero_division=0),
    'F-Measure': make_scorer(f1_score, average="macro", zero_division=0)
}

def converter(df):
    scores = {
        'fit_time': df['fit_time'],
        'score_time': df['score_time'],
        'test_Accuracy': df['test_Accuracy'],
        'test_Precision': df['test_Precision'],
        'test_Recall': df['test_Recall'],
        'test_F-Measure': df['test_F-Measure']
    }
    estimators = df['estimator']
    accuracies = df['test_Accuracy']
    for key in scores.keys():
        if "test_" in key:
            scores[key] = [f"{scores[key].mean() * 100: .2f}%"]
        else:
            scores[key] = [f"{scores[key].mean(): .2f}"]
    return [pd.DataFrame(scores), estimators, accuracies]

def feat_extraction(estimators, avoid_scores = False):
    features_per_fold = {}
    fold_index = 0
    for estim in estimators:
        fold_index += 1
        feature = 0
        sel_features = {}
        feat_scores = []
        if not avoid_scores:
            feat_scores = estim['feat_sel'].scores_
        for selected in estim['feat_sel'].get_support():
            feature+=1
            if(selected == True):
                if len(feat_scores) > 0:
                    sel_features[ranks_df.columns[feature]] = [feat_scores[feature-1]]
                else:
                    sel_features[ranks_df.columns[feature]] = True
        features_per_fold[f"fold_{fold_index}"] = sel_features
    return pd.DataFrame(features_per_fold).transpose()

skf = StratifiedKFold(n_splits=10, shuffle=True, random_state=randrange(1,42))

# %% [markdown]
# ### ANALYSIS

# %%
smoted_pipeline = Pipeline([
    ('sampler', SMOTE(random_state=randrange(1,42))),
    ('clf', GaussianNB())
])
unsmoted_pipeline = Pipeline([
    ('clf', GaussianNB())
])
#######################################################
kbest_smoted = Pipeline([
    ('feat_sel', SelectKBest(chi2, k=12)),
    ('sampler', SMOTE(random_state=randrange(1,42))),
    ('clf', GaussianNB())
])
kbest_unsmoted = Pipeline([
    ('feat_sel', SelectKBest(chi2, k=12)),
    ('clf', GaussianNB())
])
########################################################
kbest_smoted_mutual = Pipeline([
    ('feat_sel', SelectKBest(mutual_info_classif, k=12)),
    ('sampler', SMOTE(random_state=randrange(1,42))),
    ('clf', GaussianNB())
])
kbest_unsmoted_mutual = Pipeline([
    ('feat_sel', SelectKBest(mutual_info_classif, k=12)),
    ('clf', GaussianNB())
])
########################################################
VT_smoted = Pipeline([
    ('feat_sel', VarianceThreshold(threshold=0.7)),
    ('sampler', SMOTE(random_state=randrange(1,42))),
    ('clf', GaussianNB())
])
VT_unsmoted = Pipeline([
    ('feat_sel', VarianceThreshold(threshold=0.7)),
    ('clf', GaussianNB())
])

metricsComparison = {}

# %% [markdown]
# ### SMOTE NO ATTRIBUT SELECTION

# %%
smoted_ = cross_validate(smoted_pipeline, X, y, scoring=scoring, cv=skf, n_jobs=8, return_estimator=True)
mean_smoted, smoted_estimators, accuracies = converter(smoted_)

metricsComparison['NB + SMOTE'] = [accuracies]

mean_smoted
# Out:
#   fit_time score_time test_Accuracy test_Precision test_Recall test_F-Measure
# 0     0.06       0.04        49.32%         49.40%      49.32%         48.09%

# %% [markdown]
# ### NO SMOTE NO ATTRIBUTE SELECTION

# %%
unsmoted_ = cross_validate(unsmoted_pipeline, X, y, scoring=scoring, cv=skf, n_jobs=8, return_estimator=True)
mean_unsmoted, unsmoted_estimators, accuracies = converter(unsmoted_)

metricsComparison['NB'] = [accuracies]

mean_unsmoted
# Out:
#   fit_time score_time test_Accuracy test_Precision test_Recall test_F-Measure
# 0     0.05       0.06        49.32%         49.40%      49.32%         48.09%

# %% [markdown]
# ### SMOTE KBEST SELECTION

# %%
kbest_smoted_ = cross_validate(kbest_smoted, X, y, scoring=scoring, cv=skf, n_jobs=8, return_estimator=True)

mean_kbest_smoted, kbest_smoted_estimators, accuracies = converter(kbest_smoted_)
    
kbest_features = feat_extraction(kbest_smoted_estimators)
kbest_features
# Out:
#                         troop                 spell                  rare  \
# fold_1    [164.8701801976361]    [286.524364082133]   [213.3883595579028]
# fold_2   [171.42863781585828]  [293.26859947844764]  [209.45940356987376]
# fold_3   [170.69821729284016]  [294.99738769656307]     [208.35413153457]
# fold_4    [167.9945797359557]   [291.4967016108412]  [204.54829406323125]
# fold_5    [176.2516387261442]   [300.2051308363263]  [230.61939690301548]
# fold_6   [168.77784880004648]  [290.21733360555334]  [235.24275658863968]
# fold_7   [175.43343599279444]  [299.87004754358156]  [217.98976815064765]
# fold_8   [170.02319862125057]   [296.9488700276102]  [226.95603377826208]
# fold_9   [173.43544171458444]    [295.163561924258]  [215.16291217760366]
# fold_10  [172.48972237828627]   [293.4247430061883]  [202.80589198036006]
#
#                 conf_synergy          lift_synergy              levelSum  \
# fold_1   [8258590.969485871]   [215400623.7160621]  [3096.1813155499603]
# fold_2    [8472540.24457585]   [219460153.0894053]   [3085.908541195059]
# fold_3   [8698664.017277448]  [225689828.42211932]  [3101.3884599108114]
# fold_4   [8422444.551662724]  [221760903.02213094]  [3022.6089141268412]
# fold_5   [8659694.434846068]   [220609305.9461171]  [3005.2151065787884]
# fold_6   [8713938.219106162]  [228244830.03637734]  [3033.3481786669813]
# fold_7   [8817480.192289637]   [230109619.5767664]  [3082.2841287647198]
# fold_8   [8412403.640492756]  [218495715.59248054]  [3064.2070881360473]
# fold_9    [8258950.11422432]   [216815121.6745361]   [3080.496366367931]
# fold_10  [8404447.020892685]  [218817367.95135948]   [3123.907198601247]
#
#              avgSpellDuration               totalHP              totalDMG  \
# fold_1    [412.6436363590639]  [105079.33002539097]  [30734.793233607976]
# fold_2    [536.3939673349039]   [92016.00346443735]  [25974.683450081524]
# fold_3   [408.16700754413677]  [102423.90096564133]  [29353.652610986817]
# fold_4    [434.3044769143163]   [92609.30940473542]  [26326.029889842648]
# fold_5    [535.3585333809535]  [100295.81696241969]   [30680.93572155637]
# fold_6   [449.08451578986626]   [107463.9733098357]  [27613.705658788036]
# fold_7    [447.4796085343702]  [103650.03421116932]  [29290.543065514306]
# fold_9   [0.17718671171892963]   [0.1780303505332952]  [0.33437774593727454]
# fold_10  [0.17508532293196954]  [0.18108481130595466]  [0.33454315792687783]
#
#                       avgSpeed       avgSpellDuration                totalHP  \
# fold_1   [0.06764426270235147]   [0.1194673298050224]  [0.19900479807774807]
# fold_2   [0.06536340952607245]  [0.10958530507760633]   [0.2036896868889262]
# fold_3   [0.07372653996606604]  [0.10421482094615686]  [0.20290482890931694]
# fold_4   [0.07839881996818865]  [0.10628595919167183]  [0.19575992188132263]
# fold_5   [0.08183131698658141]  [0.10544779155847683]  [0.20083851282274812]
# fold_6   [0.08678761322214235]  [0.10551463456748755]   [0.1994949130889092]
# fold_7   [0.08152144943631012]  [0.10659463803687963]  [0.20138637738387866]
# fold_8   [0.08462365581872011]  [0.11459078692255886]   [0.2029056418868953]
# fold_9   [0.07965288690169325]  [0.10825799113039092]   [0.2028924739221476]
# fold_10  [0.06825323935865946]  [0.10945567076608143]  [0.20666012003287015]
#
#                       totalDMG                  avgAS         totalUnitsCount  \
# fold_1    [0.1708603105148938]  [0.11228035771382361]  [0.048042029746221626]
# fold_2     [0.172609059845936]  [0.11484705402538364]                     NaN
# fold_3    [0.1717033727158277]  [0.12062492031400618]                     NaN
# fold_4   [0.18027772432930322]  [0.10972374176542954]                     NaN
# fold_5    [0.1750719081025529]   [0.1099931428766765]   [0.04394404509361194]
# fold_6   [0.17344105171454616]  [0.11278686037863084]   [0.05575356738245252]
# fold_7   [0.17627942620378056]  [0.11671796741508267]                     NaN
# fold_8   [0.16898658665453592]   [0.1158429783821211]   [0.04784046442474588]
# fold_9    [0.1776455800503256]  [0.10901053589853071]  [0.049637738499228146]
# fold_10  [0.17139215676377217]  [0.12566624284794048]   [0.04521544484022311]
#
#                       avgRange                  elixir
# fold_1   [0.10089479075677832]                     NaN
# fold_2   [0.08233681719886121]   [0.04820257813125228]
# fold_3   [0.08918180248068053]  [0.048954758894189654]
# fold_4    [0.0778346359132227]   [0.04430185068330217]
# fold_5   [0.08851019582554809]                     NaN
# fold_6   [0.09368639150571823]                     NaN
# fold_7    [0.0921327094969977]    [0.0514526592276181]
# fold_8   [0.08702886106871488]                     NaN
# fold_9   [0.09059244866478666]                     NaN
# fold_10  [0.08717604132850276]                     NaN

# %%
metricsComparison['NB + KBEST and mutual_info'] = [accuracies]

kbest_unsmoted_mutual_scores
# Out:
#   fit_time score_time test_Accuracy test_Precision test_Recall test_F-Measure
# 0     4.72       0.03        48.87%         49.01%      48.87%         47.51%

# %% [markdown]
# ### VARIANCE THRESHOLD SELECTION

# %% [markdown]
# ###### SMOTED

# %%
VT_smoted_ = cross_validate(VT_smoted, X, y, scoring=scoring, cv=skf, n_jobs=8, return_estimator=True)
VT_smoted_scores, VT_smoted_estimators, accuracies = converter(VT_smoted_)

VT_smoted_features = feat_extraction(VT_smoted_estimators, avoid_scores=True)
VT_smoted_features
# Out:
#         troop spell common  rare  epic legendary conf_synergy lift_synergy  \
# fold_1   True  True   True  True  True      True         True         True
# fold_2   True  True   True  True  True      True         True         True
# fold_3   True  True   True  True  True      True         True         True
# fold_4   True  True   True  True  True      True         True         True
# fold_5   True   NaN   True  True  True      True         True         True
# fold_6   True   NaN   True  True  True      True         True         True
# fold_7   True  True   True  True  True      True         True         True
# fold_8   True  True   True  True  True      True         True         True
# fold_9   True  True   True  True  True      True         True         True
# fold_10  True  True   True  True  True      True         True         True
#
#         levelSum avgSpeed avgSpellDuration totalHP totalDMG totalUnitsCount  \
# fold_1      True     True             True    True     True            True
# fold_2      True     True             True    True     True            True
# fold_3      True     True             True    True     True            True
# fold_4      True     True             True    True     True            True
# fold_5      True     True             True    True     True            True
# fold_6      True     True             True    True     True            True
# fold_7      True     True             True    True     True            True
# fold_8      True     True             True    True     True            True
# fold_9      True     True             True    True     True            True
# fold_10     True     True             True    True     True            True
#
#         abilityCount avgRange totalAirT totalProjectiles
# fold_1          True     True      True             True
# fold_2          True     True      True             True
# fold_3          True     True      True             True
# fold_4          True     True      True             True
# fold_5          True     True      True             True
# fold_6          True     True      True             True
# fold_7          True     True      True             True
# fold_8          True     True      True             True
# fold_9          True     True      True             True
# fold_10         True     True      True             True

# %%
metricsComparison['NB + SMOTE + Variance Threshold'] = [accuracies]

VT_smoted_scores
# Out:
#   fit_time score_time test_Accuracy test_Precision test_Recall test_F-Measure
# 0     0.06       0.03        49.31%         49.41%      49.31%         48.07%

# %% [markdown]
# ###### UNSMOTED

# %%
VT_unsmoted_ = cross_validate(VT_unsmoted, X, y, scoring=scoring, cv=skf, n_jobs=8, return_estimator=True)
VT_unsmoted_scores, VT_unsmoted_estimators, accuracies = converter(VT_unsmoted_)

VT_unsmoted_features = feat_extraction(VT_unsmoted_estimators, avoid_scores=True)
VT_unsmoted_features
# Out:
#         troop spell common  rare  epic legendary conf_synergy lift_synergy  \
# fold_1   True  True   True  True  True      True         True         True
# fold_2   True  True   True  True  True      True         True         True
# fold_3   True  True   True  True  True      True         True         True
# fold_4   True  True   True  True  True      True         True         True
# fold_5   True   NaN   True  True  True      True         True         True
# fold_6   True   NaN   True  True  True      True         True         True
# fold_7   True  True   True  True  True      True         True         True
# fold_8   True  True   True  True  True      True         True         True
# fold_9   True  True   True  True  True      True         True         True
# fold_10  True  True   True  True  True      True         True         True
#
#         levelSum avgSpeed avgSpellDuration totalHP totalDMG totalUnitsCount  \
# fold_1      True     True             True    True     True            True
# fold_2      True     True             True    True     True            True
# fold_3      True     True             True    True     True            True
# fold_4      True     True             True    True     True            True
# fold_5      True     True             True    True     True            True
# fold_6      True     True             True    True     True            True
# fold_7      True     True             True    True     True            True
# fold_8      True     True             True    True     True            True
# fold_9      True     True             True    True     True            True
# fold_10     True     True             True    True     True            True
#
#         abilityCount avgRange totalAirT totalProjectiles
# fold_1          True     True      True             True
# fold_2          True     True      True             True
# fold_3          True     True      True             True
# fold_4          True     True      True             True
# fold_5          True     True      True             True
# fold_6          True     True      True             True
# fold_7          True     True      True             True
# fold_8          True     True      True             True
# fold_9          True     True      True             True
# fold_10         True     True      True             True

# %%
metricsComparison['NB + Variance Threshold'] = [accuracies]

VT_unsmoted_scores
# Out:
#   fit_time score_time test_Accuracy test_Precision test_Recall test_F-Measure
# 0     0.05       0.02        49.31%         49.41%      49.31%         48.07%

# %% [markdown]
# ### BOX PLOT OF RESULTS

# %%
final_dict = {}
for metric in metricsComparison:
    for m in metricsComparison[metric]:
        final_dict[metric] = m
mc_df = pd.DataFrame(final_dict)
mc_df.plot.box(return_type='axes', figsize=(40,20), grid=True, fontsize=14)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## ANALYSIS WITHOUT LEVEL

# %%
ranks_nolevel_df = ranks_df.drop(["levelSum"], axis="columns")
ranks_nolevel_df
# Out:
#              rank  troop  building  spell  common  rare  epic  legendary  \
# 0      Challenger      5         0      3       1     1     4          2
# 1      Challenger      5         1      2       1     2     3          2
# 2          Master      7         1      0       3     3     2          0
# 3      Challenger      7         0      1       4     2     1          1
# 4      Challenger      5         0      3       1     1     5          1
# ...           ...    ...       ...    ...     ...   ...   ...        ...
# 10495    Champion      5         1      2       0     4     4          0
# 10496    Champion      6         0      2       1     2     3          2
# 10497    Champion      6         0      2       2     1     2          3
# 10498    Champion      5         1      2       4     2     1          1
# 10499    Champion      6         0      2       0     1     6          1
#
#        elixir  conf_synergy  ...  totalDMG     avgAS  totalUnitsCount  \
# 0       3.375   2865.990531  ...      1320  1.420000               19
# 1       4.250   3980.516610  ...      1847  1.316667                5
# 2       4.875      0.000000  ...      2100  2.075000               27
# 3       3.750   1389.332225  ...      2068  1.428571               11
# 4       4.500   4049.013035  ...      1688  1.740000                5
# ...       ...           ...  ...       ...       ...              ...
# 10495   3.625   2191.588585  ...      1505  2.783333                5
# 10496   4.000  26569.219252  ...      2462  1.233333                6
# 10497   3.750   2671.736517  ...      2095  1.316667               10
# 10498   3.125  14365.842341  ...      2351  1.733333               17
# 10499   4.625   3303.615309  ...      2186  1.583333                6
#
#        abilityCount  avgRange  totalGroundT  totalAirT  totalBuildingT  \
# 0                 2   2712.50             8          3               0
# 1                 3   2018.75             7          5               1
# 2                 1   1925.00             8          2               2
# 3                 2   4175.00             8          6               0
# 4                 2   3056.25             8          4               1
# ...             ...       ...           ...        ...             ...
# 10495             4   2800.00             8          4               1
# 10496             4   2581.25             8          4               1
# 10497             3   2275.00             8          4               1
# 10498             0   3868.75             8          3               1
# 10499             4   3006.25             8          5               1
#
#        totalBuffCount  totalProjectiles
# 0                   0                 3
# 1                   2                 0
# 2                   0                 0
# 3                   0                 1
# 4                   2                 1
# ...               ...               ...
# 10495               1                 1
# 10496               2                 0
# 10497               1                 1
# 10498               0                 2
# 10499               0                 2
#
# [10500 rows x 24 columns]

# %%
y = np.array([x for x in ranks_nolevel_df["rank"]])
X = np.array([x for x in ranks_nolevel_df.drop(["rank"], axis="columns").values])
metricsComparison = {}

# %% [markdown]
# ### SMOTE NO ATTRIBUT SELECTION

# %%
smoted_ = cross_validate(smoted_pipeline, X, y, scoring=scoring, cv=skf, n_jobs=8, return_estimator=True)
mean_smoted, smoted_estimators, accuracies = converter(smoted_)

metricsComparison['NB+SMOTE'] = [accuracies]

mean_smoted
# Out:
#   fit_time score_time test_Accuracy test_Precision test_Recall test_F-Measure
# 0     0.21       0.11        42.01%         44.82%      42.01%         38.36%

# %% [markdown]
# ### NO SMOTE NO ATTRIBUTE SELECTION

# %%
unsmoted_ = cross_validate(unsmoted_pipeline, X, y, scoring=scoring, cv=skf, n_jobs=8, return_estimator=True)
mean_unsmoted, unsmoted_estimators, accuracies = converter(unsmoted_)

metricsComparison['NB'] = [accuracies]

mean_unsmoted
# Out:
#   fit_time score_time test_Accuracy test_Precision test_Recall test_F-Measure
# 0     0
# fold_2   [0.17415652858986075]  [0.11155213835682942]   [0.04630867660581983]
# fold_3     [0.175488728086441]   [0.1125239338016768]  [0.041434812107781216]
# fold_4   [0.17985506271992868]  [0.11073558484074586]  [0.046789107873046465]
# fold_5   [0.17623573953485439]  [0.11087311356564711]                     NaN
# fold_6   [0.17575415640843195]  [0.11489030466979178]   [0.04604084607921144]
# fold_7   [0.17606832587819232]  [0.11307673970058962]   [0.04824303264918073]
# fold_8   [0.17209502041225289]  [0.11177660541974022]  [0.042986707608901664]
# fold_9   [0.17717161162059836]  [0.11040650388784412]   [0.05171855226646693]
# fold_10  [0.17232447435837073]  [0.11051089930626645]  [0.042602761412961154]
#
#                   abilityCount              legendary
# fold_1   [0.09237414081025785]                    NaN
# fold_2    [0.0964797137773672]                    NaN
# fold_3   [0.08681932112566293]                    NaN
# fold_4    [0.0977442313499941]                    NaN
# fold_5   [0.08149697424414715]  [0.03518025671392988]
# fold_6   [0.08798186365578342]                    NaN
# fold_7   [0.09308931514952157]                    NaN
# fold_8   [0.09126975810836391]                    NaN
# fold_9   [0.09073457937000984]                    NaN
# fold_10  [0.08456108132869522]                    NaN

# %%
metricsComparison['NB+KBest and mutual info'] = [accuracies]

kbest_unsmoted_mutual_scores
# Out:
#   fit_time score_time test_Accuracy test_Precision test_Recall test_F-Measure
# 0     2.69       0.02        41.94%         44.75%      41.94%         38.23%

# %% [markdown]
# ### VARIANCE THRESHOLD SELECTION

# %% [markdown]
# ###### SMOTED

# %%
VT_smoted_ = cross_validate(VT_smoted, X, y, scoring=scoring, cv=skf, n_jobs=8, return_estimator=True)
VT_smoted_scores, VT_smoted_estimators, accuracies = converter(VT_smoted_)

VT_smoted_features = feat_extraction(VT_smoted_estimators, avoid_scores=True)
VT_smoted_features
# Out:
#         troop spell common  rare  epic legendary conf_synergy lift_synergy  \
# fold_1   True  True   True  True  True      True         True         True
# fold_2   True  True   True  True  True      True         True         True
# fold_3   True  True   True  True  True      True         True         True
# fold_4   True  True   True  True  True      True         True         True
# fold_5   True   NaN   True  True  True      True         True         True
# fold_6   True   NaN   True  True  True      True         True         True
# fold_7   True  True   True  True  True      True         True         True
# fold_8   True  True   True  True  True      True         True         True
# fold_9   True  True   True  True  True      True         True         True
# fold_10  True  True   True  True  True      True         True         True
#
#         levelSum avgSpeed avgSpellDuration totalHP avgAS totalUnitsCount  \
# fold_1      True     True             True    True  True            True
# fold_2      True     True             True    True  True            True
# fold_3      True     True             True    True  True            True
# fold_4      True     True             True    True  True            True
# fold_5      True     True             True    True  True            True
# fold_6      True     True             True    True  True            True
# fold_7      True     True             True    True  True            True
# fold_8      True     True             True    True  True            True
# fold_9      True     True             True    True  True            True
# fold_10     True     True             True    True  True            True
#
#         abilityCount totalGroundT totalBuffCount
# fold_1          True         True           True
# fold_2          True         True           True
# fold_3          True         True           True
# fold_4          True         True           True
# fold_5          True         True           True
# fold_6          True         True           True
# fold_7          True         True           True
# fold_8          True         True           True
# fold_9          True         True           True
# fold_10         True         True           True

# %%
metricsComparison['NB+SMOTE+VT'] = [accuracies]

VT_smoted_scores
# Out:
#   fit_time score_time test_Accuracy test_Precision test_Recall test_F-Measure
# 0     0.07       0.05        42.02%         44.83%      42.02%         38.38%

# %% [markdown]
# ###### UNSMOTED

# %%
VT_unsmoted_ = cross_validate(VT_unsmoted, X, y, scoring=scoring, cv=skf, n_jobs=8, return_estimator=True)
VT_unsmoted_scores, VT_unsmoted_estimators, accuracies = converter(VT_unsmoted_)

VT_unsmoted_features = feat_extraction(VT_unsmoted_estimators, avoid_scores=True)
VT_unsmoted_features
# Out:
#         troop spell common  rare  epic legendary conf_synergy lift_synergy  \
# fold_1   True  True   True  True  True      True         True         True
# fold_2   True  True   True  True  True      True         True         True
# fold_3   True  True   True  True  True      True         True         True
# fold_4   True  True   True  True  True      True         True         True
# fold_5   True   NaN   True  True  True      True         True         True
# fold_6   True   NaN   True  True  True      True         True         True
# fold_7   True  True   True  True  True      True         True         True
# fold_8   True  True   True  True  True      True         True         True
# fold_9   True  True   True  True  True      True         True         True
# fold_10  True  True   True  True  True      True         True         True
#
#         levelSum avgSpeed avgSpellDuration totalHP avgAS totalUnitsCount  \
# fold_1      True     True             True    True  True            True
# fold_2      True     True             True    True  True            True
# fold_3      True     True             True    True  True            True
# fold_4      True     True             True    True  True            True
# fold_5      True     True             True    True  True            True
# fold_6      True     True             True    True  True            True
# fold_7      True     True             True    True  True            True
# fold_8      True     True             True    True  True            True
# fold_9      True     True             True    True  True            True
# fold_10     True     True             True    True  True            True
#
#         abilityCount totalGroundT totalBuffCount
# fold_1          True         True           True
# fold_2          True         True           True
# fold_3          True         True           True
# fold_4          True         True           True
# fold_5          True         True           True
# fold_6          True         True           True
# fold_7          True         True           True
# fold_8          True         True           True
# fold_9          True         True           True
# fold_10         True         True           True

# %%
metricsComparison['NB+VT'] = [accuracies]

VT_unsmoted_scores
# Out:
#   fit_time score_time test_Accuracy test_Precision test_Recall test_F-Measure
# 0     0.08       0.05        42.02%         44.83%      42.02%         38.38%

# %% [markdown]
# ### BOX PLOT OF RESULTS

# %%
final_dict = {}
for metric in metricsComparison:
    for m in metricsComparison[metric]:
        final_dict[metric] = m
mc_df = pd.DataFrame(final_dict)
mc_df.plot.box(return_type='axes', figsize=(40,20), grid=True, fontsize=14)
# Out:
# <AxesSubplot:>
