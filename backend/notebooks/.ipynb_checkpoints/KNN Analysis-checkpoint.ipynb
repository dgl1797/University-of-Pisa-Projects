# %% [markdown]
# ## ANALYSIS WITH LEVEL

# %%
import pandas as pd
import numpy as np

ranks_df = pd.read_csv("../csv_sources/leveled_for_rarity.csv").drop(["index", "crowns"], axis="columns")
print("---------------------------------------------------")
print(ranks_df[["rank", "troop"]].groupby("rank").mean())
print(ranks_df[["rank", "troop"]].groupby("rank").std())
print("---------------------------------------------------")
print("---------------------------------------------------")
print(ranks_df[["rank", "building"]].groupby("rank").mean())
print(ranks_df[["rank", "building"]].groupby("rank").std())
print("---------------------------------------------------")
print("---------------------------------------------------")
print(ranks_df[["rank", "spell"]].groupby("rank").mean())
print(ranks_df[["rank", "spell"]].groupby("rank").std())
print("---------------------------------------------------")
print("---------------------------------------------------")
print(ranks_df[["rank", "common"]].groupby("rank").mean())
print(ranks_df[["rank", "common"]].groupby("rank").std())
print("---------------------------------------------------")
print("---------------------------------------------------")
print(ranks_df[["rank", "rare"]].groupby("rank").mean())
print(ranks_df[["rank", "rare"]].groupby("rank").std())
print("---------------------------------------------------")
print("---------------------------------------------------")
print(ranks_df[["rank", "epic"]].groupby("rank").mean())
print(ranks_df[["rank", "epic"]].groupby("rank").std())
print("---------------------------------------------------")
print("---------------------------------------------------")
print(ranks_df[["rank", "legendary"]].groupby("rank").mean())
print(ranks_df[["rank", "legendary"]].groupby("rank").std())
print("---------------------------------------------------")
print("---------------------------------------------------")
print(ranks_df[["rank", "elixir"]].groupby("rank").mean())
print(ranks_df[["rank", "elixir"]].groupby("rank").std())
print("---------------------------------------------------")
print("---------------------------------------------------")
print(ranks_df[["rank", "conf_synergy"]].groupby("rank").mean())
print(ranks_df[["rank", "conf_synergy"]].groupby("rank").std())
print("---------------------------------------------------")
print("---------------------------------------------------")
print(ranks_df[["rank", "lift_synergy"]].groupby("rank").mean())
print(ranks_df[["rank", "lift_synergy"]].groupby("rank").std())
print("---------------------------------------------------")
print("---------------------------------------------------")
print(ranks_df[["rank", "levelSum"]].groupby("rank").mean())
print(ranks_df[["rank", "levelSum"]].groupby("rank").std())
print("---------------------------------------------------")
print("---------------------------------------------------")
print(ranks_df[["rank", "avgSpeed"]].groupby("rank").mean())
print(ranks_df[["rank", "avgSpeed"]].groupby("rank").std())
print("---------------------------------------------------")
print("---------------------------------------------------")
print(ranks_df[["rank", "avgSpellDuration"]].groupby("rank").mean())
print(ranks_df[["rank", "avgSpellDuration"]].groupby("rank").std())
print("---------------------------------------------------")
print("---------------------------------------------------")
print(ranks_df[["rank", "totalHP"]].groupby("rank").mean())
print(ranks_df[["rank", "totalHP"]].groupby("rank").std())
print("---------------------------------------------------")
print("---------------------------------------------------")
print(ranks_df[["rank", "totalDMG"]].groupby("rank").mean())
print(ranks_df[["rank", "totalDMG"]].groupby("rank").std())
print("---------------------------------------------------")
print("---------------------------------------------------")
print(ranks_df[["rank", "avgAS"]].groupby("rank").mean())
print(ranks_df[["rank", "avgAS"]].groupby("rank").std())
print("---------------------------------------------------")
print("---------------------------------------------------")
print(ranks_df[["rank", "totalUnitsCount"]].groupby("rank").mean())
print(ranks_df[["rank", "totalUnitsCount"]].groupby("rank").std())
print("---------------------------------------------------")
print("---------------------------------------------------")
print(ranks_df[["rank", "abilityCount"]].groupby("rank").mean())
print(ranks_df[["rank", "abilityCount"]].groupby("rank").std())
print("---------------------------------------------------")
print("---------------------------------------------------")
print(ranks_df[["rank", "avgRange"]].groupby("rank").mean())
print(ranks_df[["rank", "avgRange"]].groupby("rank").std())
print("---------------------------------------------------")
print("---------------------------------------------------")
print(ranks_df[["rank", "totalGroundT"]].groupby("rank").mean())
print(ranks_df[["rank", "totalGroundT"]].groupby("rank").std())
print("---------------------------------------------------")
print("---------------------------------------------------")
print(ranks_df[["rank", "totalAirT"]].groupby("rank").mean())
print(ranks_df[["rank", "totalAirT"]].groupby("rank").std())
print("---------------------------------------------------")
print("---------------------------------------------------")
print(ranks_df[["rank", "totalBuildingT"]].groupby("rank").mean())
print(ranks_df[["rank", "totalBuildingT"]].groupby("rank").std())
print("---------------------------------------------------")
print("---------------------------------------------------")
print(ranks_df[["rank", "totalBuffCount"]].groupby("rank").mean())
print(ranks_df[["rank", "totalBuffCount"]].groupby("rank").std())
print("---------------------------------------------------")
print("---------------------------------------------------")
print(ranks_df[["rank", "totalProjectiles"]].groupby("rank").mean())
print(ranks_df[["rank", "totalProjectiles"]].groupby("rank").std())
print("---------------------------------------------------")
print("---------------------------------------------------")

ranks_df
# Out:
# ---------------------------------------------------
#                troop
# rank
# Challenger  5.889429
# Champion    5.137143
# Master      5.368857
#                troop
# rank
# Challenger  1.115021
# Champion    0.950650
# Master      1.013316
# ---------------------------------------------------
# ---------------------------------------------------
#             building
# rank
# Challenger  0.372857
# Champion    0.508571
# Master      0.516571
#             building
# rank
# Challenger   0.55465
# Champion     0.58287
# Master       0.60342
# ---------------------------------------------------
# ---------------------------------------------------
#                spell
# rank
# Challenger  1.737714
# Champion    2.354286
# Master      2.114571
#                spell
# rank
# Challenger  0.902700
# Champion    0.688925
# Master      0.792047
# ---------------------------------------------------
# ---------------------------------------------------
#               common
# rank
# Challenger  2.013143
# Champion    2.072000
# Master      2.136571
#               common
# rank
# Challenger  1.294281
# Champion    1.376305
# Master      1.301693
# ---------------------------------------------------
# ---------------------------------------------------
#                 rare
# rank
# Challenger  2.021143
# Champion    1.655429
# Master      2.154286
#                 rare
# rank
# Challenger  1.248999
# Champion    1.116844
# Master      1.283559
# ---------------------------------------------------
# ---------------------------------------------------
#                 epic
# rank
# Challenger  2.185714
# Champion    2.470857
# Master      2.216857
#                 epic
# rank
# Challenger  1.298458
# Champion    1.577567
# Master      1.415668
# ---------------------------------------------------
# ---------------------------------------------------
#             legendary
# rank
# Challenger   1.780000
# Champion     1.801714
# Master       1.492286
#             legendary
# rank
# Challenger   1.344450
# Champion     1.019444
# Master       1.047158
# ---------------------------------------------------
# ---------------------------------------------------
#               elixir
# rank
# Challenger  3.941923
# Champion    3.663602
# Master      3.789852
#               elixir
# rank
# Challenger  0.537450
# Champion    0.489592
# Master      0.496820
# ---------------------------------------------------
# ---------------------------------------------------
#             conf_synergy
# rank
# Challenger   5166.317494
# Champion    11960.667065
# Master       8512.293683
#             conf_synergy
# rank
# Challenger  11910.223708
# Champion    16885.578943
# Master      14923.715174
# ---------------------------------------------------
# ---------------------------------------------------
#              lift_synergy
# rank
# Challenger  171762.530769
# Champion    366761.641239
# Master      273465.345554
#              lift_synergy
# rank
# Challenger  431438.047552
# Champion    543340.957634
# Master      517453.027176
# ---------------------------------------------------
# ---------------------------------------------------
#               levelSum
# rank
# Challenger   91.497714
# Champion    103.779429
# Master      103.326571
#              levelSum
# rank
# Challenger  11.262933
# Champion     0.590900
# Master       1.403027
# ---------------------------------------------------
# ---------------------------------------------------
#              avgSpeed
# rank
# Challenger  76.585816
# Champion    75.893459
# Master      77.657602
#              avgSpeed
# rank
# Challenger   9.492413
# Champion    10.364504
# Master       9.948391
# ---------------------------------------------------
# ---------------------------------------------------
#             avgSpellDuration
# rank
# Challenger          5.644639
# Champion            5.840915
# Master              6.916762
#             avgSpellDuration
# rank
# Challenger          8.355736
# Champion            6.088218
# Master              8.031840
# ---------------------------------------------------
# ---------------------------------------------------
#                 totalHP
# rank
# Challenger  8081.543429
# Champion    8247.429143
# Master      8776.516000
#                 totalHP
# rank
# Challenger  2481.123329
# Champion    2348.916699
# Master      2527.995296
# ---------------------------------------------------
# ---------------------------------------------------
#                totalDMG
# rank
# Challenger  2122.466571
# Champion    2219.544857
# Master      2306.429429
#               totalDMG
# rank
# Challenger  736.051547
# Champion    771.445512
# Master      757.911465
# ---------------------------------------------------
# ---------------------------------------------------
#                avgAS
# rank
# Challenger  1.564996
# Champion    1.717283
# Master      1.681641
#                avgAS
# rank
# Challenger  0.469242
# Champion    0.658200
# Master      0.618986
# ---------------------------------------------------
# ---------------------------------------------------
#             totalUnitsCount
# rank
# Challenger        13.337714
# Champion           9.594571
# Master            11.098000
#             totalUnitsCount
# rank
# Challenger         7.276297
# Champion           5.809535
# Master             6.554788
# ---------------------------------------------------
# ---------------------------------------------------
#             abilityCount
# rank
# Challenger      2.488857
# Champion        2.569143
# Master          2.147143
#             abilityCount
# rank
# Challenger      1.472096
# Champion        1.367807
# Master          1.312026
# ---------------------------------------------------
# ---------------------------------------------------
#                avgRange
# rank
# Challenger  2863.975000
# Champion    2976.914286
# Master      2801.794643
#               avgRange
# rank
# Challenger  637.938937
# Champion    688.172799
# Master      640.297747
# ---------------------------------------------------
# ---------------------------------------------------
#             totalGroundT
# rank
# Challenger      7.923429
# Champion        7.982286
# Master          7.953714
#             totalGroundT
# rank
# Challenger      0.275450
# Champion        0.131930
# Master          0.212836
# ---------------------------------------------------
# ---------------------------------------------------
#             totalAirT
# rank
# Challenger   4.072286
# Champion     4.089714
# Master       3.991714
#             totalAirT
# rank
# Challenger   1.023406
# Champion     0.895167
# Master       0.966835
# ---------------------------------------------------
# ---------------------------------------------------
#             totalBuildingT
# rank
# Challenger        0.910000
# Champion          0.920000
# Master            0.947429
#             totalBuildingT
# rank
# Challenger        0.750088
# Champion          0.636509
# Master            0.632168
# ---------------------------------------------------
# ---------------------------------------------------
#             totalBuffCount
# rank
# Challenger        0.672571
# Champion          0.956000
# Master            0.821143
#             totalBuffCount
# rank
# Challenger        0.711793
# Champion          0.743309
# Master            0.739224
# ---------------------------------------------------
# ---------------------------------------------------
#             totalProjectiles
# rank
# Challenger          1.123714
# Champion            1.377429
# Master              1.324000
#             totalProjectiles
# rank
# Challenger          0.850908
# Champion            0.865062
# Master              0.866740
# ---------------------------------------------------
# ---------------------------------------------------
#              rank  troop  building  spell  common  rare  epic  legendary  \
# 0      Challenger      5         0      3       1     1     4          2
# 1      Challenger      5         1      2       1     2     3          2
# 2          Master      7         1      0       3     3     2          0
# 3      Challenger      7         0      1       4     2     1          1
# 4      Challenger      5         0      3       1     1     5          1
# ...           ...    ...       ...    ...     ...   ...   ...        ...
# 10495    Champion      5         1      2       0     4     4          0
# 10496    Champion      6         0      2       1     2     3          2
# 10497    Champion      6         0      2       2     1     2          3
# 10498    Champion      5         1      2       4     2     1          1
# 10499    Champion      6         0      2       0     1     6          1
#
#        elixir  conf_synergy  ...  avgRange  totalGroundT  totalAirT  \
# 0       3.375   2865.990531  ...   2712.50             8          3
# 1       4.250   3980.516610  ...   2018.75             7          5
# 2       4.875      0.000000  ...   1925.00             8          2
# 3       3.750   1389.332225  ...   4175.00             8          6
# 4       4.500   4049.013035  ...   3056.25             8          4
# ...       ...           ...  ...       ...           ...        ...
# 10495   3.625   2191.588585  ...   2800.00             8          4
# 10496   4.000  26569.219252  ...   2581.25             8          4
# 10497   3.750   2671.736517  ...   2275.00             8          4
# 10498   3.125  14365.842341  ...   3868.75             8          3
# 10499   4.625   3303.615309  ...   3006.25             8          5
#
#        totalBuildingT  totalBuffCount  totalProjectiles  commonLevel  \
# 0                   0               0                 3        11.00
# 1                   1               2                 0        13.00
# 2                   2               0                 0        13.00
# 3                   0               0                 1        13.00
# 4                   1               2                 1        13.00
# ...               ...             ...               ...          ...
# 10495               1               1                 1         0.00
# 10496               1               2                 0        13.00
# 10497               1               1                 1        13.00
# 10498               1               0                 2        16.25
# 10499               1               0                 2         0.00
#
#        rareLevel  epicLevel  legendaryLevel
# 0           11.0      10.25            10.5
# 1           13.0      13.00            13.0
# 2           13.0      13.00             0.0
# 3           13.0      13.00            13.0
# 4           13.0      13.00            13.0
# ...          ...        ...             ...
# 10495       13.0      13.00             0.0
# 10496       13.0      13.00            13.0
# 10497       13.0      13.00            13.0
# 10498       13.0       0.00            13.0
# 10499       13.0      13.00            13.0
#
# [10500 rows x 29 columns]

# %%
from sklearn.model_selection import StratifiedKFold
from imblearn.pipeline import Pipeline
from imblearn.over_sampling import SMOTE
from sklearn.feature_selection import SelectKBest, chi2, mutual_info_classif, VarianceThreshold
from sklearn.metrics import classification_report
from sklearn.model_selection import cross_validate
from sklearn.tree import DecisionTreeClassifier
from random import randrange
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn.metrics import make_scorer
from sklearn.neighbors import KNeighborsClassifier

y = np.array([x for x in ranks_df["rank"]])
X = np.array([x for x in ranks_df.drop(["rank"], axis="columns").values])

scoring = {
    'Accuracy': make_scorer(accuracy_score),
    'Precision': make_scorer(precision_score, average='macro', zero_division=0),
    'Recall': make_scorer(recall_score, average="macro", zero_division=0),
    'F-Measure': make_scorer(f1_score, average="macro", zero_division=0)
}

def converter(df):
    scores = {
        'fit_time': df['fit_time'],
        'score_time': df['score_time'],
        'test_Accuracy': df['test_Accuracy'],
        'test_Precision': df['test_Precision'],
        'test_Recall': df['test_Recall'],
        'test_F-Measure': df['test_F-Measure']
    }
    estimators = df['estimator']
    accuracies = df['test_Accuracy']
    for key in scores.keys():
        if "test_" in key:
            scores[key] = [f"{scores[key].mean() * 100: .2f}%"]
        else:
            scores[key] = [f"{scores[key].mean(): .2f}"]
    return [pd.DataFrame(scores), estimators, accuracies]

def feat_extraction(estimators, avoid_scores = False):
    features_per_fold = {}
    fold_index = 0
    for estim in estimators:
        fold_index += 1
        feature = 0
        sel_features = {}
        feat_scores = []
        if not avoid_scores:
            feat_scores = estim['feat_sel'].scores_
        for selected in estim['feat_sel'].get_support():
            feature+=1
            if(selected == True):
                if len(feat_scores) > 0:
                    sel_features[ranks_df.columns[feature]] = [feat_scores[feature-1]]
                else:
                    sel_features[ranks_df.columns[feature]] = True
        features_per_fold[f"fold_{fold_index}"] = sel_features
    return pd.DataFrame(features_per_fold).transpose()

skf = StratifiedKFold(n_splits=10, shuffle=True, random_state=randrange(1,42))

# %% [markdown]
# ### ANALYSIS

# %%
smoted_pipeline = Pipeline([
    ('sampler', SMOTE(random_state=randrange(1,42))),
    ('clf', KNeighborsClassifier(n_neighbors=4))
])
unsmoted_pipeline = Pipeline([
    ('clf', KNeighborsClassifier(n_neighbors=4))
])
#######################################################
kbest_smoted = Pipeline([
    ('feat_sel', SelectKBest(chi2, k=12)),
    ('sampler', SMOTE(random_state=randrange(1,42))),
    ('clf', KNeighborsClassifier(n_neighbors=4))
])
kbest_unsmoted = Pipeline([
    ('feat_sel', SelectKBest(chi2, k=12)),
    ('clf', KNeighborsClassifier(n_neighbors=4))
])
########################################################
kbest_smoted_mutual = Pipeline([
    ('feat_sel', SelectKBest(mutual_info_classif, k=12)),
    ('sampler', SMOTE(random_state=randrange(1,42))),
    ('clf', KNeighborsClassifier(n_neighbors=4))
])
kbest_unsmoted_mutual = Pipeline([
    ('feat_sel', SelectKBest(mutual_info_classif, k=12)),
    ('clf', KNeighborsClassifier(n_neighbors=4))
])
########################################################
VT_smoted = Pipeline([
    ('feat_sel', VarianceThreshold(threshold=0.7)),
    ('sampler', SMOTE(random_state=randrange(1,42))),
    ('clf', KNeighborsClassifier(n_neighbors=4))
])
VT_unsmoted = Pipeline([
    ('feat_sel', VarianceThreshold(threshold=0.7)),
    ('clf', KNeighborsClassifier(n_neighbors=4))
])

metricsComparison = {}

# %% [markdown]
# ### SMOTE NO ATTRIBUT SELECTION

# %%
smoted_ = cross_validate(smoted_pipeline, X, y, scoring=scoring, cv=skf, n_jobs=8, return_estimator=True)
mean_smoted, smoted_estimators, accuracies = converter(smoted_)

metricsComparison['KNN + SMOTE'] = [accuracies]

mean_smoted
# Out:
#   fit_time score_time test_Accuracy test_Precision test_Recall test_F-Measure
# 0     0.03       0.66        55.85%         54.55%      55.85%         54.16%

# %% [markdown]
# ### NO SMOTE NO ATTRIBUTE SELECTION

# %%
unsmoted_ = cross_validate(unsmoted_pipeline, X, y, scoring=scoring, cv=skf, n_jobs=8, return_estimator=True)
mean_unsmoted, unsmoted_estimators, accuracies = converter(unsmoted_)

metricsComparison['KNN'] = [accuracies]

mean_unsmoted
# Out:
#   fit_time score_time test_Accuracy test_Precision test_Recall test_F-Measure
# 0     0.01       0.73        52.52%         51.45%      52.52%         51.46%

# %% [markdown]
# ### SMOTE KBEST SELECTION

# %%
kbest_smoted_ = cross_validate(kbest_smoted, X, y, scoring=scoring, cv=skf, n_jobs=8, return_estimator=True)

mean_kbest_smoted, kbest_smoted_estimators, accuracies = converter(kbest_smoted_)
    
kbest_features = feat_extraction(kbest_smoted_estimators)
kbest_features
# Out:
#                 conf_synergy          lift_synergy              levelSum  \
# fold_1   [8258590.969485871]   [215400623.7160621]  [3096.1813155499603]
# fold_2    [8472540.24457585]   [219460153.0894053]   [3085.908541195059]
# fold_3   [8698664.017277448]  [225689828.42211932]  [3101.3884599108114]
# fold_4   [8422444.551662724]  [221760903.02213094]  [3022.6089141268412]
# fold_5   [8659694.434846068]   [220609305.9461171]  [3005.2151065787884]
# fold_6   [8713938.219106162]  [228244830.03637734]  [3033.3481786669813]
# fold_7   [8817480.192289637]   [230109619.5767664]  [3082.2841287647198]
# fold_8   [8412403.640492756]  [218495715.59248054]  [3064.2070881360473]
# fold_9    [8258950.11422432]   [216815121.6745361]   [3080.496366367931]
# fold_10  [8404447.020892685]  [218817367.95135948]   [3123.907198601247]
#
#              avgSpellDuration               totalHP              totalDMG  \
# fold_1    [412.6436363590639]  [105079.33002539097]  [26281.086108380092]
# fold_2    [536.3939673349039]   [92016.00346443735]  [21738.827604837024]
# fold_3   [408.16700754413677]  [102423.90096564133]   [24996.71438130614]
# fold_4    [434.3044769143163]   [92609.30940473542]    [22681.8999066256]
# fold_5    [535.3585333809535]  [100295.81696241969]  [26006.061151239686]
# fold_6   [449.08451578986626]   [107463.9733098357]  [23631.273235691966]
# fold_7    [447.4796085343702]  [103650.03421116932]  [25076.914113643055]
# fold_8    [547.6298169193652]    [91445.7475554758]  [21978.317168152702]
# fold_6   [0.23947023185365413]   [0.2515873408498832]  [0.31539817426756955]
# fold_7    [0.2259061942978109]  [0.24412764620406757]   [0.3203990346157324]
# fold_8   [0.23925784216161916]   [0.2567124124628759]  [0.31491184428858965]
# fold_9   [0.23657809951168574]   [0.2547522595585503]  [0.32236741678420033]
# fold_10  [0.22911125092883688]   [0.2553636606204903]  [0.32281096654720853]

# %%
metricsComparison['KNN + SMOTE + KBEST and mutual_info'] = [accuracies]

kbest_smoted_mutual_scores
# Out:
#   fit_time score_time test_Accuracy test_Precision test_Recall test_F-Measure
# 0     2.14       0.09        55.58%         54.29%      55.58%         54.00%

# %% [markdown]
# ###### UNSMOTED

# %%
kbest_unsmoted_mutual_ = cross_validate(kbest_unsmoted_mutual, X, y, scoring=scoring, cv=skf, n_jobs=8, return_estimator=True)
kbest_unsmoted_mutual_scores, kbest_unsmoted_mutual_estimators, accuracies = converter(kbest_unsmoted_mutual_)

kbest_unsmoted_mutual_features = feat_extraction(kbest_unsmoted_mutual_estimators)
kbest_unsmoted_mutual_features

# %%
metricsComparison['KNN + KBEST and mutual_info'] = [accuracies]

kbest_unsmoted_mutual_scores

# %% [markdown]
# ### VARIANCE THRESHOLD SELECTION

# %% [markdown]
# ###### SMOTED

# %%
VT_smoted_ = cross_validate(VT_smoted, X, y, scoring=scoring, cv=skf, n_jobs=8, return_estimator=True)
VT_smoted_scores, VT_smoted_estimators, accuracies = converter(VT_smoted_)

VT_smoted_features = feat_extraction(VT_smoted_estimators, avoid_scores=True)
VT_smoted_features

# %%
metricsComparison['KNN + SMOTE + Variance Threshold'] = [accuracies]

VT_smoted_scores

# %% [markdown]
# ###### UNSMOTED

# %%
VT_unsmoted_ = cross_validate(VT_unsmoted, X, y, scoring=scoring, cv=skf, n_jobs=8, return_estimator=True)
VT_unsmoted_scores, VT_unsmoted_estimators, accuracies = converter(VT_unsmoted_)

VT_unsmoted_features = feat_extraction(VT_unsmoted_estimators, avoid_scores=True)
VT_unsmoted_features

# %%
metricsComparison['KNN + Variance Threshold'] = [accuracies]

VT_unsmoted_scores

# %% [markdown]
# ### BOX PLOT OF RESULTS

# %%
final_dict = {}
for metric in metricsComparison:
    for m in metricsComparison[metric]:
        final_dict[metric] = m
mc_df = pd.DataFrame(final_dict)
mc_df.plot.box(return_type='axes', figsize=(40,20), grid=True, fontsize=14)

# %% [markdown]
# ## ANALYSIS WITHOUT LEVEL

# %%
ranks_nolevel_df = ranks_df.drop(["levelSum"], axis="columns")
ranks_nolevel_df

# %%
y = np.array([x for x in ranks_nolevel_df["rank"]])
X = np.array([x for x in ranks_nolevel_df.drop(["rank"], axis="columns").values])
metricsComparison = {}

# %% [markdown]
# ### SMOTE NO ATTRIBUT SELECTION

# %%
smoted_ = cross_validate(smoted_pipeline, X, y, scoring=scoring, cv=skf, n_jobs=8, return_estimator=True)
mean_smoted, smoted_estimators, accuracies = converter(smoted_)

metricsComparison['KNN+SMOTE'] = [accuracies]

mean_smoted

# %% [markdown]
# ### NO SMOTE NO ATTRIBUTE SELECTION

# %%
unsmoted_ = cross_validate(unsmoted_pipeline, X, y, scoring=scoring, cv=skf, n_jobs=8, return_estimator=True)
mean_unsmoted, unsmoted_estimators, accuracies = converter(unsmoted_)

metricsComparison['KNN'] = [accuracies]

mean_unsmoted

# %% [markdown]
# ### SMOTE KBEST SELECTION

# %%
kbest_smoted_ = cross_validate(kbest_smoted, X, y, scoring=scoring, cv=skf, n_jobs=8, return_estimator=True)

mean_kbest_smoted, kbest_smoted_estimators, accuracies = converter(kbest_smoted_)
    
kbest_features = feat_extraction(kbest_smoted_estimators)
kbest_features

# %%
metricsComparison['KNN+SMOTE+KBEST and chi2'] = [accuracies]

mean_kbest_smoted

# %% [markdown]
# ### NO SMOTE KBEST SELECTION

# %%
kbest_unsmoted_scores = cross_validate(kbest_unsmoted, X, y, scoring=scoring, cv=skf, n_jobs=8, return_estimator=True)
mean_kbest_unsmoted, kbest_unsmoted_estimators, accuracies = converter(kbest_unsmoted_scores)

kbest_unsmoted_features = feat_extraction(kbest_unsmoted_estimators)

kbest_unsmoted_features

# %%
metricsComparison['KNN+KBEST and chi2'] = [accuracies]

mean_kbest_unsmoted

# %% [markdown]
# ### KBEST SELECTOR WITH MUTUAL INFO CLASSIFIER

# %% [markdown]
# ###### SMOTED

# %%
kbest_smoted_mutual_ = cross_validate(kbest_smoted_mutual, X, y, scoring=scoring, cv=skf, n_jobs=8, return_estimator=True)
kbest_smoted_mutual_scores, kbest_smoted_mutual_estimators, accuracies = converter(kbest_smoted_mutual_)

kbest_smoted_mutual_features = feat_extraction(kbest_smoted_mutual_estimators)
kbest_smoted_mutual_features

# %%
metricsComparison['KNN+SMOTE+KBest and mutual info'] = [accuracies]

kbest_smoted_mutual_scores

# %% [markdown]
# ###### UNSMOTED

# %%
kbest_unsmoted_mutual_ = cross_validate(kbest_unsmoted_mutual, X, y, scoring=scoring, cv=skf, n_jobs=8, return_estimator=True)
kbest_unsmoted_mutual_scores, kbest_unsmoted_mutual_estimators, accuracies = converter(kbest_unsmoted_mutual_)

kbest_unsmoted_mutual_features = feat_extraction(kbest_unsmoted_mutual_estimators)
kbest_unsmoted_mutual_features

# %%
metricsComparison['KNN+KBest and mutual info'] = [accuracies]

kbest_unsmoted_mutual_scores

# %% [markdown]
# ### VARIANCE THRESHOLD SELECTION

# %% [markdown]
# ###### SMOTED

# %%
VT_smoted_ = cross_validate(VT_smoted, X, y, scoring=scoring, cv=skf, n_jobs=8, return_estimator=True)
VT_smoted_scores, VT_smoted_estimators, accuracies = converter(VT_smoted_)

VT_smoted_features = feat_extraction(VT_smoted_estimators, avoid_scores=True)
VT_smoted_features.transpose()

# %%
metricsComparison['KNN+SMOTE+VT'] = [accuracies]

VT_smoted_scores

# %% [markdown]
# ###### UNSMOTED

# %%
VT_unsmoted_ = cross_validate(VT_unsmoted, X, y, scoring=scoring, cv=skf, n_jobs=8, return_estimator=True)
VT_unsmoted_scores, VT_unsmoted_estimators, accuracies = converter(VT_unsmoted_)

VT_unsmoted_features = feat_extraction(VT_unsmoted_estimators, avoid_scores=True)
VT_unsmoted_features

# %%
metricsComparison['KNN+VT'] = [accuracies]

VT_unsmoted_scores.transpose()

# %% [markdown]
# ### BOX PLOT OF RESULTS

# %%
final_dict = {}
for metric in metricsComparison:
    for m in metricsComparison[metric]:
        final_dict[metric] = m
mc_df = pd.DataFrame(final_dict)
mc_df.plot.box(return_type='axes', figsize=(40,20), grid=True, fontsize=14)
